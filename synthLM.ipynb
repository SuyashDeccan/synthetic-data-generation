# %%
import os
import glob
import json
import math
import random
import re
from collections import Counter
import networkx as nx
import pdfplumber
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

# Set the OpenAI API key from environment variable
api_key = os.getenv("OPENAI_API_KEY")
client = OpenAI(api_key=api_key)

# -- Document Loading ------------------------------------------------------

def load_docs_from_dir(dir_path):
    """
    Load all .pdf files from a directory and extract their full text.
    Returns a list of strings, one per PDF.
    """
    docs = []
    filenames = []
    for filepath in glob.glob(os.path.join(dir_path, '*.pdf')):
        try:
            text_pages = []
            with pdfplumber.open(filepath) as pdf:
                for page in pdf.pages:
                    text_pages.append(page.extract_text() or "")
            full_text = "\n".join(text_pages)
            docs.append(full_text)
            filenames.append(os.path.basename(filepath))
        except Exception as e:
            # skip unreadable PDFs
            print(f"Warning: could not load {filepath}: {e}")
    return docs, filenames

# -- 1. Extract topics and key concepts -----------------------------------

def extract_json_from_text(text):
    """Helper function to extract JSON content from markdown code blocks or raw text"""
    # Try to extract JSON from markdown code blocks
    json_match = re.search(r'```(?:json)?\s*(.*?)\s*```', text, re.DOTALL)
    if json_match:
        return json_match.group(1).strip()
    
    # If no code blocks, try to find JSON-like structures
    json_match = re.search(r'(\{.*\})', text, re.DOTALL)
    if json_match:
        return json_match.group(1).strip()
    
    # Return original text if no JSON structure found
    return text

def extract_concepts_from_docs(doc_texts, filenames, model="gpt-4o"):  
    """
    Call OpenAI API to extract topics and key concepts from each document.
    Returns list of dicts with keys 'topics' and 'key_concepts'.
    """
    extractions = []
    for i, text in enumerate(doc_texts):
        filename = filenames[i] if i < len(filenames) else f"doc_{i}"
        
        prompt = (
            "Extract high-level topics and key concepts from the following document. "
            f"Return JSON with keys 'topics' and 'key_concepts'.\n\n{text}"
        )
        response = client.chat.completions.create(
            model=model,
            messages=[
                {"role": "system", "content": "You are an expert summarizer. Return your response as a JSON object with 'topics' and 'key_concepts' as arrays."},
                {"role": "user", "content": prompt}
            ],
        )
        
        output = response.choices[0].message.content
        print("Raw output:", output)
        
        try:
            # Clean and extract JSON from the output
            json_str = extract_json_from_text(output)
            data = json.loads(json_str)
            
            # Ensure we have the expected keys
            if "topics" in data and "key_concepts" in data:
                extraction = {
                    "filename": filename,
                    "topics": data["topics"],
                    "key_concepts": data["key_concepts"]
                }
                extractions.append(extraction)
                print(f"Successfully extracted {len(data['topics'])} topics and {len(data['key_concepts'])} key concepts from {filename}")
            else:
                print(f"Warning: Parsed JSON doesn't have expected keys: {data.keys()}")
                extractions.append({
                    "filename": filename,
                    "topics": [], 
                    "key_concepts": []
                })
                
        except json.JSONDecodeError as e:
            print(f"Failed to parse JSON: {e}")
            extractions.append({
                "filename": filename,
                "topics": [], 
                "key_concepts": []
            })
    
    return extractions

# -- 2. Construct the concept graph ----------------------------------------

def build_concept_graph(extractions, eps=1e-6):
    """
    Build a unified graph G where nodes are topics + key concepts and
    edges weighted by log(freq+eps) based on co-occurrence in docs.
    Returns: G (nx.Graph), topic_nodes, kc_nodes
    """
    freq = Counter()
    all_topics, all_kcs = set(), set()

    for ex in extractions:
        nodes = ex["topics"] + ex["key_concepts"]
        for i in range(len(nodes)):
            for j in range(i+1, len(nodes)):
                u, v = sorted((nodes[i], nodes[j]))
                freq[(u, v)] += 1
        all_topics.update(ex["topics"])
        all_kcs.update(ex["key_concepts"])

    G = nx.Graph()
    for (u, v), f in freq.items():
        weight = math.log(f + eps)
        G.add_edge(u, v, weight=weight)

    print(f"Graph built with {len(all_topics)} topics and {len(all_kcs)} key concepts")
    return G, all_topics, all_kcs

# -- Helpers for sampling --------------------------------------------------

def softmax(weights):
    exps = [math.exp(w) for w in weights]
    s = sum(exps) or 1.0
    return [e/s for e in exps]


def random_walk(G, start, steps):
    """
    Random walk on graph G for given steps from 'start',
    with transition probabilities via softmax over edge weights.
    """
    path = [start]
    current = start
    for _ in range(steps):
        nbrs = list(G[current])
        if not nbrs:
            break
        weights = [G[current][n]['weight'] for n in nbrs]
        probs = softmax(weights)
        current = random.choices(nbrs, probs)[0]
        path.append(current)
    return path

# -- 3. Concept combination sampling ---------------------------------------

def sample_concept_combinations(
    G, topic_nodes, kc_nodes,
    num_samples=100,
    topic_walk_steps=(1, 2),
    kc_walk_steps=(3, 4)
):
    """
    Generate sampled sets of topics and key concepts via multi-stage random walks.
    Returns list of dicts: {'topics': set, 'key_concepts': set}
    """
    # Safety check
    if not topic_nodes:
        print("Error: No topics found. Cannot sample combinations.")
        return []
        
    G_topic = G.subgraph(topic_nodes)
    G_topic_kc = G.subgraph(topic_nodes | kc_nodes)
    G_kc = G.subgraph(kc_nodes)
    samples = []

    topics_list = list(topic_nodes)
    print(f"Sampling from {len(topics_list)} topics")
    
    for _ in range(num_samples):
        t0 = random.choice(topics_list)
        t_steps = random.choice(topic_walk_steps)
        topic_path = random_walk(G_topic, t0, t_steps)
        sampled_topics = set(topic_path)

        kc_cands = [nbr for t in sampled_topics for nbr in G_topic_kc[t] if nbr in kc_nodes]
        if kc_cands:
            k0 = random.choice(kc_cands)
            k_steps = random.choice(kc_walk_steps)
            kc_path = random_walk(G_kc, k0, k_steps)
            sampled_kcs = set(kc_path)
        else:
            sampled_kcs = set()

        samples.append({
            "topics": list(sampled_topics),  # Convert sets to lists for JSON serialization
            "key_concepts": list(sampled_kcs)
        })
    
    return samples

# -- 4. Question generation ------------------------------------------------

def generate_questions_for_samples(combos, docs, extractions, model="gpt-4o"):  
    """
    For each sampled combo, pick two docs via Jaccard on concept sets,
    then call LLM to generate questions.
    Returns list of dicts: {'sample': combo, 'questions': [...]}.
    """
    doc_concepts = [set(ex['topics'] + ex['key_concepts']) for ex in extractions]
    # doc_concepts= doc_concepts[:1]
    results = []
    max_samples = 100
    # combos = combos[:max_samples]
    for i, combo in enumerate(combos):
        combo_id = f"combo_{i+1}"
        kg = set(combo['topics']) | set(combo['key_concepts'])
        sims = []
        for idx, dc in enumerate(doc_concepts):
            inter = kg & dc
            union = kg | dc
            sims.append((len(inter) / (len(union) or 1), idx))
        sims.sort(reverse=True)
        top_idxs = [i for _, i in sims[:2]]
        refs = [docs[i] for i in top_idxs]
        ref_files = [extractions[i]["filename"] for i in top_idxs]
        System_prompt =f"""
Each question must follow these instructions:
Model a Physical Scenario: Start from a real-world or idealized setup. Avoid abstract Physics problems or purely conceptual statements.
Target a Solvable Quantity: Ask for a clear symbolic expression of a physical variable (e.g., tension, acceleration, energy).
Force Multi-Step Reasoning: Ensure the question involves a sequence of physics laws, transformations, and derivations to reach the answer.
Avoid Redundancy: Exclude extraneous details or variables that do not impact the final solution.
Be Unique: Do not rephrase standard textbook problems; ensure originality and complexity.
Single solution: Expect a single symbolic expression, unambiguous, presented in LaTeX. Multiple equivalent algebraic forms are allowed. No equations or floating-point approximations.
Use rigorous, concise phrasing.
Avoid colloquial or ambiguous terminology.
Units must be consistent; symbols should follow standard notation.
"""
        prompt = (
            f"Generate a set of difficult Physics questions based on the following:\n"
            
            f"Topics: {combo['topics']}\n"
            f"Key Concepts: {combo['key_concepts']}\n"
            f"Reference Doc 1:\n{refs[0]}\n"
        )
        if len(refs) > 1:
            prompt += f"Reference Doc 2:\n{refs[1]}\n"
        prompt += "Return a JSON array of questions."

        # from ollama import chat
        # from ollama import ChatResponse

        # response: ChatResponse = chat(model='qwen3:8b', 
        #                                messages=[
        #         {"role": "system", "content": System_prompt},
        #         {"role": "user", "content": prompt}
        #     ])
        # # print(response['message']['content'])
        # # or access fields directly from the response object
        # print(response.message.content)
        # content = response.message.content
        response = client.chat.completions.create(
            model=model,
            messages=[
                {"role": "system", "content": System_prompt},
                {"role": "user", "content": prompt}
            ]
        )
        content = response.choices[0].message.content
        
        try:
            # Clean and extract JSON from the output
            json_str = extract_json_from_text(content)
            questions = json.loads(json_str)
            if not isinstance(questions, list):
                # If the output is an object with a questions key
                if isinstance(questions, dict) and "questions" in questions:
                    questions = questions["questions"]
                else:
                    questions = [str(questions)]
        except json.JSONDecodeError:
            questions = [content]

        results.append({
            "id": combo_id,
            "topics": combo['topics'],
            "key_concepts": combo['key_concepts'],
            "reference_files": ref_files,
            "questions": questions
        })
        max_samples-=1
        if max_samples == 0:
            break


    return results

# -- Save outputs to files ------------------------------------------------

def save_extractions(extractions, output_file="document_extractions.json"):
    """Save the extracted topics and key concepts for each document"""
    # Ensure the extractions are serializable (convert sets to lists)
    serializable_extractions = []
    for ex in extractions:
        serializable_extractions.append({
            "filename": ex["filename"],
            "topics": list(ex["topics"]),
            "key_concepts": list(ex["key_concepts"])
        })
    
    with open(output_file, "w") as f:
        json.dump(serializable_extractions, f, indent=2)
    
    print(f"Saved document extractions to {output_file}")

def save_questions_with_topics(questions, output_file="questions_with_topics.json"):
    """Save the generated questions with their topic combinations"""
    with open(output_file, "w") as f:
        json.dump(questions, f, indent=2)
    
    print(f"Saved questions with topic combinations to {output_file}")

# -- Main Execution --------------------------------------------------------

# if __name__ == "__main__":
#     # Create output directory if it doesn't exist
#     output_dir = "output_apple"
#     os.makedirs(output_dir, exist_ok=True)
    
#     # adjust this path to where your .pdf docs live
#     docs_dir = "docs/"
    
#     print("Loading documents...")
#     docs, filenames = load_docs_from_dir(docs_dir)
#     print(f"Loaded {len(docs)} documents")
    
#     if not docs:
#         print("No documents found. Please check the docs directory.")
#         exit(1)
    
#     # 1) Extract topics & KCs
#     print("\nExtracting topics and key concepts...")
#     extractions = extract_concepts_from_docs(docs, filenames)
    
#     # Save extractions to file
#     save_extractions(extractions, os.path.join(output_dir, "document_extractions.json"))
    
#     # Verify we have valid extractions
#     valid_extractions = [ex for ex in extractions if ex["topics"] or ex["key_concepts"]]
#     if not valid_extractions:
#         print("No valid topics or key concepts extracted. Check your data and API responses.")
#         exit(1)
    
#     # 2) Build graph
#     print("\nBuilding concept graph...")
#     G, topic_nodes, kc_nodes = build_concept_graph(extractions)
    
#     if not topic_nodes:
#         print("No topics found in the graph. Cannot proceed.")
#         exit(1)
    
#     # 3) Sample combinations
#     print("\nSampling concept combinations...")
#     combos = sample_concept_combinations(G, topic_nodes, kc_nodes, num_samples=10)  # Reduced for testing
    
#     if not combos:
#         print("Failed to generate concept combinations.")
#         exit(1)
    
#     # Save topic combinations
#     with open(os.path.join(output_dir, "topic_combinations.json"), "w") as f:
#         json.dump(combos, f, indent=2)
    
#     # 4) Generate questions
#     print("\nGenerating questions for each combination...")
#     q_outputs = generate_questions_for_samples(combos, docs, extractions)
    
#     # Save questions with topics
#     save_questions_with_topics(q_outputs, os.path.join(output_dir, "questions_with_topics.json"))
    
#     # Display results
#     print("\n===== GENERATED QUESTIONS =====")
#     for idx, out in enumerate(q_outputs, 1):
#         print(f"\nSample {idx}:")
#         print(f"Topics: {out['topics']}")
#         print(f"Key Concepts: {out['key_concepts']}")
#         print(f"Reference Files: {out['reference_files']}")
#         print("Questions:")
#         for q in out['questions']:
#             print(f" - {q}")
    
#     print(f"\nAll outputs saved to directory: {output_dir}") 

if __name__ == "__main__":
    # Create output directory if it doesn't exist
    # Create output directory if it doesn't exist
    output_dir = "output_apple"
    os.makedirs(output_dir, exist_ok=True)
    
    # adjust this path to where your .pdf docs live
    docs_dir = "docs/"
    
    print("Loading documents...")
    docs, filenames = load_docs_from_dir(docs_dir)
    print(f"Loaded {len(docs)} documents")
    document_extractions = []
    with open("output_apple/document_extractions.json", "r") as f:
        document_extractions = json.load(f)
    for doc in document_extractions:
        print(doc)
        break

    topic_combinations = []
    with open("output_apple/topic_combinations.json", "r") as f:
        topic_combinations = json.load(f)
    for combo in topic_combinations:
        print(combo)
        break

    # generate questions 
    print("Generating questions...")
    q_outputs = generate_questions_for_samples(topic_combinations, docs, document_extractions)

    # Save questions with topics
    save_questions_with_topics(q_outputs, os.path.join(output_dir, "questions_with_topics.json"))
    
    # Display results
    print("\n===== GENERATED QUESTIONS =====")
    for idx, out in enumerate(q_outputs, 1):
        print(f"\nSample {idx}:")
        print(f"Topics: {out['topics']}")
        print(f"Key Concepts: {out['key_concepts']}")
        print(f"Reference Files: {out['reference_files']}")
        print("Questions:")
        for q in out['questions']:
            print(f" - {q}")
    
    print(f"\nAll outputs saved to directory: {output_dir}")
# Out:
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# Loading documents...
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# Warning: could not load docs/23.pdf: No /Root object! - Is this really a PDF?
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# ...
#  - {'question': 'Consider a scalar field theory with a Higgs sector described by the potential $V(\\Phi) = \\mu^2 |\\Phi|^2 + \\lambda |\\Phi|^4$ in the Standard Model framework. Using Wilsonian effective field theory, derive an expression for the parameter $\\mu^2$ renormalized at a scale $\\mu_R$ in terms of a high-energy cutoff $\\Lambda$ and loop corrections from top quarks, Higgs bosons, and gauge bosons. Discuss the significance of these corrections in relation to the Little Hierarchy Problem.', 'topic': 'Standard Model', 'key_concepts': ['Higgs mass term', 'Wilsonian effective field theory', 'Little Hierarchy Problem']}
#  - {'question': 'In the context of the Standard Model, the mass term for the Higgs field is $\\mu^2 \\Phi^\\dagger \\Phi$. Discuss how radiative corrections to this term contribute to the Hierarchy Problem. Derive an expression for the leading contribution to $\\mu^2$ as modified by the scale of new physics $\\Lambda$, and comment on the potentially necessary characteristics of this new physics to mitigate the Hierarchy Problem.', 'topic': 'Standard Model', 'key_concepts': ['Higgs mass term', 'Hierarchy Problem', 'new physics scale']}
#  - {'question': 'The Little Higgs models posit a new set of interactions that include vectorlike top partners to protect the Higgs mass from large radiative corrections. Given a setup where the Higgs boson is a pseudo-Goldstone boson, derive the expression for the Higgs mass parameter squared $m_H^2$ in terms of the new physics mass scale $M_{NP}$ and the symmetry breaking scale $f$, including the contribution from these top partners. Explain how this helps address the Little Hierarchy Problem.', 'topic': 'Little Higgs Models', 'key_concepts': ['Higgs mass term', 'Particle hierarchy and mass scales', 'Little Hierarchy Problem']}
#  - {'question': 'Using the Wilsonian perspective, consider a scenario where the Higgs boson is viewed as a composite particle within a strongly coupled sector at a scale $\\Lambda_{HC}$. Derive an expression for the Higgs mass parameter in terms of the couplings at this high-energy scale and outline how this viewpoint aids in addressing the Little Hierarchy Problem.', 'topic': 'Composite Higgs Model', 'key_concepts': ['Wilsonian effective field theory', 'Higgs mass term', 'Little Hierarchy Problem']}
#
# Sample 7:
# Topics: ['Non-Abelian Topological Superconductivity', 'Impurities and Disorder Effects']
# Key Concepts: ['Impurities such as uranium defects significantly affect superconducting properties, potentially inducing a B3u dominant state.', 'UTe2 is investigated for its fully gapped pairing state and absence of nodes in the order parameter, challenging previous beliefs about its structure.', 'The nature of gap symmetries in UTe2 is crucial; evidence suggests a fully gapped Au state analogous to the B phase of superfluid 3He.']
# Reference Files: ['7.pdf', '2.pdf']
# Questions:
#  - {'question': 'Consider a non-Abelian topological superconductor characterized by the B3u dominant state with point nodes along the a axis. Suppose an impurity, modeled as a delta function potential, is introduced along the a axis. Derive an expression for the induced change in the superconducting gap function using perturbation theory, considering the non-Abelian symmetry constraints.', 'answer': "The change in the superconducting gap function, \\( \\Delta \\psi(\\mathbf{k}) \\), induced by a delta function impurity \\( V_0 \\delta(x) \\) in a non-Abelian topological superconductor with B3u symmetry, can be expressed as: \\( \\Delta \\psi(\\mathbf{k}) = -V_0 \\sum_{\\mathbf{k'}} \\frac{\\psi(\\mathbf{k'})}{E_{\\mathbf{k'}} - E_{\\mathbf{k}} + i\\delta} \\), where \\( \\psi(\\mathbf{k'}) \\) is the unperturbed gap function and \\( i\\delta \\) arises from the energy's imaginary part ensuring causality."}
#  - {'question': 'In a system characterized by isotropic Au non-Abelian topological superconductivity in UTe2, considered with uranium defect impurities, calculate the crossover temperature at which uranium clusters begin to disrupt the global superconducting order, assuming short-range interactions. Include necessary transformations to reach the final expression.', 'answer': 'The crossover temperature, \\( T^* \\), at which uranium defect clusters disrupt the superconducting order in the isotropic Au state can be expressed as: \\( T^* = T_c - \\frac{g^2 \\mu_0}{k_B} \\), where \\( g \\) is the coupling constant of uranium defects, \\( \\mu_0 \\) is the characteristic energy scale of uranium clusters, and \\( k_B \\) is the Boltzmann constant.'}
#  - {'question': 'Analyzing the thermal transport in a clean UTe2 sample under a magnetic field \\( H \\) applied along the a axis, derive an expression for the field-dependent thermal conductivity coefficient, assuming a fully gapped Au state. Employ the concepts of magnetic flux quantization and superconducting pair-breaking.', 'answer': 'The thermal conductivity coefficient, \\( \\kappa(H) \\), as a function of an applied magnetic field, \\( H \\), in a UTe2 sample with a fully gapped Au state can be expressed as: \\( \\kappa(H) = \\kappa_0 \\left(1 - \\frac{(H/H_{c2})^2}{1 + (H/H_0)^2}\\right) \\), where \\( \\kappa_0 \\) is the zero-field thermal conductivity, \\( H_{c2} \\) is the upper critical field, and \\( H_0 \\) is a scaling field parameter related to pair-breaking processes.'}
#  - {'question': 'Investigate the effects of impurity scattering on the thermal conductivity of UTe2 in a disordered system with B3u symmetry. Using the relaxation time approximation, provide a symbolic expression of the modified thermal conductivity.', 'answer': 'The modified thermal conductivity \\( \\kappa_d \\) for disordered UTe2 with B3u symmetry can be expressed as \\( \\kappa_d = \\kappa_0 \\left(1 + \\frac{n_i v_F}{\\tau v_0} \\right)^{-1} \\), where \\( \\kappa_0 \\) is the clean limit thermal conductivity, \\( n_i \\) is the impurity concentration, \\( v_F \\) is the Fermi velocity, \\( \\tau \\) is the relaxation time, and \\( v_0 \\) is a characteristic velocity associated with the impurity potential.'}
#
# Sample 8:
# Topics: ['Properties and applications of monolayer 1T′-MoTe₂', 'Charge order and pair-density-wave (PDW) in topological materials', 'Interplay of electron correlation and topology']
# Key Concepts: ['Interband nesting between electron and hole pockets', 'Influence of interfacial disorder on superconductivity', 'Unidirectional or striped charge order (CO)']
# Reference Files: ['8.pdf', '2.pdf']
# Questions:
#  - {'question': "Consider a monolayer of 1T'-MoTe₂ with electronic band structure exhibiting interband nesting between electron and hole pockets. Derive the expression for the charge density wave vector Q_c associated with nesting if the Fermi surface comprises a hole pocket centered at the Γ point and electron pockets oriented along the k_y axis, given that the lattice constant along the Mo atom chains is b. Assume modulation corresponds to five times the lattice spacing.", 'solution': '\\mathbf{Q}_c = (0, 0.4)\\pi/b'}
#  - {'question': "For monolayer 1T'-MoTe₂, the superconducting transition temperature T_c is significantly enhanced in comparison to its bulk counterpart. Assuming two-gap superconductivity is influenced by electron correlations, compute the expression for the ratio of the larger superconducting gap ∆₂ to the smaller gap ∆₁, given that their average measured gap lengths are 1.27 meV and 1.91 meV, respectively.", 'solution': '\\frac{\\Delta_2}{\\Delta_1} = \\frac{1.91}{1.27}'}
#  - {'question': 'In a topological material exhibiting a pair-density-wave (PDW) with wavevector Q_P, the energy gap ∆_1 is spatially modulated and causes a particle-hole symmetric charge order with wavevector 2Q_P. If Q_P is approximated by (0, 0.4)π/b, determine the expression for the wavevector of the induced charge order.', 'solution': '\\mathbf{2Q}_P = (0, 0.8)\\pi/b'}
#  - {'question': "In a group of topological materials, achieving superconductivity is driven by interfacial disorder and correlations. Given a typical Cooper pair size related to coherence length ξ, show the coherence length expression in terms of the upper critical field B_c2 as ξ = √(Φ_0/(2πB_c2)), where Φ_0 is the magnetic flux quantum. Validate it using B_c2 = 4 T for monolayer 1T'-MoTe₂.", 'solution': '\\xi = \\sqrt{\\frac{\\Phi_0}{2\\pi B_{c2}}} \\approx 9.1 \\text{ nm}, \\; \\text{with } B_{c2} = 4 \\text{ T}'}
#  - {'question': 'Account for the enhancement of superconductivity in monolayer MoTe₂ compared to the bulk by considering the role of nesting behavior between its electron and hole pockets. Establish the condition involving the electron doping n_e that achieves the nesting wavevector Q_c = Q_P, which correlates to a fixed vector exchange, and evaluate its effect for n_e = 0.05e per unit cell.', 'solution': 'Condition: n_e gives \\mathbf{Q}_c = \\mathbf{Q}_P \\approx (0, 0.4)\\pi/b, \\text{ for } n_e = 0.05e'}
#
# Sample 9:
# Topics: ['High Order Perturbation', 'Numerical Algorithms']
# Key Concepts: ['Non-Hermitian Matrices', 'Scalable Algorithms', 'Puiseux Series', 'Multivariate Polynomial System']
# Reference Files: ['18.pdf', '2.pdf']
# Questions:
#  - ```json
# [
#     {
#         "question": "Consider a non-Hermitian matrix \( \mathbf{A}(\lambda, \nu) \) that depends on a complex parameter \( \nu \) and has eigenvalues expressed in terms of a Puiseux series near an exceptional point (EP). Using a third-order perturbation theory, derive the expression for the coefficient \( d_3 \) in the series \( \lambda(\nu) = \lambda^* + d_1 (\nu - \nu^*)^{1/2} + d_2 (\nu - \nu^*) + d_3 (\nu - \nu^*)^{3/2} + \ldots \). Assume \( \mathbf{A}(\lambda, \nu) \) is analytic around \( \nu = \nu^* \).",
#         "topics": "High Order Perturbation",
#         "key_concepts": ["Non-Hermitian Matrices", "Puiseux Series"],
#         "solution": "The coefficient \( d_3 \) can be derived by considering the third-order derivative of the characteristic polynomial associated with the matrix \( \mathbf{A}(\lambda, \nu) \) in the vicinity of the exceptional point \( (\lambda^*, \nu^*) \). The expression involves the third-order terms in the expansion of both the matrix and the perturbative correction subject to the conditions \( \partial_\lambda^2 P(\lambda^*, \nu^*) = 0 \) and \( \partial_\lambda^3 P(\lambda^*, \nu^*) \neq 0 \)."
#     },
#     {
#         "question": "Consider a numerical algorithm that solves for the eigenvalues of a large sparse non-Hermitian matrix using scalable iterative methods. For a given matrix \( \mathbf{B}(\nu_1, \nu_2) \) that depends on two independent parameters, derive the expression to compute the partial derivatives of selected eigenvalues up to second order using a bordered matrix approach. Assume \( \nu_1 = \nu_2 = 0 \) as a reference point.",
#         "topics": "Numerical Algorithms",
#         "key_concepts": ["Scalable Algorithms", "Multivariate Polynomial System"],
#         "solution": "The partial derivatives \( \partial_{\nu_1} \lambda \), \( \partial_{\nu_2} \lambda \), \( \partial^2_{\nu_1 \nu_2} \lambda \) can be computed using the bordered matrix \( \left[ \begin{array}{cc} \mathbf{B}(\lambda) \quad \partial_{\nu} \mathbf{B} \mathbf{x} \\ \mathbf{v}^T \quad 0 \end{array} \right] \) where \( \mathbf{v} \) is chosen such that \( \mathbf{v}^T \mathbf{x} = 1 \). The solved system yields the derivatives when the above subset condition is met, and the eigenvectors are normalized with this bordered matrix."
#     },
#     {
#         "question": "Given a multivariate polynomial system derived from the Taylor expansion of a Partial Characteristic Polynomial (PCP) for a matrix \( \mathbf{C}(\lambda, \nu) \), formulate the system of equations needed to locate high-order exceptional points (EPs) requiring multiple parameters. Use a truncation order \( D \) to second order expansions.",
#         "topics": "High Order Perturbation",
#         "key_concepts": ["Non-Hermitian Matrices", "Puiseux Series", "Multivariate Polynomial System"],
#         "solution": "To locate high-order EPs, set up a system of equations using the PCP expansions \( Q(\lambda, \nu) \approx \sum_{k\leq D} a_k(\nu) \lambda^k \). Each coefficient \( a_k(\nu) \) must satisfy the condition that its \( i \)-th total derivative (up to order \( N-1 \)) vanishes at the EP, i.e., \( \partial^{i}_\nu a_k(\lambda^*,\nu^*) = 0 \) for \( i=0,...,N-1 \)."
#     },
#     {
#         "question": "For a set of parametric eigenvalue problems, derive an expression for the perturbative correction of order \( n \) in the eigenvalue expansion using a Puiseux series under the assumption of symmetry breaking in the vicinity of an exceptional point in a non-Hermitian system.",
#         "topics": "High Order Perturbation",
#         "key_concepts": ["Puiseux Series", "Non-Hermitian Matrices"],
#         "solution": "The perturbative correction of order \( n \) in the eigenvalue expansion can be expressed as the coefficient of \( (\nu - \nu^*)^{n/2} \) in the Puiseux series \( \lambda(\nu) = \lambda^* + \sum_{k=1}^n d_k (\nu - \nu^*)^{k/2} \). This requires computing higher-order derivatives of the characteristic polynomial \( P(\lambda, \nu) \) and ensuring consistency with symmetry breaking constraints around \( \nu^* \)."
#     }
# ]
# ```
#
# Sample 10:
# Topics: ['Onsager and Kirkwood theories', 'Polarization dynamics']
# Key Concepts: ['Molecular dynamics simulations of polar fluids', 'Kirkwood-Fröhlich equation', 'Solvation free energy', 'Static dielectric constant', 'Debye relaxation']
# Reference Files: ['11.pdf', '2.pdf']
# Questions:
#  - {'question': 'Consider a polar fluid characterized by an orientational polarization \\( p_1 \\) and an induced polarization \\( p_2 \\), subject to an oscillating directing electric field \\( E_d \\) and Lorentz internal field \\( F \\). Given the Kirkwood-Fröhlich equation for the static dielectric constant \\( \\epsilon \\), derive an expression for \\( \\epsilon^* (\\omega) \\) in terms of \\( \\epsilon \\), \\( \\epsilon_\\infty \\), and the frequency-dependent parameters of the three relaxation times \\( \\tau_D \\), \\( \\tau_L \\), and \\( \\tau_f \\).', 'topics': ['Onsager and Kirkwood theories', 'Polarization dynamics'], 'key_concepts': ['Kirkwood-Fröhlich equation', 'Dielectric response', 'Relaxation times']}
#  - {'question': 'In a molecular dynamics simulation of a polar fluid confined between parallel conducting plates, derive an expression for the solvation free energy \\( F_s \\) as a functional of the orientational polarization \\( p_1 \\) and bare electric field \\( E_0 \\). Assume fixed potential boundary conditions and include the Lorentz term in the dielectric free energy.', 'topics': ['Onsager and Kirkwood theories'], 'key_concepts': ['Solvation free energy', 'Fixed-potential conditions', 'Lorentz term']}
#  - {'question': "Consider Onsager's theory for polar fluids with an orientational susceptibility \\( \\chi_1 \\) and induced susceptibility \\( \\chi_2 \\). Formulate the space-time correlation function of the total polarization \\( p = p_1 + p_2 \\) in terms of the static and dynamic dielectric constants \\( \\epsilon \\) and \\( \\epsilon_\\infty \\), using the wave number \\( q \\) and observation time \\( t \\). Assume \\( \\epsilon \\gg \\epsilon_\\infty \\).", 'topics': ['Onsager and Kirkwood theories', 'Polarization dynamics'], 'key_concepts': ['Molecular dynamics simulations', 'Dielectric response', 'Correlation functions']}
#  - {'question': 'In the context of Onsager and Kirkwood theories, derive the frequency-dependent surface dielectric length \\( \\ell^*(\\omega) \\) for a fluid confined between two metallic plates. Consider the dynamic effects of surface polarization \\( p_s \\) with a relaxation time \\( \\tau_s \\), and relate it to the static surface electric length \\( \\ell_w \\).', 'topics': ['Onsager and Kirkwood theories'], 'key_concepts': ['Dynamic surface polarization', 'Dielectric response', 'Relaxation times']}
#
# All outputs saved to directory: output_apple

# %% [markdown]
# ### download data from csv

# %%
import os
import argparse
import pandas as pd
import requests
from urllib.parse import urlparse, unquote

def download_files(
    csv_path="Researchpapers_PhD_Synthetic_Data - Physics.csv",
    output_dir="docs"
) -> None:
    """
    Reads a CSV with a 'Link' column and downloads each URL to output_dir,
    saving each file with a .pdf extension.
    """
    # Load CSV
    df = pd.read_csv(csv_path)
    if 'Link' not in df.columns:
        raise ValueError("CSV must contain a 'Link' column.")

    # Ensure output directory exists
    os.makedirs(output_dir, exist_ok=True)

    total = len(df['Link'].dropna())
    for idx, url in enumerate(df['Link'].dropna(), start=1):
        try:
            # Parse URL and derive a safe filename
            parsed = urlparse(url)
            raw_name = os.path.basename(parsed.path)
            raw_name = unquote(raw_name)  # decode URL-encoded characters

            if raw_name:
                name, ext = os.path.splitext(raw_name)
                # If there's no .pdf extension, force it
                filename = f"{idx}.pdf" if ext.lower() != '.pdf' else raw_name
            else:
                filename = f"{idx}.pdf"

            out_path = os.path.join(output_dir, filename)

            # Stream download
            with requests.get(url, stream=True) as r:
                r.raise_for_status()
                with open(out_path, 'wb') as f:
                    for chunk in r.iter_content(chunk_size=8192):
                        if chunk:
                            f.write(chunk)

            print(f"[{idx}/{total}] Downloaded → {filename}")

        except Exception as e:
            print(f"[{idx}/{total}] FAILED  → {url}\n    {e}")

if __name__ == "__main__":
    download_files()
# Out:
# [1/23] Downloaded → 1.pdf
# [2/23] Downloaded → 2.pdf
# [3/23] Downloaded → 3.pdf
# [4/23] Downloaded → 4.pdf
# [5/23] Downloaded → 5.pdf
# [6/23] Downloaded → 6.pdf
# [7/23] Downloaded → 7.pdf
# [8/23] Downloaded → 8.pdf
# [9/23] Downloaded → 9.pdf
# [10/23] Downloaded → 10.pdf
# [11/23] Downloaded → 11.pdf
# [12/23] Downloaded → 12.pdf
# [13/23] Downloaded → 13.pdf
# [14/23] Downloaded → 14.pdf
# [15/23] Downloaded → 15.pdf
# [16/23] Downloaded → 16.pdf
# [17/23] Downloaded → 17.pdf
# [18/23] Downloaded → 18.pdf
# [19/23] Downloaded → 19.pdf
# [20/23] Downloaded → 20.pdf
# [21/23] Downloaded → 21.pdf
# [22/23] FAILED  → https://arxiv.org/abs/2505.06432'
#     404 Client Error: Not Found for url: https://arxiv.org/abs/2505.06432'
# [23/23] Downloaded → 23.pdf

# %% [markdown]
# ## Author - Critique Model

# %%
import logging
from typing import List, Dict, Tuple

from langchain.chat_models import ChatOpenAI
from langchain.prompts import PromptTemplate, FewShotPromptTemplate
from langchain.chains import LLMChain

# Explicit logging configuration for console and file
logger = logging.getLogger()
logger.setLevel(logging.INFO)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

# File handler
file_handler = logging.FileHandler('conversation.log', mode='w')
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# Console handler
console_handler = logging.StreamHandler()
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

# -- Cost parameters (per-million tokens) --
# COST_PARAMS = {
#     "gpt-4o": {"input": 5.00, "cached_input":2.50, "output":20.00},
#     "o4-mini": {"input": 0.60, "cached_input":0.30, "output":2.40},
# }

# -- Tokenizer setup for all new chat models --
# ENC = tiktoken.get_encoding("cl100k_base")

def count_tokens(text: str) -> int:
    """Exact token count under cl100k_base."""
    # return len(ENC.encode(text))
    return 0

# def cost_for_call(
#     prompt_text: str,
#     completion_text: str,
#     model: str,
#     cached_input_tokens: int = 0
# ) -> Tuple[int, int, float]:
#     params = COST_PARAMS[model]
#     input_tokens  = count_tokens(prompt_text)
#     output_tokens = count_tokens(completion_text)
#     non_cached    = input_tokens - cached_input_tokens
#     cost = (
#         non_cached      / 1_000_000 * params["input"] +
#         output_tokens   / 1_000_000 * params["output"]
#     )
#     return input_tokens, output_tokens, cost


def author_critique_loop(
    topics: List[str],
    concepts: List[str],
    guidelines: str,
    few_shot_examples: List[Dict[str,str]],
    max_turns: int = 5,
) -> str:
    """
    Runs the author–critic loop and logs the conversation.
    Returns the final questions (str).
    """
    # Initialize LLMs
    author_model = "o4-mini"
    critic_model = "o3"
    author_llm = ChatOpenAI(model_name=author_model, temperature=1)
    critic_llm = ChatOpenAI(model_name=critic_model, temperature=1)

    # Build Few-Shot prompt for author
    example_prompt = PromptTemplate(
        input_variables=["example"],
        template="Example:\n{example}\n---"
    )
    author_fs_prompt = FewShotPromptTemplate(
        examples=few_shot_examples,
        example_prompt=example_prompt,
        prefix="You are a physics education specialist. Generate novel university-level physics questions. Here are some examples:",
        suffix=(
            "Now, based on the topics: {topics}, key concepts: {concepts}, "
            "and guidelines: {guidelines}, produce a set of new, high-quality physics questions."
        ),
        input_variables=["topics", "concepts", "guidelines"],
    )
    author_chain = LLMChain(llm=author_llm, prompt=author_fs_prompt)

    # Build Critic prompt
    critic_prompt = PromptTemplate(
        input_variables=["questions", "guidelines"],
        template=(
            "You are a physics assessment expert. Critique the following questions:\n"
            "{questions}\n"
            "Evaluate them against these guidelines:\n{guidelines}\n"
            "Provide concise, actionable feedback on how to improve."
        ),
    )
    critic_chain = LLMChain(llm=critic_llm, prompt=critic_prompt)

    questions = ""
    feedback  = ""

    for turn in range(max_turns):
        # ---- AUTHOR STEP ----
        if turn == 0:
            prompt_text = author_fs_prompt.format_prompt(
                topics=topics, concepts=concepts, guidelines=guidelines
            ).to_string()
            completion = author_chain.run(
                topics=topics, concepts=concepts, guidelines=guidelines
            )
            print("Suyash")
        else:
            refine_template = PromptTemplate(
                input_variables=["questions", "feedback"],
                template=(
                    "Refine these questions based on the feedback below:\n"
                    "Questions:\n{questions}\n"
                    "Feedback:\n{feedback}\n"
                    "Produce an improved set of physics questions following the original criteria."
                ),
            )
            prompt_text = refine_template.format(
                questions=questions, feedback=feedback
            )
            completion = LLMChain(llm=author_llm, prompt=refine_template).run(
                questions=questions, feedback=feedback
            )

        # Log author conversation
        logging.info(f"[Author turn {turn}] Prompt:\n{prompt_text}")
        logging.info(f"[Author turn {turn}] Response:\n{completion}")
        print("Hi")
        questions = completion

        # ---- CRITIC STEP ----
        prompt_text = critic_prompt.format(
            questions=questions, guidelines=guidelines
        )
        completion = critic_chain.run(
            questions=questions, guidelines=guidelines
        )
        # Log critic conversation
        logging.info(f"[Critic turn {turn}] Prompt:\n{prompt_text}")
        logging.info(f"[Critic turn {turn}] Response:\n{completion}")
        feedback = completion

    return questions


if __name__ == "__main__":
    # Example usage
    topics = [
        "Standard Model of Particle Physics",
        "Electroweak Symmetry Breaking",
        "Elementary Particles and Forces",
    ]
    concepts = [
        "Theories like the Seesaw Mechanism, Majorana Neutrinos, and Sterile Neutrinos address neutrino masses.",
        "Neutrino oscillations suggest nonzero masses, contradicting the Standard Model's massless assumption.",
        "Radiative corrections adjust particle masses at higher energy scales, posing a fine-tuning problem.",
        "Quantum Field Theory is foundational to the Standard Model, explaining fundamental forces excluding gravity.",
    ]
    guidelines = (
        "1. Model a Physical Scenario: Start from a real-world or idealized setup. "
        "2. Target a Solvable Quantity: Ask for a clear symbolic expression of a physical variable (e.g., tension, acceleration, energy). "
        "3. Force Multi-Step Reasoning: Ensure the question involves a sequence of physics laws, transformations, and derivations to reach the answer. "
        "4. Avoid Redundancy: Exclude extraneous details or variables that do not impact the final solution. "
        "5. Be Unique: Do not rephrase standard textbook problems; ensure originality and complexity. "
        "6. Single solution: Expect a single symbolic expression, unambiguous, presented in LaTeX. Multiple equivalent algebraic forms are allowed. No equations or floating-point approximations. "
        "7. Use rigorous, concise phrasing. "
        "8. Avoid colloquial or ambiguous terminology. "
        "9. Units must be consistent; symbols should follow standard notation."
    )
    few_shot_examples = [
        {"example": "Good: Imagine a scenario where a sea quark in a meson has negative gravitational charge. Develop an equation that relates the effective gravitational mass of this meson, M_g, to its rest mass, M_0, the gravitational charge of the sea quark, q_g, and the typical quark potential energy, U, under the assumption that the sea quark's contribution is repulsive."},
        {"example": "Bad: What is energy?"},
    ]

    final_questions = author_critique_loop(
        topics, concepts, guidelines, few_shot_examples, max_turns=4
    )
    print(f"Final Questions:\n{final_questions}\n")
    # save the final questions to a file
    with open("final_questions.txt", "w") as f:
        f.write(final_questions)
    logging.info("Author–Critique loop complete.")
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-22 13:18:33,452 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:root:[Author turn 0] Prompt:
# You are a physics education specialist. Generate novel university-level physics questions. Here are some examples:
#
# Example:
# Good: Imagine a scenario where a sea quark in a meson has negative gravitational charge. Develop an equation that relates the effective gravitational mass of this meson, M_g, to its rest mass, M_0, the gravitational charge of the sea quark, q_g, and the typical quark potential energy, U, under the assumption that the sea quark's contribution is repulsive.
# ---
#
# Example:
# Bad: What is energy?
# ---
#
# Now, based on the topics: ['Standard Model of Particle Physics', 'Electroweak Symmetry Breaking', 'Elementary Particles and Forces'], key concepts: ['Theories like the Seesaw Mechanism, Majorana Neutrinos, and Sterile Neutrinos address neutrino masses.', "Neutrino oscillations suggest nonzero masses, contradicting the Standard Model's massless assumption.", 'Radiative corrections adjust particle masses at higher energy scales, posing a fine-tuning problem.', 'Quantum Field Theory is foundational to the Standard Model, explaining fundamental forces excluding gravity.'], and guidelines: 1. Model a Physical Scenario: Start from a real-world or idealized setup. 2. Target a Solvable Quantity: Ask for a clear symbolic expression of a physical variable (e.g., tension, acceleration, energy). 3. Force Multi-Step Reasoning: Ensure the question involves a sequence of physics laws, transformations, and derivations to reach the answer. 4. Avoid Redundancy: Exclude extraneous details or variables that do not impact the final solution. 5. Be Unique: Do not rephrase standard textbook problems; ensure originality and complexity. 6. Single solution: Expect a single symbolic expression, unambiguous, presented in LaTeX. Multiple equivalent algebraic forms are allowed. No equations or floating-point approximations. 7. Use rigorous, concise phrasing. 8. Avoid colloquial or ambiguous terminology. 9. Units must be consistent; symbols should follow standard notation., produce a set of new, high-quality physics questions.
# 2025-05-22 13:18:33,456 - INFO - [Author turn 0] Prompt:
# You are a physics education specialist. Generate novel university-level physics questions. Here are some examples:
#
# Example:
# Good: Imagine a scenario where a sea quark in a meson has negative gravitational charge. Develop an equation that relates the effective gravitational mass of this meson, M_g, to its rest mass, M_0, the gravitational charge of the sea quark, q_g, and the typical quark potential energy, U, under the assumption that the sea quark's contribution is repulsive.
# ---
#
# Example:
# Bad: What is energy?
# ---
#
# Now, based on the topics: ['Standard Model of Particle Physics', 'Electroweak Symmetry Breaking', 'Elementary Particles and Forces'], key concepts: ['Theories like the Seesaw Mechanism, Majorana Neutrinos, and Sterile Neutrinos address neutrino masses.', "Neutrino oscillations suggest nonzero masses, contradicting the Standard Model's massless assumption.", 'Radiative corrections adjust particle masses at higher energy scales, posing a fine-tuning problem.', 'Quantum Field Theory is foundational to the Standard Model, explaining fundamental forces excluding gravity.'], and guidelines: 1. Model a Physical Scenario: Start from a real-world or idealized setup. 2. Target a Solvable Quantity: Ask for a clear symbolic expression of a physical variable (e.g., tension, acceleration, energy). 3. Force Multi-Step Reasoning: Ensure the question involves a sequence of physics laws, transformations, and derivations to reach the answer. 4. Avoid Redundancy: Exclude extraneous details or variables that do not impact the final solution. 5. Be Unique: Do not rephrase standard textbook problems; ensure originality and complexity. 6. Single solution: Expect a single symbolic expression, unambiguous, presented in LaTeX. Multiple equivalent algebraic forms are allowed. No equations or floating-point approximations. 7. Use rigorous, concise phrasing. 8. Avoid colloquial or ambiguous terminology. 9. Units must be consistent; symbols should follow standard notation., produce a set of new, high-quality physics questions.
# INFO:root:[Author turn 0] Response:
# Below is a set of five novel, university‐level problems. Each models an idealized scenario, targets a clear symbolic result, and requires multi‐step reasoning (e.g. diagonalization, perturbation theory, renormalization). Answers should be given as single, unambiguous symbolic expressions in LaTeX.
#
# 1. Seesaw + One‐Loop Correction
#    Scenario: A single‐generation neutrino obtains mass via a Type-I seesaw with Dirac mass \(m_D\) and heavy Majorana mass \(M_R\). A one‐loop Higgs–neutrino diagram with Yukawa coupling \(y\) and UV cutoff \(\Lambda\gg M_R\) induces an additive mass correction
#    \[
#      \delta m_\nu \;=\; \frac{y^2}{16\pi^2}\,M_R\ln\!\Bigl(\tfrac{\Lambda}{M_R}\Bigr).
#    \]
#    Derive the corrected light neutrino mass \(m_\nu\) in terms of \(m_D,\;M_R,\;y,\;\Lambda\).
#
# 2. MSW Effective Mixing Angle
#    Scenario: A two‐flavor beam \((\nu_e,\nu_\mu)\) of energy \(E\) traverses constant‐density matter with electron potential \(V_e\). Vacuum parameters are mixing angle \(\theta\) and mass‐squared difference \(\Delta m^2\).
#    Derive an expression for the effective in‐matter mixing angle \(\theta_m\) satisfying
#    \[
#      \sin2\theta_m \;=\; \frac{\sin2\theta}{\sqrt{\bigl(\cos2\theta - \tfrac{2EV_e}{\Delta m^2}\bigr)^2 + \sin^2 2\theta}}\,.
#    \]
#
# 3. Higgs Mass Fine‐Tuning from Top‐Quark Loop
#    Scenario: In the Standard Model, the dominant one‐loop top‐quark contribution to the Higgs mass parameter is
#    \[
#      \delta m_H^2 \;=\; -\,\frac{|y_t|^2}{8\pi^2}\,\Lambda^2,
#    \]
#    where \(y_t\) is the top Yukawa and \(\Lambda\) the UV cutoff. Define the fine‐tuning measure
#    \(\Delta \equiv \bigl|\delta m_H^2/m_H^2\bigr|\).
#    Express \(\Delta\) in terms of \(\,y_t,\;\Lambda,\;m_H\).
#
# 4. 3+1 Sterile Neutrino Survival Probability
#    Scenario: A neutrino flavor state \(\nu_e\) is a mixture of three active and one sterile mass eigenstate. In the short‐baseline limit (neglecting small active–active splittings), only the largest \(\Delta m^2_{41}\) and mixing element \(U_{e4}\) matter. Distance \(L\), energy \(E\).
#    Derive the electron‐neutrino survival probability \(P_{ee}(L)\) in terms of \(|U_{e4}|^2,\;\Delta m^2_{41},\;L,\;E\).
#
# 5. One‐Loop Running of a Neutrino Yukawa
#    Scenario: A heavy Majorana neutrino couples to the Higgs via Yukawa \(y(\mu)\). Its one‐loop beta function in the SM gauge‐Yukawa sector is
#    \(\beta(y)\equiv \dfrac{d\,y}{d\ln\mu} = a\,y^3\),
#    with constant \(a\). Given \(y(\mu_0)\) at scale \(\mu_0\), find \(y(\mu)\) for \(\mu>\mu_0\).
#
# Each problem expects a final symbolic result in LaTeX form.
# 2025-05-22 13:18:33,458 - INFO - [Author turn 0] Response:
# Below is a set of five novel, university‐level problems. Each models an idealized scenario, targets a clear symbolic result, and requires multi‐step reasoning (e.g. diagonalization, perturbation theory, renormalization). Answers should be given as single, unambiguous symbolic expressions in LaTeX.
#
# 1. Seesaw + One‐Loop Correction
#    Scenario: A single‐generation neutrino obtains mass via a Type-I seesaw with Dirac mass \(m_D\) and heavy Majorana mass \(M_R\). A one‐loop Higgs–neutrino diagram with Yukawa coupling \(y\) and UV cutoff \(\Lambda\gg M_R\) induces an additive mass correction
#    \[
#      \delta m_\nu \;=\; \frac{y^2}{16\pi^2}\,M_R\ln\!\Bigl(\tfrac{\Lambda}{M_R}\Bigr).
#    \]
#    Derive the corrected light neutrino mass \(m_\nu\) in terms of \(m_D,\;M_R,\;y,\;\Lambda\).
#
# 2. MSW Effective Mixing Angle
#    Scenario: A two‐flavor beam \((\nu_e,\nu_\mu)\) of energy \(E\) traverses constant‐density matter with electron potential \(V_e\). Vacuum parameters are mixing angle \(\theta\) and mass‐squared difference \(\Delta m^2\).
#    Derive an expression for the effective in‐matter mixing angle \(\theta_m\) satisfying
#    \[
#      \sin2\theta_m \;=\; \frac{\sin2\theta}{\sqrt{\bigl(\cos2\theta - \tfrac{2EV_e}{\Delta m^2}\bigr)^2 + \sin^2 2\theta}}\,.
#    \]
#
# 3. Higgs Mass Fine‐Tuning from Top‐Quark Loop
#    Scenario: In the Standard Model, the dominant one‐loop top‐quark contribution to the Higgs mass parameter is
#    \[
#      \delta m_H^2 \;=\; -\,\frac{|y_t|^2}{8\pi^2}\,\Lambda^2,
#    \]
#    where \(y_t\) is the top Yukawa and \(\Lambda\) the UV cutoff. Define the fine‐tuning measure
#    \(\Delta \equiv \bigl|\delta m_H^2/m_H^2\bigr|\).
#    Express \(\Delta\) in terms of \(\,y_t,\;\Lambda,\;m_H\).
#
# 4. 3+1 Sterile Neutrino Survival Probability
#    Scenario: A neutrino flavor state \(\nu_e\) is a mixture of three active and one sterile mass eigenstate. In the short‐baseline limit (neglecting small active–active splittings), only the largest \(\Delta m^2_{41}\) and mixing element \(U_{e4}\) matter. Distance \(L\), energy \(E\).
#    Derive the electron‐neutrino survival probability \(P_{ee}(L)\) in terms of \(|U_{e4}|^2,\;\Delta m^2_{41},\;L,\;E\).
#
# 5. One‐Loop Running of a Neutrino Yukawa
#    Scenario: A heavy Majorana neutrino couples to the Higgs via Yukawa \(y(\mu)\). Its one‐loop beta function in the SM gauge‐Yukawa sector is
#    \(\beta(y)\equiv \dfrac{d\,y}{d\ln\mu} = a\,y^3\),
#    with constant \(a\). Given \(y(\mu_0)\) at scale \(\mu_0\), find \(y(\mu)\) for \(\mu>\mu_0\).
#
# Each problem expects a final symbolic result in LaTeX form.
# Suyash
# Hi
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-22 13:18:51,773 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:root:[Critic turn 0] Prompt:
# You are a physics assessment expert. Critique the following questions:
# Below is a set of five novel, university‐level problems. Each models an idealized scenario, targets a clear symbolic result, and requires multi‐step reasoning (e.g. diagonalization, perturbation theory, renormalization). Answers should be given as single, unambiguous symbolic expressions in LaTeX.
#
# 1. Seesaw + One‐Loop Correction
#    Scenario: A single‐generation neutrino obtains mass via a Type-I seesaw with Dirac mass \(m_D\) and heavy Majorana mass \(M_R\). A one‐loop Higgs–neutrino diagram with Yukawa coupling \(y\) and UV cutoff \(\Lambda\gg M_R\) induces an additive mass correction
#    \[
#      \delta m_\nu \;=\; \frac{y^2}{16\pi^2}\,M_R\ln\!\Bigl(\tfrac{\Lambda}{M_R}\Bigr).
#    \]
#    Derive the corrected light neutrino mass \(m_\nu\) in terms of \(m_D,\;M_R,\;y,\;\Lambda\).
#
# 2. MSW Effective Mixing Angle
#    Scenario: A two‐flavor beam \((\nu_e,\nu_\mu)\) of energy \(E\) traverses constant‐density matter with electron potential \(V_e\). Vacuum parameters are mixing angle \(\theta\) and mass‐squared difference \(\Delta m^2\).
#    Derive an expression for the effective in‐matter mixing angle \(\theta_m\) satisfying
#    \[
#      \sin2\theta_m \;=\; \frac{\sin2\theta}{\sqrt{\bigl(\cos2\theta - \tfrac{2EV_e}{\Delta m^2}\bigr)^2 + \sin^2 2\theta}}\,.
#    \]
#
# 3. Higgs Mass Fine‐Tuning from Top‐Quark Loop
#    Scenario: In the Standard Model, the dominant one‐loop top‐quark contribution to the Higgs mass parameter is
#    \[
#      \delta m_H^2 \;=\; -\,\frac{|y_t|^2}{8\pi^2}\,\Lambda^2,
#    \]
#    where \(y_t\) is the top Yukawa and \(\Lambda\) the UV cutoff. Define the fine‐tuning measure
#    \(\Delta \equiv \bigl|\delta m_H^2/m_H^2\bigr|\).
#    Express \(\Delta\) in terms of \(\,y_t,\;\Lambda,\;m_H\).
#
# 4. 3+1 Sterile Neutrino Survival Probability
#    Scenario: A neutrino flavor state \(\nu_e\) is a mixture of three active and one sterile mass eigenstate. In the short‐baseline limit (neglecting small active–active splittings), only the largest \(\Delta m^2_{41}\) and mixing element \(U_{e4}\) matter. Distance \(L\), energy \(E\).
#    Derive the electron‐neutrino survival probability \(P_{ee}(L)\) in terms of \(|U_{e4}|^2,\;\Delta m^2_{41},\;L,\;E\).
#
# 5. One‐Loop Running of a Neutrino Yukawa
#    Scenario: A heavy Majorana neutrino couples to the Higgs via Yukawa \(y(\mu)\). Its one‐loop beta function in the SM gauge‐Yukawa sector is
#    \(\beta(y)\equiv \dfrac{d\,y}{d\ln\mu} = a\,y^3\),
#    with constant \(a\). Given \(y(\mu_0)\) at scale \(\mu_0\), find \(y(\mu)\) for \(\mu>\mu_0\).
#
# Each problem expects a final symbolic result in LaTeX form.
# Evaluate them against these guidelines:
# 1. Model a Physical Scenario: Start from a real-world or idealized setup. 2. Target a Solvable Quantity: Ask for a clear symbolic expression of a physical variable (e.g., tension, acceleration, energy). 3. Force Multi-Step Reasoning: Ensure the question involves a sequence of physics laws, transformations, and derivations to reach the answer. 4. Avoid Redundancy: Exclude extraneous details or variables that do not impact the final solution. 5. Be Unique: Do not rephrase standard textbook problems; ensure originality and complexity. 6. Single solution: Expect a single symbolic expression, unambiguous, presented in LaTeX. Multiple equivalent algebraic forms are allowed. No equations or floating-point approximations. 7. Use rigorous, concise phrasing. 8. Avoid colloquial or ambiguous terminology. 9. Units must be consistent; symbols should follow standard notation.
# Provide concise, actionable feedback on how to improve.
# 2025-05-22 13:18:51,779 - INFO - [Critic turn 0] Prompt:
# You are a physics assessment expert. Critique the following questions:
# Below is a set of five novel, university‐level problems. Each models an idealized scenario, targets a clear symbolic result, and requires multi‐step reasoning (e.g. diagonalization, perturbation theory, renormalization). Answers should be given as single, unambiguous symbolic expressions in LaTeX.
#
# 1. Seesaw + One‐Loop Correction
#    Scenario: A single‐generation neutrino obtains mass via a Type-I seesaw with Dirac mass \(m_D\) and heavy Majorana mass \(M_R\). A one‐loop Higgs–neutrino diagram with Yukawa coupling \(y\) and UV cutoff \(\Lambda\gg M_R\) induces an additive mass correction
#    \[
#      \delta m_\nu \;=\; \frac{y^2}{16\pi^2}\,M_R\ln\!\Bigl(\tfrac{\Lambda}{M_R}\Bigr).
#    \]
#    Derive the corrected light neutrino mass \(m_\nu\) in terms of \(m_D,\;M_R,\;y,\;\Lambda\).
#
# 2. MSW Effective Mixing Angle
#    Scenario: A two‐flavor beam \((\nu_e,\nu_\mu)\) of energy \(E\) traverses constant‐density matter with electron potential \(V_e\). Vacuum parameters are mixing angle \(\theta\) and mass‐squared difference \(\Delta m^2\).
#    Derive an expression for the effective in‐matter mixing angle \(\theta_m\) satisfying
#    \[
#      \sin2\theta_m \;=\; \frac{\sin2\theta}{\sqrt{\bigl(\cos2\theta - \tfrac{2EV_e}{\Delta m^2}\bigr)^2 + \sin^2 2\theta}}\,.
#    \]
#
# 3. Higgs Mass Fine‐Tuning from Top‐Quark Loop
#    Scenario: In the Standard Model, the dominant one‐loop top‐quark contribution to the Higgs mass parameter is
#    \[
#      \delta m_H^2 \;=\; -\,\frac{|y_t|^2}{8\pi^2}\,\Lambda^2,
#    \]
#    where \(y_t\) is the top Yukawa and \(\Lambda\) the UV cutoff. Define the fine‐tuning measure
#    \(\Delta \equiv \bigl|\delta m_H^2/m_H^2\bigr|\).
#    Express \(\Delta\) in terms of \(\,y_t,\;\Lambda,\;m_H\).
#
# 4. 3+1 Sterile Neutrino Survival Probability
#    Scenario: A neutrino flavor state \(\nu_e\) is a mixture of three active and one sterile mass eigenstate. In the short‐baseline limit (neglecting small active–active splittings), only the largest \(\Delta m^2_{41}\) and mixing element \(U_{e4}\) matter. Distance \(L\), energy \(E\).
#    Derive the electron‐neutrino survival probability \(P_{ee}(L)\) in terms of \(|U_{e4}|^2,\;\Delta m^2_{41},\;L,\;E\).
#
# 5. One‐Loop Running of a Neutrino Yukawa
#    Scenario: A heavy Majorana neutrino couples to the Higgs via Yukawa \(y(\mu)\). Its one‐loop beta function in the SM gauge‐Yukawa sector is
#    \(\beta(y)\equiv \dfrac{d\,y}{d\ln\mu} = a\,y^3\),
#    with constant \(a\). Given \(y(\mu_0)\) at scale \(\mu_0\), find \(y(\mu)\) for \(\mu>\mu_0\).
#
# Each problem expects a final symbolic result in LaTeX form.
# Evaluate them against these guidelines:
# 1. Model a Physical Scenario: Start from a real-world or idealized setup. 2. Target a Solvable Quantity: Ask for a clear symbolic expression of a physical variable (e.g., tension, acceleration, energy). 3. Force Multi-Step Reasoning: Ensure the question involves a sequence of physics laws, transformations, and derivations to reach the answer. 4. Avoid Redundancy: Exclude extraneous details or variables that do not impact the final solution. 5. Be Unique: Do not rephrase standard textbook problems; ensure originality and complexity. 6. Single solution: Expect a single symbolic expression, unambiguous, presented in LaTeX. Multiple equivalent algebraic forms are allowed. No equations or floating-point approximations. 7. Use rigorous, concise phrasing. 8. Avoid colloquial or ambiguous terminology. 9. Units must be consistent; symbols should follow standard notation.
# Provide concise, actionable feedback on how to improve.
# INFO:root:[Critic turn 0] Response:
# Overall remarks
# • All five prompts reference topical, graduate-level subjects (seesaw, MSW, fine–tuning, sterile neutrinos, RGE running) and request symbolic answers, which is positive.
# • However, most of the tasks are solved in only one or two algebraic lines, so they do not actually “force multi-step reasoning” as required.
# • Several questions merely ask the student to reproduce a formula already written in the stem, which defeats the purpose of derivation and reduces originality.
# • A few superfluous words and parameters appear, and some wording could be tightened.
#
# Detailed critique and suggestions
#
# 1. Seesaw + One-Loop Correction
#    • Weak multi-step load: once the Type-I seesaw result \(m_\nu^{(0)}=-m_D^{2}/M_R\) is quoted, the student only adds the given \(\delta m_\nu\).
#    • The real diagonalisation that yields the tree-level seesaw term is not requested.
#    • Actionable fix: ask for the full diagonalisation of the \((\nu_L, N_R)\) mass matrix, then include the one-loop self-energy and perform a perturbative re-diagonalisation. Remove the explicit final formula for \(\delta m_\nu\) from the stem; give only the Feynman diagram description and constants. This forces block-diagonalisation + loop calculation (multi-step).
#
# 2. MSW Effective Mixing Angle
#    • The exact expression to be “derived” is already printed in the question, so the student can simply cite it.
#    • Actionable fix: supply only the Hamiltonian and ask for the eigenvectors/eigenvalues, then ask for \(\sin2\theta_{m}\) in terms of the variables; omit the boxed answer from the prompt.
#
# 3. Higgs Mass Fine-Tuning from Top-Quark Loop
#    • A single division yields \(\Delta = |y_t|^{2}\Lambda^{2}/(8\pi^{2}m_H^{2})\); no physics reasoning beyond reading the stem.
#    • Actionable fix: embed this in a broader naturalness exercise (e.g. include gauge and scalar loops, ask for combined \(\delta m_H^{2}\), then evaluate \(\Delta\) and discuss its dependence on renormalisation scheme).
#
# 4. 3+1 Sterile Neutrino Survival Probability
#    • Only two-flavor-like survival formula: \(P_{ee}=1-4|U_{e4}|^{2}(1-|U_{e4}|^{2})\sin^{2}(\tfrac{\Delta m^{2}_{41}L}{4E})\). This is a one-line derivation once the student recalls the general two-state result.
#    • Actionable fix: start from the full \(4\times4\) mixing matrix, require the student to construct the approximate evolution operator in the short-baseline limit, then extract \(P_{ee}\). Possibly include matter effects or CP phases to raise complexity.
#
# 5. One-Loop Running of a Neutrino Yukawa
#    • Acceptable level of mathematical work (separable ODE integration), though still modest.
#    • Minor phrasing: specify that \(a>0\) and constant, and that perturbativity holds.
#    • Could be strengthened by letting \(a\) depend on gauge couplings that themselves run, so the student must couple RGEs.
#
# Style and redundancy
# • Delete remarks like “Answers should be given…” from inside the problems; that belongs in overall instructions, not each stem.
# • Remove informal words (“kind of”, “dominant one-loop”).
# • Ensure symbols used in the final answer all appear in the prompt; e.g. for Problem 1 explicitly define the tree-level light mass before referencing it.
#
# Uniqueness
# • All five questions are standard textbook or review-article formulas. Add twists (non-degenerate heavy states, finite-temperature MSW, two-loop corrections, etc.) to achieve novelty.
#
# Units and notation
# • Units are consistent and standard notation is used; no corrections needed here.
#
# Summary of improvements
# 1. Omit given final formulas; let students derive them.
# 2. Expand each scenario so that at least three substantive physics steps (diagonalisation, perturbation, integration, limiting cases) are required.
# 3. Trim instructional boilerplate from individual stems; use concise, formal language.
# 4. Introduce unique twists (e.g. non-trivial potentials, multiple heavy states, running gauge couplings) to move beyond textbook replicas.
# 2025-05-22 13:18:51,780 - INFO - [Critic turn 0] Response:
# Overall remarks
# • All five prompts reference topical, graduate-level subjects (seesaw, MSW, fine–tuning, sterile neutrinos, RGE running) and request symbolic answers, which is positive.
# • However, most of the tasks are solved in only one or two algebraic lines, so they do not actually “force multi-step reasoning” as required.
# • Several questions merely ask the student to reproduce a formula already written in the stem, which defeats the purpose of derivation and reduces originality.
# • A few superfluous words and parameters appear, and some wording could be tightened.
#
# Detailed critique and suggestions
#
# 1. Seesaw + One-Loop Correction
#    • Weak multi-step load: once the Type-I seesaw result \(m_\nu^{(0)}=-m_D^{2}/M_R\) is quoted, the student only adds the given \(\delta m_\nu\).
#    • The real diagonalisation that yields the tree-level seesaw term is not requested.
#    • Actionable fix: ask for the full diagonalisation of the \((\nu_L, N_R)\) mass matrix, then include the one-loop self-energy and perform a perturbative re-diagonalisation. Remove the explicit final formula for \(\delta m_\nu\) from the stem; give only the Feynman diagram description and constants. This forces block-diagonalisation + loop calculation (multi-step).
#
# 2. MSW Effective Mixing Angle
#    • The exact expression to be “derived” is already printed in the question, so the student can simply cite it.
#    • Actionable fix: supply only the Hamiltonian and ask for the eigenvectors/eigenvalues, then ask for \(\sin2\theta_{m}\) in terms of the variables; omit the boxed answer from the prompt.
#
# 3. Higgs Mass Fine-Tuning from Top-Quark Loop
#    • A single division yields \(\Delta = |y_t|^{2}\Lambda^{2}/(8\pi^{2}m_H^{2})\); no physics reasoning beyond reading the stem.
#    • Actionable fix: embed this in a broader naturalness exercise (e.g. include gauge and scalar loops, ask for combined \(\delta m_H^{2}\), then evaluate \(\Delta\) and discuss its dependence on renormalisation scheme).
#
# 4. 3+1 Sterile Neutrino Survival Probability
#    • Only two-flavor-like survival formula: \(P_{ee}=1-4|U_{e4}|^{2}(1-|U_{e4}|^{2})\sin^{2}(\tfrac{\Delta m^{2}_{41}L}{4E})\). This is a one-line derivation once the student recalls the general two-state result.
#    • Actionable fix: start from the full \(4\times4\) mixing matrix, require the student to construct the approximate evolution operator in the short-baseline limit, then extract \(P_{ee}\). Possibly include matter effects or CP phases to raise complexity.
#
# 5. One-Loop Running of a Neutrino Yukawa
#    • Acceptable level of mathematical work (separable ODE integration), though still modest.
#    • Minor phrasing: specify that \(a>0\) and constant, and that perturbativity holds.
#    • Could be strengthened by letting \(a\) depend on gauge couplings that themselves run, so the student must couple RGEs.
#
# Style and redundancy
# • Delete remarks like “Answers should be given…” from inside the problems; that belongs in overall instructions, not each stem.
# • Remove informal words (“kind of”, “dominant one-loop”).
# • Ensure symbols used in the final answer all appear in the prompt; e.g. for Problem 1 explicitly define the tree-level light mass before referencing it.
#
# Uniqueness
# • All five questions are standard textbook or review-article formulas. Add twists (non-degenerate heavy states, finite-temperature MSW, two-loop corrections, etc.) to achieve novelty.
#
# Units and notation
# • Units are consistent and standard notation is used; no corrections needed here.
#
# Summary of improvements
# 1. Omit given final formulas; let students derive them.
# 2. Expand each scenario so that at least three substantive physics steps (diagonalisation, perturbation, integration, limiting cases) are required.
# 3. Trim instructional boilerplate from individual stems; use concise, formal language.
# 4. Introduce unique twists (e.g. non-trivial potentials, multiple heavy states, running gauge couplings) to move beyond textbook replicas.
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-22 13:19:13,384 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:root:[Author turn 1] Prompt:
# Refine these questions based on the feedback below:
# Questions:
# Below is a set of five novel, university‐level problems. Each models an idealized scenario, targets a clear symbolic result, and requires multi‐step reasoning (e.g. diagonalization, perturbation theory, renormalization). Answers should be given as single, unambiguous symbolic expressions in LaTeX.
#
# 1. Seesaw + One‐Loop Correction
#    Scenario: A single‐generation neutrino obtains mass via a Type-I seesaw with Dirac mass \(m_D\) and heavy Majorana mass \(M_R\). A one‐loop Higgs–neutrino diagram with Yukawa coupling \(y\) and UV cutoff \(\Lambda\gg M_R\) induces an additive mass correction
#    \[
#      \delta m_\nu \;=\; \frac{y^2}{16\pi^2}\,M_R\ln\!\Bigl(\tfrac{\Lambda}{M_R}\Bigr).
#    \]
#    Derive the corrected light neutrino mass \(m_\nu\) in terms of \(m_D,\;M_R,\;y,\;\Lambda\).
#
# 2. MSW Effective Mixing Angle
#    Scenario: A two‐flavor beam \((\nu_e,\nu_\mu)\) of energy \(E\) traverses constant‐density matter with electron potential \(V_e\). Vacuum parameters are mixing angle \(\theta\) and mass‐squared difference \(\Delta m^2\).
#    Derive an expression for the effective in‐matter mixing angle \(\theta_m\) satisfying
#    \[
#      \sin2\theta_m \;=\; \frac{\sin2\theta}{\sqrt{\bigl(\cos2\theta - \tfrac{2EV_e}{\Delta m^2}\bigr)^2 + \sin^2 2\theta}}\,.
#    \]
#
# 3. Higgs Mass Fine‐Tuning from Top‐Quark Loop
#    Scenario: In the Standard Model, the dominant one‐loop top‐quark contribution to the Higgs mass parameter is
#    \[
#      \delta m_H^2 \;=\; -\,\frac{|y_t|^2}{8\pi^2}\,\Lambda^2,
#    \]
#    where \(y_t\) is the top Yukawa and \(\Lambda\) the UV cutoff. Define the fine‐tuning measure
#    \(\Delta \equiv \bigl|\delta m_H^2/m_H^2\bigr|\).
#    Express \(\Delta\) in terms of \(\,y_t,\;\Lambda,\;m_H\).
#
# 4. 3+1 Sterile Neutrino Survival Probability
#    Scenario: A neutrino flavor state \(\nu_e\) is a mixture of three active and one sterile mass eigenstate. In the short‐baseline limit (neglecting small active–active splittings), only the largest \(\Delta m^2_{41}\) and mixing element \(U_{e4}\) matter. Distance \(L\), energy \(E\).
#    Derive the electron‐neutrino survival probability \(P_{ee}(L)\) in terms of \(|U_{e4}|^2,\;\Delta m^2_{41},\;L,\;E\).
#
# 5. One‐Loop Running of a Neutrino Yukawa
#    Scenario: A heavy Majorana neutrino couples to the Higgs via Yukawa \(y(\mu)\). Its one‐loop beta function in the SM gauge‐Yukawa sector is
#    \(\beta(y)\equiv \dfrac{d\,y}{d\ln\mu} = a\,y^3\),
#    with constant \(a\). Given \(y(\mu_0)\) at scale \(\mu_0\), find \(y(\mu)\) for \(\mu>\mu_0\).
#
# Each problem expects a final symbolic result in LaTeX form.
# Feedback:
# Overall remarks
# • All five prompts reference topical, graduate-level subjects (seesaw, MSW, fine–tuning, sterile neutrinos, RGE running) and request symbolic answers, which is positive.
# • However, most of the tasks are solved in only one or two algebraic lines, so they do not actually “force multi-step reasoning” as required.
# • Several questions merely ask the student to reproduce a formula already written in the stem, which defeats the purpose of derivation and reduces originality.
# • A few superfluous words and parameters appear, and some wording could be tightened.
#
# Detailed critique and suggestions
#
# 1. Seesaw + One-Loop Correction
#    • Weak multi-step load: once the Type-I seesaw result \(m_\nu^{(0)}=-m_D^{2}/M_R\) is quoted, the student only adds the given \(\delta m_\nu\).
#    • The real diagonalisation that yields the tree-level seesaw term is not requested.
#    • Actionable fix: ask for the full diagonalisation of the \((\nu_L, N_R)\) mass matrix, then include the one-loop self-energy and perform a perturbative re-diagonalisation. Remove the explicit final formula for \(\delta m_\nu\) from the stem; give only the Feynman diagram description and constants. This forces block-diagonalisation + loop calculation (multi-step).
#
# 2. MSW Effective Mixing Angle
#    • The exact expression to be “derived” is already printed in the question, so the student can simply cite it.
#    • Actionable fix: supply only the Hamiltonian and ask for the eigenvectors/eigenvalues, then ask for \(\sin2\theta_{m}\) in terms of the variables; omit the boxed answer from the prompt.
#
# 3. Higgs Mass Fine-Tuning from Top-Quark Loop
#    • A single division yields \(\Delta = |y_t|^{2}\Lambda^{2}/(8\pi^{2}m_H^{2})\); no physics reasoning beyond reading the stem.
#    • Actionable fix: embed this in a broader naturalness exercise (e.g. include gauge and scalar loops, ask for combined \(\delta m_H^{2}\), then evaluate \(\Delta\) and discuss its dependence on renormalisation scheme).
#
# 4. 3+1 Sterile Neutrino Survival Probability
#    • Only two-flavor-like survival formula: \(P_{ee}=1-4|U_{e4}|^{2}(1-|U_{e4}|^{2})\sin^{2}(\tfrac{\Delta m^{2}_{41}L}{4E})\). This is a one-line derivation once the student recalls the general two-state result.
#    • Actionable fix: start from the full \(4\times4\) mixing matrix, require the student to construct the approximate evolution operator in the short-baseline limit, then extract \(P_{ee}\). Possibly include matter effects or CP phases to raise complexity.
#
# 5. One-Loop Running of a Neutrino Yukawa
#    • Acceptable level of mathematical work (separable ODE integration), though still modest.
#    • Minor phrasing: specify that \(a>0\) and constant, and that perturbativity holds.
#    • Could be strengthened by letting \(a\) depend on gauge couplings that themselves run, so the student must couple RGEs.
#
# Style and redundancy
# • Delete remarks like “Answers should be given…” from inside the problems; that belongs in overall instructions, not each stem.
# • Remove informal words (“kind of”, “dominant one-loop”).
# • Ensure symbols used in the final answer all appear in the prompt; e.g. for Problem 1 explicitly define the tree-level light mass before referencing it.
#
# Uniqueness
# • All five questions are standard textbook or review-article formulas. Add twists (non-degenerate heavy states, finite-temperature MSW, two-loop corrections, etc.) to achieve novelty.
#
# Units and notation
# • Units are consistent and standard notation is used; no corrections needed here.
#
# Summary of improvements
# 1. Omit given final formulas; let students derive them.
# 2. Expand each scenario so that at least three substantive physics steps (diagonalisation, perturbation, integration, limiting cases) are required.
# 3. Trim instructional boilerplate from individual stems; use concise, formal language.
# 4. Introduce unique twists (e.g. non-trivial potentials, multiple heavy states, running gauge couplings) to move beyond textbook replicas.
# Produce an improved set of physics questions following the original criteria.
# 2025-05-22 13:19:13,387 - INFO - [Author turn 1] Prompt:
# Refine these questions based on the feedback below:
# Questions:
# Below is a set of five novel, university‐level problems. Each models an idealized scenario, targets a clear symbolic result, and requires multi‐step reasoning (e.g. diagonalization, perturbation theory, renormalization). Answers should be given as single, unambiguous symbolic expressions in LaTeX.
#
# 1. Seesaw + One‐Loop Correction
#    Scenario: A single‐generation neutrino obtains mass via a Type-I seesaw with Dirac mass \(m_D\) and heavy Majorana mass \(M_R\). A one‐loop Higgs–neutrino diagram with Yukawa coupling \(y\) and UV cutoff \(\Lambda\gg M_R\) induces an additive mass correction
#    \[
#      \delta m_\nu \;=\; \frac{y^2}{16\pi^2}\,M_R\ln\!\Bigl(\tfrac{\Lambda}{M_R}\Bigr).
#    \]
#    Derive the corrected light neutrino mass \(m_\nu\) in terms of \(m_D,\;M_R,\;y,\;\Lambda\).
#
# 2. MSW Effective Mixing Angle
#    Scenario: A two‐flavor beam \((\nu_e,\nu_\mu)\) of energy \(E\) traverses constant‐density matter with electron potential \(V_e\). Vacuum parameters are mixing angle \(\theta\) and mass‐squared difference \(\Delta m^2\).
#    Derive an expression for the effective in‐matter mixing angle \(\theta_m\) satisfying
#    \[
#      \sin2\theta_m \;=\; \frac{\sin2\theta}{\sqrt{\bigl(\cos2\theta - \tfrac{2EV_e}{\Delta m^2}\bigr)^2 + \sin^2 2\theta}}\,.
#    \]
#
# 3. Higgs Mass Fine‐Tuning from Top‐Quark Loop
#    Scenario: In the Standard Model, the dominant one‐loop top‐quark contribution to the Higgs mass parameter is
#    \[
#      \delta m_H^2 \;=\; -\,\frac{|y_t|^2}{8\pi^2}\,\Lambda^2,
#    \]
#    where \(y_t\) is the top Yukawa and \(\Lambda\) the UV cutoff. Define the fine‐tuning measure
#    \(\Delta \equiv \bigl|\delta m_H^2/m_H^2\bigr|\).
#    Express \(\Delta\) in terms of \(\,y_t,\;\Lambda,\;m_H\).
#
# 4. 3+1 Sterile Neutrino Survival Probability
#    Scenario: A neutrino flavor state \(\nu_e\) is a mixture of three active and one sterile mass eigenstate. In the short‐baseline limit (neglecting small active–active splittings), only the largest \(\Delta m^2_{41}\) and mixing element \(U_{e4}\) matter. Distance \(L\), energy \(E\).
#    Derive the electron‐neutrino survival probability \(P_{ee}(L)\) in terms of \(|U_{e4}|^2,\;\Delta m^2_{41},\;L,\;E\).
#
# 5. One‐Loop Running of a Neutrino Yukawa
#    Scenario: A heavy Majorana neutrino couples to the Higgs via Yukawa \(y(\mu)\). Its one‐loop beta function in the SM gauge‐Yukawa sector is
#    \(\beta(y)\equiv \dfrac{d\,y}{d\ln\mu} = a\,y^3\),
#    with constant \(a\). Given \(y(\mu_0)\) at scale \(\mu_0\), find \(y(\mu)\) for \(\mu>\mu_0\).
#
# Each problem expects a final symbolic result in LaTeX form.
# Feedback:
# Overall remarks
# • All five prompts reference topical, graduate-level subjects (seesaw, MSW, fine–tuning, sterile neutrinos, RGE running) and request symbolic answers, which is positive.
# • However, most of the tasks are solved in only one or two algebraic lines, so they do not actually “force multi-step reasoning” as required.
# • Several questions merely ask the student to reproduce a formula already written in the stem, which defeats the purpose of derivation and reduces originality.
# • A few superfluous words and parameters appear, and some wording could be tightened.
#
# Detailed critique and suggestions
#
# 1. Seesaw + One-Loop Correction
#    • Weak multi-step load: once the Type-I seesaw result \(m_\nu^{(0)}=-m_D^{2}/M_R\) is quoted, the student only adds the given \(\delta m_\nu\).
#    • The real diagonalisation that yields the tree-level seesaw term is not requested.
#    • Actionable fix: ask for the full diagonalisation of the \((\nu_L, N_R)\) mass matrix, then include the one-loop self-energy and perform a perturbative re-diagonalisation. Remove the explicit final formula for \(\delta m_\nu\) from the stem; give only the Feynman diagram description and constants. This forces block-diagonalisation + loop calculation (multi-step).
#
# 2. MSW Effective Mixing Angle
#    • The exact expression to be “derived” is already printed in the question, so the student can simply cite it.
#    • Actionable fix: supply only the Hamiltonian and ask for the eigenvectors/eigenvalues, then ask for \(\sin2\theta_{m}\) in terms of the variables; omit the boxed answer from the prompt.
#
# 3. Higgs Mass Fine-Tuning from Top-Quark Loop
#    • A single division yields \(\Delta = |y_t|^{2}\Lambda^{2}/(8\pi^{2}m_H^{2})\); no physics reasoning beyond reading the stem.
#    • Actionable fix: embed this in a broader naturalness exercise (e.g. include gauge and scalar loops, ask for combined \(\delta m_H^{2}\), then evaluate \(\Delta\) and discuss its dependence on renormalisation scheme).
#
# 4. 3+1 Sterile Neutrino Survival Probability
#    • Only two-flavor-like survival formula: \(P_{ee}=1-4|U_{e4}|^{2}(1-|U_{e4}|^{2})\sin^{2}(\tfrac{\Delta m^{2}_{41}L}{4E})\). This is a one-line derivation once the student recalls the general two-state result.
#    • Actionable fix: start from the full \(4\times4\) mixing matrix, require the student to construct the approximate evolution operator in the short-baseline limit, then extract \(P_{ee}\). Possibly include matter effects or CP phases to raise complexity.
#
# 5. One-Loop Running of a Neutrino Yukawa
#    • Acceptable level of mathematical work (separable ODE integration), though still modest.
#    • Minor phrasing: specify that \(a>0\) and constant, and that perturbativity holds.
#    • Could be strengthened by letting \(a\) depend on gauge couplings that themselves run, so the student must couple RGEs.
#
# Style and redundancy
# • Delete remarks like “Answers should be given…” from inside the problems; that belongs in overall instructions, not each stem.
# • Remove informal words (“kind of”, “dominant one-loop”).
# • Ensure symbols used in the final answer all appear in the prompt; e.g. for Problem 1 explicitly define the tree-level light mass before referencing it.
#
# Uniqueness
# • All five questions are standard textbook or review-article formulas. Add twists (non-degenerate heavy states, finite-temperature MSW, two-loop corrections, etc.) to achieve novelty.
#
# Units and notation
# • Units are consistent and standard notation is used; no corrections needed here.
#
# Summary of improvements
# 1. Omit given final formulas; let students derive them.
# 2. Expand each scenario so that at least three substantive physics steps (diagonalisation, perturbation, integration, limiting cases) are required.
# 3. Trim instructional boilerplate from individual stems; use concise, formal language.
# 4. Introduce unique twists (e.g. non-trivial potentials, multiple heavy states, running gauge couplings) to move beyond textbook replicas.
# Produce an improved set of physics questions following the original criteria.
# INFO:root:[Author turn 1] Response:
# Below are five refined, graduate-level problems. Each requires at least three substantive steps (e.g. matrix diagonalization, perturbation theory, coupled ODE integration) and culminates in a single, unambiguous symbolic result in LaTeX.
#
# 1. Type-I Seesaw plus One-Loop Self-Energy
#    Consider the two‐state neutrino mass matrix in the basis \((\nu_L,N_R^c)\),
#      \(M=\begin{pmatrix}0 & m_D\\ m_D & M_R\end{pmatrix},\)
#    with \(M_R\gg m_D\).
#    (a) Diagonalize \(M\) at tree level via a unitary rotation to obtain the leading light mass \(m_\nu^{(0)}\).
#    (b) A one-loop Higgs–neutrino self-energy yields \(\Sigma(p)\approx(y^2/16\pi^2)\,p\ln(\Lambda/p)\). Evaluate \(\Sigma\) at \(p=M_R\), then perform a first-order perturbative re-diagonalization of \(M+\Sigma\) to find the corrected light eigenvalue \(m_\nu\).
#
# 2. MSW Mixing Angle from Hamiltonian Diagonalization
#    A two‐flavor neutrino beam of energy \(E\) propagates through constant‐density matter with electron potential \(V_e\).  In the flavor basis the effective Hamiltonian is
#      \(H = \frac{\Delta m^2}{4E}\bigl(-\cos2\theta\,\sigma_3+\sin2\theta\,\sigma_1\bigr)+\frac{V_e}{2}\,\sigma_3.\)
#    (a) Find the eigenvalues of \(H\).
#    (b) Determine the rotation angle \(\theta_m\) that diagonalizes \(H\) and derive expressions for
#      \(\sin2\theta_m\)  and  \(\cos2\theta_m\)
#    in terms of \(\theta,\;\Delta m^2,\;E,\;V_e\).
#
# 3. Higgs Mass Naturalness with Multiple Loops
#    In the SM, the one-loop corrections to the Higgs mass parameter are
#      \(\delta m_H^2|_t = -\frac{3|y_t|^2}{8\pi^2}\,\Lambda^2,\)
#      \(\delta m_H^2|_V = +\frac{9g^2+3g'^2}{64\pi^2}\,\Lambda^2.\)
#    Define the fine‐tuning measure \(\Delta_i\equiv|\delta m_H^2|_i/m_H^2\) and the total
#      \(\Delta_{\rm tot}=\bigl|\delta m_H^2|_t+\delta m_H^2|_V\bigr|/m_H^2.\)
#    (a) Compute \(\Delta_t,\;\Delta_V\).
#    (b) Combine them to write \(\Delta_{\rm tot}\) as a single symbolic expression in \(y_t,\;g,\;g',\;\Lambda,\;m_H\).
#
# 4. Electron-Neutrino Survival in a 3+1 System
#    A 4×4 mixing matrix \(U\) relates flavor states \(\nu_\alpha\) to mass eigenstates \(\nu_i\).  In the short-baseline limit (\(L/E\) such that only \(\Delta m^2_{41}\) induces oscillations), show by
#    (i) writing the amplitude \(A_{ee}=\sum_i U_{e i}e^{-i m_i^2L/2E}U^*_{e i}\),
#    (ii) neglecting \(\Delta m^2_{21},\Delta m^2_{31}\),
#    that the survival probability
#      \(P_{ee}(L)=|A_{ee}|^2\)
#    reduces to
#      \(P_{ee}=1-4|U_{e4}|^2\bigl(1-|U_{e4}|^2\bigr)\sin^2\!\bigl(\tfrac{\Delta m^2_{41}L}{4E}\bigr).\)
#
# 5. Coupled One-Loop RGEs for a Neutrino Yukawa
#    The SM gauge and Yukawa couplings obey to one loop:
#      \(\dfrac{dy}{dt}=a\,y^3+d\,y\,g^2,\quad \dfrac{dg}{dt}=-b\,g^3,\)
#    where \(t=\ln\mu\) and \(a,b,d\) are constants.  Given boundary values \(y(\mu_0)=y_0,\;g(\mu_0)=g_0\),
#    (a) solve the gauge RGE to obtain \(g(\mu)\).
#    (b) substitute \(g(\mu)\) into the \(y\)–equation and integrate to find \(y(\mu)\) for \(\mu>\mu_0\).
#
# Each answer should be presented as a single LaTeX expression for the final result.
# 2025-05-22 13:19:13,389 - INFO - [Author turn 1] Response:
# Below are five refined, graduate-level problems. Each requires at least three substantive steps (e.g. matrix diagonalization, perturbation theory, coupled ODE integration) and culminates in a single, unambiguous symbolic result in LaTeX.
#
# 1. Type-I Seesaw plus One-Loop Self-Energy
#    Consider the two‐state neutrino mass matrix in the basis \((\nu_L,N_R^c)\),
#      \(M=\begin{pmatrix}0 & m_D\\ m_D & M_R\end{pmatrix},\)
#    with \(M_R\gg m_D\).
#    (a) Diagonalize \(M\) at tree level via a unitary rotation to obtain the leading light mass \(m_\nu^{(0)}\).
#    (b) A one-loop Higgs–neutrino self-energy yields \(\Sigma(p)\approx(y^2/16\pi^2)\,p\ln(\Lambda/p)\). Evaluate \(\Sigma\) at \(p=M_R\), then perform a first-order perturbative re-diagonalization of \(M+\Sigma\) to find the corrected light eigenvalue \(m_\nu\).
#
# 2. MSW Mixing Angle from Hamiltonian Diagonalization
#    A two‐flavor neutrino beam of energy \(E\) propagates through constant‐density matter with electron potential \(V_e\).  In the flavor basis the effective Hamiltonian is
#      \(H = \frac{\Delta m^2}{4E}\bigl(-\cos2\theta\,\sigma_3+\sin2\theta\,\sigma_1\bigr)+\frac{V_e}{2}\,\sigma_3.\)
#    (a) Find the eigenvalues of \(H\).
#    (b) Determine the rotation angle \(\theta_m\) that diagonalizes \(H\) and derive expressions for
#      \(\sin2\theta_m\)  and  \(\cos2\theta_m\)
#    in terms of \(\theta,\;\Delta m^2,\;E,\;V_e\).
#
# 3. Higgs Mass Naturalness with Multiple Loops
#    In the SM, the one-loop corrections to the Higgs mass parameter are
#      \(\delta m_H^2|_t = -\frac{3|y_t|^2}{8\pi^2}\,\Lambda^2,\)
#      \(\delta m_H^2|_V = +\frac{9g^2+3g'^2}{64\pi^2}\,\Lambda^2.\)
#    Define the fine‐tuning measure \(\Delta_i\equiv|\delta m_H^2|_i/m_H^2\) and the total
#      \(\Delta_{\rm tot}=\bigl|\delta m_H^2|_t+\delta m_H^2|_V\bigr|/m_H^2.\)
#    (a) Compute \(\Delta_t,\;\Delta_V\).
#    (b) Combine them to write \(\Delta_{\rm tot}\) as a single symbolic expression in \(y_t,\;g,\;g',\;\Lambda,\;m_H\).
#
# 4. Electron-Neutrino Survival in a 3+1 System
#    A 4×4 mixing matrix \(U\) relates flavor states \(\nu_\alpha\) to mass eigenstates \(\nu_i\).  In the short-baseline limit (\(L/E\) such that only \(\Delta m^2_{41}\) induces oscillations), show by
#    (i) writing the amplitude \(A_{ee}=\sum_i U_{e i}e^{-i m_i^2L/2E}U^*_{e i}\),
#    (ii) neglecting \(\Delta m^2_{21},\Delta m^2_{31}\),
#    that the survival probability
#      \(P_{ee}(L)=|A_{ee}|^2\)
#    reduces to
#      \(P_{ee}=1-4|U_{e4}|^2\bigl(1-|U_{e4}|^2\bigr)\sin^2\!\bigl(\tfrac{\Delta m^2_{41}L}{4E}\bigr).\)
#
# 5. Coupled One-Loop RGEs for a Neutrino Yukawa
#    The SM gauge and Yukawa couplings obey to one loop:
#      \(\dfrac{dy}{dt}=a\,y^3+d\,y\,g^2,\quad \dfrac{dg}{dt}=-b\,g^3,\)
#    where \(t=\ln\mu\) and \(a,b,d\) are constants.  Given boundary values \(y(\mu_0)=y_0,\;g(\mu_0)=g_0\),
#    (a) solve the gauge RGE to obtain \(g(\mu)\).
#    (b) substitute \(g(\mu)\) into the \(y\)–equation and integrate to find \(y(\mu)\) for \(\mu>\mu_0\).
#
# Each answer should be presented as a single LaTeX expression for the final result.
# Hi
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-22 13:19:38,485 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:root:[Critic turn 1] Prompt:
# You are a physics assessment expert. Critique the following questions:
# Below are five refined, graduate-level problems. Each requires at least three substantive steps (e.g. matrix diagonalization, perturbation theory, coupled ODE integration) and culminates in a single, unambiguous symbolic result in LaTeX.
#
# 1. Type-I Seesaw plus One-Loop Self-Energy
#    Consider the two‐state neutrino mass matrix in the basis \((\nu_L,N_R^c)\),
#      \(M=\begin{pmatrix}0 & m_D\\ m_D & M_R\end{pmatrix},\)
#    with \(M_R\gg m_D\).
#    (a) Diagonalize \(M\) at tree level via a unitary rotation to obtain the leading light mass \(m_\nu^{(0)}\).
#    (b) A one-loop Higgs–neutrino self-energy yields \(\Sigma(p)\approx(y^2/16\pi^2)\,p\ln(\Lambda/p)\). Evaluate \(\Sigma\) at \(p=M_R\), then perform a first-order perturbative re-diagonalization of \(M+\Sigma\) to find the corrected light eigenvalue \(m_\nu\).
#
# 2. MSW Mixing Angle from Hamiltonian Diagonalization
#    A two‐flavor neutrino beam of energy \(E\) propagates through constant‐density matter with electron potential \(V_e\).  In the flavor basis the effective Hamiltonian is
#      \(H = \frac{\Delta m^2}{4E}\bigl(-\cos2\theta\,\sigma_3+\sin2\theta\,\sigma_1\bigr)+\frac{V_e}{2}\,\sigma_3.\)
#    (a) Find the eigenvalues of \(H\).
#    (b) Determine the rotation angle \(\theta_m\) that diagonalizes \(H\) and derive expressions for
#      \(\sin2\theta_m\)  and  \(\cos2\theta_m\)
#    in terms of \(\theta,\;\Delta m^2,\;E,\;V_e\).
#
# 3. Higgs Mass Naturalness with Multiple Loops
#    In the SM, the one-loop corrections to the Higgs mass parameter are
#      \(\delta m_H^2|_t = -\frac{3|y_t|^2}{8\pi^2}\,\Lambda^2,\)
#      \(\delta m_H^2|_V = +\frac{9g^2+3g'^2}{64\pi^2}\,\Lambda^2.\)
#    Define the fine‐tuning measure \(\Delta_i\equiv|\delta m_H^2|_i/m_H^2\) and the total
#      \(\Delta_{\rm tot}=\bigl|\delta m_H^2|_t+\delta m_H^2|_V\bigr|/m_H^2.\)
#    (a) Compute \(\Delta_t,\;\Delta_V\).
#    (b) Combine them to write \(\Delta_{\rm tot}\) as a single symbolic expression in \(y_t,\;g,\;g',\;\Lambda,\;m_H\).
#
# 4. Electron-Neutrino Survival in a 3+1 System
# ...
# Provide concise, actionable feedback on how to improve.
# 2025-05-22 13:21:15,538 - INFO - [Critic turn 3] Prompt:
# You are a physics assessment expert. Critique the following questions:
# 1. One-Loop–Corrected Seesaw Neutrino Mass
# Given the $2\times2$ Majorana mass matrix
# \[
# M=\begin{pmatrix}0 & m_D\\ m_D & M_R\end{pmatrix},\qquad M_R\gg m_D,
# \]
# and the one-loop self-energy
# \[
# \Sigma=\Sigma_h(p^2=M_R^2)+\Sigma_W(p^2=M_R^2),\qquad \Sigma\ll M_R,
# \]
# whose tree-level light eigenvalue is $m_D^2/M_R$, find the one-loop–corrected light neutrino mass eigenvalue $m_\nu$ to first order in $\Sigma$.
# Provide
# \[
# m_\nu=\dots
# \]
# as a single LaTeX expression in terms of $m_D$, $M_R$, and $\Sigma\,$.
#
# 2. Matter Mixing Angle with Non-Standard Neutral-Current Interaction
# The two-flavor Hamiltonian in matter is
# \[
# H=\frac{\Delta}{2}\bigl(-\cos2\theta\,\sigma_3+\sin2\theta\,\sigma_1\bigr)
# +\frac{V_e}{2}(1+\epsilon)\,\sigma_3,
# \]
# with $\Delta\equiv\Delta m^2/(2E)$, $V_e$ the standard matter potential, and $|\epsilon|\ll1$. Diagonalize $H$ to obtain the mixing angle $\theta_m$.
# Provide
# \[
# \tan2\theta_m=\dots
# \]
# as a single LaTeX expression in terms of $\theta$, $\Delta$, $V_e$, and $\epsilon\,$.
#
# 3. Cutoff Scale from One- and Two-Loop Higgs Mass Corrections
# The Higgs mass corrections are
# \[
# \delta m_H^2{}^{(1)}=-\frac{3\,y_t^2}{8\pi^2}\,\Lambda^2,\qquad
# \delta m_H^2{}^{(2)}=\frac{C\,g_s^2\,y_t^2}{16\pi^4}\,\Lambda^2,
# \]
# with real positive $y_t$, $g_s$ and $C=\mathcal O(1)$. Define the fine-tuning measure
# \[
# \Delta=\frac{\bigl|\delta m_H^2{}^{(1)}+\delta m_H^2{}^{(2)}\bigr|}{m_H^2}\le\Delta_{\max}.
# \]
# Solve for the maximal cutoff $\Lambda_{\max}$.
# Provide
# \[
# \Lambda_{\max}=\dots
# \]
# as a single LaTeX expression in terms of $y_t$, $g_s$, $m_H$, $C$, and $\Delta_{\max}\,$.
#
# 4. Short-Baseline Appearance in a 3+1 Model with a CP Phase
# Neglecting $\Delta m^2_{21},\Delta m^2_{31}$ and standard CP phases, the 3+1 appearance probability is
# \[
# P_{\mu e}(L)=\biggl|\sum_{i=1}^4U_{\mu i}U^*_{e i}\,e^{-i\,m_i^2L/(2E)}\biggr|^2,
# \]
# with $|U_{e4}U_{\mu4}|\ll1$ and a CP phase $\delta_{14}\in(-\pi,\pi]$. Expand $P_{\mu e}(L)$ to leading order in $|U_{e4}U_{\mu4}|$.
# Provide
# \[
# P_{\mu e}(L)\approx\dots
# \]
# as a single LaTeX expression in terms of $|U_{e4}U_{\mu4}|$, $\delta_{14}$, $\Delta m^2_{41}$, $L$, and $E\,$.
#
# 5. Closed-Form Solution of Coupled One-Loop RGEs
# The RGEs are
# \[
# \frac{dy}{dt}=a\,y^3+d\,y\,g^2,\quad
# \frac{dg}{dt}=-b\,g^3,
# \]
# with $t=\ln\mu$, $y(0)=y_0$, $g(0)=g_0$, and $a,b,d>0$. Eliminate $g(t)$, integrate, and express $y(t)$ in closed form.
# Provide
# \[
# y(t)=\dots
# \]
# in terms of $t$, $y_0$, $g_0$, $a$, $b$, and $d$ (Lambert $W$ allowed).
# Evaluate them against these guidelines:
# 1. Model a Physical Scenario: Start from a real-world or idealized setup. 2. Target a Solvable Quantity: Ask for a clear symbolic expression of a physical variable (e.g., tension, acceleration, energy). 3. Force Multi-Step Reasoning: Ensure the question involves a sequence of physics laws, transformations, and derivations to reach the answer. 4. Avoid Redundancy: Exclude extraneous details or variables that do not impact the final solution. 5. Be Unique: Do not rephrase standard textbook problems; ensure originality and complexity. 6. Single solution: Expect a single symbolic expression, unambiguous, presented in LaTeX. Multiple equivalent algebraic forms are allowed. No equations or floating-point approximations. 7. Use rigorous, concise phrasing. 8. Avoid colloquial or ambiguous terminology. 9. Units must be consistent; symbols should follow standard notation.
# Provide concise, actionable feedback on how to improve.
# INFO:root:[Critic turn 3] Response:
# Overall remarks
# • All five items satisfy the spirit of “graduate-level, multi–step, symbolic” problems and already avoid numerical evaluation.
# • The main weaknesses are:
#   – some superfluous symbols or wording that never enter the requested final expression;
#   – occasional ambiguity about expansion order, sign conventions, or the domain of parameters;
#   – missing reminders about units or about which parameters are treated as real.
# • Below is itemised feedback mapped to the nine guidelines.
#
# ────────────────────────────────────────
# Problem 1  (one–loop seesaw mass)
#
# + G1, G2, G3: Realistic seesaw set-up, clearly asks for the corrected light eigenvalue.
# – G4: The separate labels “Σ_h” and “Σ_W” never re-appear; only their sum Σ matters.
# – G6: “to first order in Σ” is fine, but you should say “retain terms up to 𝒪(Σ)” to remove any doubt.
# – G9: Add “Σ has the dimension of mass” so units are explicit.
#
# Actionable fixes
# • Remove “Σ_h(p^2=M_R^2)+Σ_W(p^2=M_R^2)” and introduce a single symbol Σ.
# • Append “… keep terms linear in Σ” to avoid any ambiguity.
# • State “m_D, M_R, Σ are real and positive” for clarity.
#
# ────────────────────────────────────────
# Problem 2  (mixing angle with NSI)
#
# + G1–G3: Well–defined flavour Hamiltonian; diagonalisation requires several algebraic steps.
# – G4: The symbol Δ is defined once, but the reader still must carry “Δm², E” although they cancel in the requested ratio; you can simply call the frequency “Δ”.
# – G6: Ask explicitly for “a single LaTeX formula for tan 2θ_m”.
# – G8: “Diagonalise H” is fine, but be explicit that θ_m is defined through H’s eigenbasis so the sign convention matches the usual one.
#
# Actionable fixes
# • Delete “Δ≡Δm²/(2E)” or rewrite the Hamiltonian directly with Δ.
# • Add the sentence “Retain only terms linear in ε (|ε|≪1).”
#
# ────────────────────────────────────────
# Problem 3  (Higgs cut-off)
#
# + G1, G2, G5: Original fine-tuning criterion mixing one- and two-loop pieces.
# – G3: Solving |δ¹+δ²|≤Δ_max m_H² requires taking a square root; indicate whether C>0 so the sign of δ² is fixed.
# – G6: Because of the absolute value, two algebraically distinct Λ_max branches exist; specify you want the larger root.
# – G4: The sentence “with real positive y_t, g_s and C=𝒪(1)” is partially redundant—leave only “C>0”.
#
# Actionable fixes
# • Replace the absolute value by “Assume δ¹ and δ² have opposite sign and partially cancel; keep the magnitude.”
# • State “Give the largest Λ that satisfies the inequality.”
#
# ────────────────────────────────────────
# Problem 4  (3+1 appearance probability)
#
# + G1, G2, G3: Short-baseline 3+1 oscillation with a new CP phase is current-research relevant.
# – G4: The sum over i=1⋯4 still contains U_{μ1}U_{e1} etc., but these cancel after setting Δm²_21,31→0; spell this out so the student knows those terms drop.
# – G6: “Expand to leading order in |U_{e4}U_{μ4}|” should be sharpened to “keep terms ∝|U_{e4}U_{μ4}| and neglect (|U_{e4}U_{μ4}|)²”.
# – G8: Make the phase convention explicit, e.g. “δ₁₄ is attached to U_{e4}”.
#
# Actionable fixes
# • State explicitly “Set U_{e1}U_{μ1}+U_{e2}U_{μ2}+U_{e3}U_{μ3}=0 by unitarity.”
# • Clarify which sine-squared argument appears in the final answer so units stay intact.
#
# ────────────────────────────────────────
# Problem 5  (coupled RGEs)
#
# + G2, G3: Requires eliminating g(t), integrating, inverting to Lambert-W.
# – G1: No physical context is given. Supply a brief statement such as “Consider a Yukawa y and a gauge coupling g in a generic BSM model.”
# – G6: Re-emphasise that the final answer must be a single closed form expression, Lambert-W allowed.
# – G9: Mention that t=ln μ is dimensionless so units are consistent.
#
# Actionable fixes
# • Add one introductory line giving a concrete (even if idealised) model context.
# • Add “Provide y(t) for 0≤t<∞ where the solution remains perturbative.”
#
# ────────────────────────────────────────
# Global suggestions
#
# 1. Always strip variables that never affect the requested quantity (Guideline 4).
# 2. Spell out exactly which terms in a perturbative expansion must be kept (order counting).
# 3. State all sign, reality and small-parameter assumptions so the solution is unique.
# 4. Precede purely mathematical systems (Problem 5) with at least one sentence linking them to a physical scenario (Guideline 1).
# 5. Finish each prompt with “Give only the final LaTeX expression, no intermediate steps.” to reinforce Guideline 6.
# 2025-05-22 13:21:15,538 - INFO - [Critic turn 3] Response:
# Overall remarks
# • All five items satisfy the spirit of “graduate-level, multi–step, symbolic” problems and already avoid numerical evaluation.
# • The main weaknesses are:
#   – some superfluous symbols or wording that never enter the requested final expression;
#   – occasional ambiguity about expansion order, sign conventions, or the domain of parameters;
#   – missing reminders about units or about which parameters are treated as real.
# • Below is itemised feedback mapped to the nine guidelines.
#
# ────────────────────────────────────────
# Problem 1  (one–loop seesaw mass)
#
# + G1, G2, G3: Realistic seesaw set-up, clearly asks for the corrected light eigenvalue.
# – G4: The separate labels “Σ_h” and “Σ_W” never re-appear; only their sum Σ matters.
# – G6: “to first order in Σ” is fine, but you should say “retain terms up to 𝒪(Σ)” to remove any doubt.
# – G9: Add “Σ has the dimension of mass” so units are explicit.
#
# Actionable fixes
# • Remove “Σ_h(p^2=M_R^2)+Σ_W(p^2=M_R^2)” and introduce a single symbol Σ.
# • Append “… keep terms linear in Σ” to avoid any ambiguity.
# • State “m_D, M_R, Σ are real and positive” for clarity.
#
# ────────────────────────────────────────
# Problem 2  (mixing angle with NSI)
#
# + G1–G3: Well–defined flavour Hamiltonian; diagonalisation requires several algebraic steps.
# – G4: The symbol Δ is defined once, but the reader still must carry “Δm², E” although they cancel in the requested ratio; you can simply call the frequency “Δ”.
# – G6: Ask explicitly for “a single LaTeX formula for tan 2θ_m”.
# – G8: “Diagonalise H” is fine, but be explicit that θ_m is defined through H’s eigenbasis so the sign convention matches the usual one.
#
# Actionable fixes
# • Delete “Δ≡Δm²/(2E)” or rewrite the Hamiltonian directly with Δ.
# • Add the sentence “Retain only terms linear in ε (|ε|≪1).”
#
# ────────────────────────────────────────
# Problem 3  (Higgs cut-off)
#
# + G1, G2, G5: Original fine-tuning criterion mixing one- and two-loop pieces.
# – G3: Solving |δ¹+δ²|≤Δ_max m_H² requires taking a square root; indicate whether C>0 so the sign of δ² is fixed.
# – G6: Because of the absolute value, two algebraically distinct Λ_max branches exist; specify you want the larger root.
# – G4: The sentence “with real positive y_t, g_s and C=𝒪(1)” is partially redundant—leave only “C>0”.
#
# Actionable fixes
# • Replace the absolute value by “Assume δ¹ and δ² have opposite sign and partially cancel; keep the magnitude.”
# • State “Give the largest Λ that satisfies the inequality.”
#
# ────────────────────────────────────────
# Problem 4  (3+1 appearance probability)
#
# + G1, G2, G3: Short-baseline 3+1 oscillation with a new CP phase is current-research relevant.
# – G4: The sum over i=1⋯4 still contains U_{μ1}U_{e1} etc., but these cancel after setting Δm²_21,31→0; spell this out so the student knows those terms drop.
# – G6: “Expand to leading order in |U_{e4}U_{μ4}|” should be sharpened to “keep terms ∝|U_{e4}U_{μ4}| and neglect (|U_{e4}U_{μ4}|)²”.
# – G8: Make the phase convention explicit, e.g. “δ₁₄ is attached to U_{e4}”.
#
# Actionable fixes
# • State explicitly “Set U_{e1}U_{μ1}+U_{e2}U_{μ2}+U_{e3}U_{μ3}=0 by unitarity.”
# • Clarify which sine-squared argument appears in the final answer so units stay intact.
#
# ────────────────────────────────────────
# Problem 5  (coupled RGEs)
#
# + G2, G3: Requires eliminating g(t), integrating, inverting to Lambert-W.
# – G1: No physical context is given. Supply a brief statement such as “Consider a Yukawa y and a gauge coupling g in a generic BSM model.”
# – G6: Re-emphasise that the final answer must be a single closed form expression, Lambert-W allowed.
# – G9: Mention that t=ln μ is dimensionless so units are consistent.
#
# Actionable fixes
# • Add one introductory line giving a concrete (even if idealised) model context.
# • Add “Provide y(t) for 0≤t<∞ where the solution remains perturbative.”
#
# ────────────────────────────────────────
# Global suggestions
#
# 1. Always strip variables that never affect the requested quantity (Guideline 4).
# 2. Spell out exactly which terms in a perturbative expansion must be kept (order counting).
# 3. State all sign, reality and small-parameter assumptions so the solution is unique.
# 4. Precede purely mathematical systems (Problem 5) with at least one sentence linking them to a physical scenario (Guideline 1).
# 5. Finish each prompt with “Give only the final LaTeX expression, no intermediate steps.” to reinforce Guideline 6.
# INFO:root:Author–Critique loop complete.
# 2025-05-22 13:21:15,540 - INFO - Author–Critique loop complete.
# Final Questions:
# 1. One-Loop–Corrected Seesaw Neutrino Mass
# Given the $2\times2$ Majorana mass matrix
# \[
# M=\begin{pmatrix}0 & m_D\\ m_D & M_R\end{pmatrix},\qquad M_R\gg m_D,
# \]
# and the one-loop self-energy
# \[
# \Sigma=\Sigma_h(p^2=M_R^2)+\Sigma_W(p^2=M_R^2),\qquad \Sigma\ll M_R,
# \]
# whose tree-level light eigenvalue is $m_D^2/M_R$, find the one-loop–corrected light neutrino mass eigenvalue $m_\nu$ to first order in $\Sigma$.
# Provide
# \[
# m_\nu=\dots
# \]
# as a single LaTeX expression in terms of $m_D$, $M_R$, and $\Sigma\,$.
#
# 2. Matter Mixing Angle with Non-Standard Neutral-Current Interaction
# The two-flavor Hamiltonian in matter is
# \[
# H=\frac{\Delta}{2}\bigl(-\cos2\theta\,\sigma_3+\sin2\theta\,\sigma_1\bigr)
# +\frac{V_e}{2}(1+\epsilon)\,\sigma_3,
# \]
# with $\Delta\equiv\Delta m^2/(2E)$, $V_e$ the standard matter potential, and $|\epsilon|\ll1$. Diagonalize $H$ to obtain the mixing angle $\theta_m$.
# Provide
# \[
# \tan2\theta_m=\dots
# \]
# as a single LaTeX expression in terms of $\theta$, $\Delta$, $V_e$, and $\epsilon\,$.
#
# 3. Cutoff Scale from One- and Two-Loop Higgs Mass Corrections
# The Higgs mass corrections are
# \[
# \delta m_H^2{}^{(1)}=-\frac{3\,y_t^2}{8\pi^2}\,\Lambda^2,\qquad
# \delta m_H^2{}^{(2)}=\frac{C\,g_s^2\,y_t^2}{16\pi^4}\,\Lambda^2,
# \]
# with real positive $y_t$, $g_s$ and $C=\mathcal O(1)$. Define the fine-tuning measure
# \[
# \Delta=\frac{\bigl|\delta m_H^2{}^{(1)}+\delta m_H^2{}^{(2)}\bigr|}{m_H^2}\le\Delta_{\max}.
# \]
# Solve for the maximal cutoff $\Lambda_{\max}$.
# Provide
# \[
# \Lambda_{\max}=\dots
# \]
# as a single LaTeX expression in terms of $y_t$, $g_s$, $m_H$, $C$, and $\Delta_{\max}\,$.
#
# 4. Short-Baseline Appearance in a 3+1 Model with a CP Phase
# Neglecting $\Delta m^2_{21},\Delta m^2_{31}$ and standard CP phases, the 3+1 appearance probability is
# \[
# P_{\mu e}(L)=\biggl|\sum_{i=1}^4U_{\mu i}U^*_{e i}\,e^{-i\,m_i^2L/(2E)}\biggr|^2,
# \]
# with $|U_{e4}U_{\mu4}|\ll1$ and a CP phase $\delta_{14}\in(-\pi,\pi]$. Expand $P_{\mu e}(L)$ to leading order in $|U_{e4}U_{\mu4}|$.
# Provide
# \[
# P_{\mu e}(L)\approx\dots
# \]
# as a single LaTeX expression in terms of $|U_{e4}U_{\mu4}|$, $\delta_{14}$, $\Delta m^2_{41}$, $L$, and $E\,$.
#
# 5. Closed-Form Solution of Coupled One-Loop RGEs
# The RGEs are
# \[
# \frac{dy}{dt}=a\,y^3+d\,y\,g^2,\quad
# \frac{dg}{dt}=-b\,g^3,
# \]
# with $t=\ln\mu$, $y(0)=y_0$, $g(0)=g_0$, and $a,b,d>0$. Eliminate $g(t)$, integrate, and express $y(t)$ in closed form.
# Provide
# \[
# y(t)=\dots
# \]
# in terms of $t$, $y_0$, $g_0$, $a$, $b$, and $d$ (Lambert $W$ allowed).
