# %%
import os
import glob
import json
import math
import random
import re
from collections import Counter
import networkx as nx
import pdfplumber
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

# Set the OpenAI API key from environment variable
api_key = os.getenv("OPENAI_API_KEY")
client = OpenAI(api_key=api_key)

# -- Document Loading ------------------------------------------------------

def load_docs_from_dir(dir_path):
    """
    Load all .pdf files from a directory and extract their full text.
    Returns a list of strings, one per PDF.
    """
    docs = []
    filenames = []
    for filepath in glob.glob(os.path.join(dir_path, '*.pdf')):
        try:
            text_pages = []
            with pdfplumber.open(filepath) as pdf:
                for page in pdf.pages:
                    text_pages.append(page.extract_text() or "")
            full_text = "\n".join(text_pages)
            docs.append(full_text)
            filenames.append(os.path.basename(filepath))
        except Exception as e:
            # skip unreadable PDFs
            print(f"Warning: could not load {filepath}: {e}")
    return docs, filenames

# -- 1. Extract topics and key concepts -----------------------------------

def extract_json_from_text(text):
    """Helper function to extract JSON content from markdown code blocks or raw text"""
    # Try to extract JSON from markdown code blocks
    json_match = re.search(r'```(?:json)?\s*(.*?)\s*```', text, re.DOTALL)
    if json_match:
        return json_match.group(1).strip()
    
    # If no code blocks, try to find JSON-like structures
    json_match = re.search(r'(\{.*\})', text, re.DOTALL)
    if json_match:
        return json_match.group(1).strip()
    
    # Return original text if no JSON structure found
    return text

def extract_concepts_from_docs(doc_texts, filenames, model="gpt-4o"):  
    """
    Call OpenAI API to extract topics and key concepts from each document.
    Returns list of dicts with keys 'topics' and 'key_concepts'.
    """
    extractions = []
    for i, text in enumerate(doc_texts):
        filename = filenames[i] if i < len(filenames) else f"doc_{i}"
        
        prompt = (
            "Extract high-level topics and key concepts from the following document. "
            f"Return JSON with keys 'topics' and 'key_concepts'.\n\n{text}"
        )
        response = client.chat.completions.create(
            model=model,
            messages=[
                {"role": "system", "content": "You are an expert Maths summarizer. Return your response as a JSON object with 'topics' and 'key_concepts' as arrays."},
                {"role": "user", "content": prompt}
            ],
        )
        
        output = response.choices[0].message.content
        print("Raw output:", output)
        
        try:
            # Clean and extract JSON from the output
            json_str = extract_json_from_text(output)
            data = json.loads(json_str)
            
            # Ensure we have the expected keys
            if "topics" in data and "key_concepts" in data:
                extraction = {
                    "filename": filename,
                    "topics": data["topics"],
                    "key_concepts": data["key_concepts"]
                }
                extractions.append(extraction)
                print(f"Successfully extracted {len(data['topics'])} topics and {len(data['key_concepts'])} key concepts from {filename}")
            else:
                print(f"Warning: Parsed JSON doesn't have expected keys: {data.keys()}")
                extractions.append({
                    "filename": filename,
                    "topics": [], 
                    "key_concepts": []
                })
                
        except json.JSONDecodeError as e:
            print(f"Failed to parse JSON: {e}")
            extractions.append({
                "filename": filename,
                "topics": [], 
                "key_concepts": []
            })
    
    return extractions

# -- 2. Construct the concept graph ----------------------------------------

def build_concept_graph(extractions, eps=1e-6):
    """
    Build a unified graph G where nodes are topics + key concepts and
    edges weighted by log(freq+eps) based on co-occurrence in docs.
    Returns: G (nx.Graph), topic_nodes, kc_nodes
    """
    freq = Counter()
    all_topics, all_kcs = set(), set()

    for ex in extractions:
        nodes = ex["topics"] + ex["key_concepts"]
        for i in range(len(nodes)):
            for j in range(i+1, len(nodes)):
                u, v = sorted((nodes[i], nodes[j]))
                freq[(u, v)] += 1
        all_topics.update(ex["topics"])
        all_kcs.update(ex["key_concepts"])

    G = nx.Graph()
    for (u, v), f in freq.items():
        weight = math.log(f + eps)
        G.add_edge(u, v, weight=weight)

    print(f"Graph built with {len(all_topics)} topics and {len(all_kcs)} key concepts")
    return G, all_topics, all_kcs

# -- Helpers for sampling --------------------------------------------------

def softmax(weights):
    exps = [math.exp(w) for w in weights]
    s = sum(exps) or 1.0
    return [e/s for e in exps]


def random_walk(G, start, steps):
    """
    Random walk on graph G for given steps from 'start',
    with transition probabilities via softmax over edge weights.
    """
    path = [start]
    current = start
    for _ in range(steps):
        nbrs = list(G[current])
        if not nbrs:
            break
        weights = [G[current][n]['weight'] for n in nbrs]
        probs = softmax(weights)
        current = random.choices(nbrs, probs)[0]
        path.append(current)
    return path

# -- 3. Concept combination sampling ---------------------------------------

def sample_concept_combinations(
    G, topic_nodes, kc_nodes,
    num_samples=100,
    topic_walk_steps=(1, 2),
    kc_walk_steps=(3, 4)
):
    """
    Generate sampled sets of topics and key concepts via multi-stage random walks.
    Returns list of dicts: {'topics': set, 'key_concepts': set}
    """
    # Safety check
    if not topic_nodes:
        print("Error: No topics found. Cannot sample combinations.")
        return []
        
    G_topic = G.subgraph(topic_nodes)
    G_topic_kc = G.subgraph(topic_nodes | kc_nodes)
    G_kc = G.subgraph(kc_nodes)
    samples = []

    topics_list = list(topic_nodes)
    print(f"Sampling from {len(topics_list)} topics")
    
    for _ in range(num_samples):
        t0 = random.choice(topics_list)
        t_steps = random.choice(topic_walk_steps)
        topic_path = random_walk(G_topic, t0, t_steps)
        sampled_topics = set(topic_path)

        kc_cands = [nbr for t in sampled_topics for nbr in G_topic_kc[t] if nbr in kc_nodes]
        if kc_cands:
            k0 = random.choice(kc_cands)
            k_steps = random.choice(kc_walk_steps)
            kc_path = random_walk(G_kc, k0, k_steps)
            sampled_kcs = set(kc_path)
        else:
            sampled_kcs = set()

        samples.append({
            "topics": list(sampled_topics),  # Convert sets to lists for JSON serialization
            "key_concepts": list(sampled_kcs)
        })
    
    return samples

# -- 4. Question generation ------------------------------------------------

# def generate_questions_for_samples(combos, docs, extractions, model="gpt-4o"):  
#     """
#     For each sampled combo, pick two docs via Jaccard on concept sets,
#     then call LLM to generate questions.
#     Returns list of dicts: {'sample': combo, 'questions': [...]}.
#     """
#     doc_concepts = [set(ex['topics'] + ex['key_concepts']) for ex in extractions]
#     # doc_concepts= doc_concepts[:1]
#     results = []
#     max_samples = 100
#     # combos = combos[:max_samples]
#     for i, combo in enumerate(combos):
#         combo_id = f"combo_{i+1}"
#         kg = set(combo['topics']) | set(combo['key_concepts'])
#         sims = []
#         for idx, dc in enumerate(doc_concepts):
#             inter = kg & dc
#             union = kg | dc
#             sims.append((len(inter) / (len(union) or 1), idx))
#         sims.sort(reverse=True)
#         top_idxs = [i for _, i in sims[:2]]
#         refs = [docs[i] for i in top_idxs]
#         ref_files = [extractions[i]["filename"] for i in top_idxs]
#         System_prompt =f"""
# Each question must follow these instructions:
# Model a Chemistry Scenario: Start from a real-world or idealized setup. Avoid abstract Physics problems or purely conceptual statements.
# Target a Solvable Quantity: Ask for a clear symbolic expression of a physical variable (e.g., tension, acceleration, energy).
# Force Multi-Step Reasoning: Ensure the question involves a sequence of physics laws, transformations, and derivations to reach the answer.
# Avoid Redundancy: Exclude extraneous details or variables that do not impact the final solution.
# Be Unique: Do not rephrase standard textbook problems; ensure originality and complexity.
# Single solution: Expect a single symbolic expression, unambiguous, presented in LaTeX. Multiple equivalent algebraic forms are allowed. No equations or floating-point approximations.
# Use rigorous, concise phrasing.
# Avoid colloquial or ambiguous terminology.
# Units must be consistent; symbols should follow standard notation.
# """
#         prompt = (
#             f"Generate a set of difficult Physics questions based on the following:\n"
            
#             f"Topics: {combo['topics']}\n"
#             f"Key Concepts: {combo['key_concepts']}\n"
#             f"Reference Doc 1:\n{refs[0]}\n"
#         )
#         if len(refs) > 1:
#             prompt += f"Reference Doc 2:\n{refs[1]}\n"
#         prompt += "Return a JSON array of questions."

#         # from ollama import chat
#         # from ollama import ChatResponse

#         # response: ChatResponse = chat(model='qwen3:8b', 
#         #                                messages=[
#         #         {"role": "system", "content": System_prompt},
#         #         {"role": "user", "content": prompt}
#         #     ])
#         # # print(response['message']['content'])
#         # # or access fields directly from the response object
#         # print(response.message.content)
#         # content = response.message.content
#         response = client.chat.completions.create(
#             model=model,
#             messages=[
#                 {"role": "system", "content": System_prompt},
#                 {"role": "user", "content": prompt}
#             ]
#         )
#         content = response.choices[0].message.content
        
#         try:
#             # Clean and extract JSON from the output
#             json_str = extract_json_from_text(content)
#             questions = json.loads(json_str)
#             if not isinstance(questions, list):
#                 # If the output is an object with a questions key
#                 if isinstance(questions, dict) and "questions" in questions:
#                     questions = questions["questions"]
#                 else:
#                     questions = [str(questions)]
#         except json.JSONDecodeError:
#             questions = [content]

#         results.append({
#             "id": combo_id,
#             "topics": combo['topics'],
#             "key_concepts": combo['key_concepts'],
#             "reference_files": ref_files,
#             "questions": questions
#         })
#         max_samples-=1
#         if max_samples == 0:
#             break


    # return results

# -- Save outputs to files ------------------------------------------------

def save_extractions(extractions, output_file="document_extractions.json"):
    """Save the extracted topics and key concepts for each document"""
    # Ensure the extractions are serializable (convert sets to lists)
    serializable_extractions = []
    for ex in extractions:
        serializable_extractions.append({
            "filename": ex["filename"],
            "topics": list(ex["topics"]),
            "key_concepts": list(ex["key_concepts"])
        })
    
    with open(output_file, "w") as f:
        json.dump(serializable_extractions, f, indent=2)
    
    print(f"Saved document extractions to {output_file}")

def save_questions_with_topics(questions, output_file="questions_with_topics.json"):
    """Save the generated questions with their topic combinations"""
    with open(output_file, "w") as f:
        json.dump(questions, f, indent=2)
    
    print(f"Saved questions with topic combinations to {output_file}")

# -- Main Execution --------------------------------------------------------

if __name__ == "__main__":
    # Create output directory if it doesn't exist
    output_dir = "output_maths"
    os.makedirs(output_dir, exist_ok=True)
    
    # adjust this path to where your .pdf docs live
    docs_dir = "data/"
    
    print("Loading documents...")
    docs, filenames = load_docs_from_dir(docs_dir)
    print(f"Loaded {len(docs)} documents")
    
    if not docs:
        print("No documents found. Please check the docs directory.")
        exit(1)
    
    # 1) Extract topics & KCs
    print("\nExtracting topics and key concepts...")
    extractions = extract_concepts_from_docs(docs, filenames)
    
    # Save extractions to file
    save_extractions(extractions, os.path.join(output_dir, "document_extractions_maths.json"))
    
    # Verify we have valid extractions
    valid_extractions = [ex for ex in extractions if ex["topics"] or ex["key_concepts"]]
    if not valid_extractions:
        print("No valid topics or key concepts extracted. Check your data and API responses.")
        exit(1)
    
    # 2) Build graph
    print("\nBuilding concept graph...")
    G, topic_nodes, kc_nodes = build_concept_graph(extractions)
    
    if not topic_nodes:
        print("No topics found in the graph. Cannot proceed.")
        exit(1)
    
    # 3) Sample combinations
    print("\nSampling concept combinations...")
    combos = sample_concept_combinations(G, topic_nodes, kc_nodes, num_samples=10)  # Reduced for testing
    
    if not combos:
        print("Failed to generate concept combinations.")
        exit(1)
    
    # Save topic combinations
    with open(os.path.join(output_dir, "topic_combinations_maths.json"), "w") as f:
        json.dump(combos, f, indent=2)
    
    # 4) Generate questions
    # print("\nGenerating questions for each combination...")
    # q_outputs = generate_questions_for_samples(combos, docs, extractions)
    
    # # Save questions with topics
    # save_questions_with_topics(q_outputs, os.path.join(output_dir, "questions_with_topics.json"))
    
    # # Display results
    # print("\n===== GENERATED QUESTIONS =====")
    # for idx, out in enumerate(q_outputs, 1):
    #     print(f"\nSample {idx}:")
    #     print(f"Topics: {out['topics']}")
    #     print(f"Key Concepts: {out['key_concepts']}")
    #     print(f"Reference Files: {out['reference_files']}")
    #     print("Questions:")
    #     for q in out['questions']:
    #         print(f" - {q}")
    
    # print(f"\nAll outputs saved to directory: {output_dir}") 

# if __name__ == "__main__":
#     # Create output directory if it doesn't exist
#     # Create output directory if it doesn't exist
#     output_dir = "output_apple"
#     os.makedirs(output_dir, exist_ok=True)
    
#     # adjust this path to where your .pdf docs live
#     docs_dir = "docs/"
    
#     print("Loading documents...")
#     docs, filenames = load_docs_from_dir(docs_dir)
#     print(f"Loaded {len(docs)} documents")
#     document_extractions = []
#     with open("output_apple/document_extractions.json", "r") as f:
#         document_extractions = json.load(f)
#     for doc in document_extractions:
#         print(doc)
#         break

#     topic_combinations = []
#     with open("output_apple/topic_combinations.json", "r") as f:
#         topic_combinations = json.load(f)
#     for combo in topic_combinations:
#         print(combo)
#         break

#     # generate questions 
#     print("Generating questions...")
#     q_outputs = generate_questions_for_samples(topic_combinations, docs, document_extractions)

#     # Save questions with topics
#     save_questions_with_topics(q_outputs, os.path.join(output_dir, "questions_with_topics.json"))
    
#     # Display results
#     print("\n===== GENERATED QUESTIONS =====")
#     for idx, out in enumerate(q_outputs, 1):
#         print(f"\nSample {idx}:")
#         print(f"Topics: {out['topics']}")
#         print(f"Key Concepts: {out['key_concepts']}")
#         print(f"Reference Files: {out['reference_files']}")
#         print("Questions:")
#         for q in out['questions']:
#             print(f" - {q}")
    
#     print(f"\nAll outputs saved to directory: {output_dir}")
# Out:
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# Loading documents...
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# Loaded 20 documents
#
# Extracting topics and key concepts...
# Raw output: ```json
# {
#   "topics": [
#     "Two-sided Gaussian Estimates",
#     "Second-order Parabolic Equations",
#     "Non-divergence Form",
#     "Fundamental Solutions",
#     "Mathematical Theorems and Proofs",
#     "Numerical Bounds and Inequalities"
#   ],
#   "key_concepts": [
#     "Two-sided Gaussian Bounds",
#     "Fundamental Solution of Parabolic Equations",
#     "Non-divergence Form Operators",
#     "Local Boundedness Property",
#     "Weak Harnack Inequality",
#     "Uniform Parabolicity Condition",
#     "Dini Mean Oscillation",
#     "Krylov-Safonov Harnack Inequality",
#     "Parabolic Muckenhoupt Weight",
#     "Ellipticity Constants",
#     "Harnack Inequality",
#     "Local Boundedness and Harnack Connections",
#     "Dini Continuity of Coefficients"
#   ]
# }
# ```
# Successfully extracted 6 topics and 13 key concepts from 2505.12659v1.pdf
# Raw output: ```json
# {
#   "topics": [
#     "Fractional Calculus",
#     "Duality Theory",
#     "Calculus of Variations",
#     "Fractional Derivatives",
#     "Integration by Parts",
#     "Dissipative Systems"
#   ],
#   "key_concepts": [
#     "Fractional differentiation of arbitrary order",
#     "Transformation between left and right fractional operators",
#     "Fractional integration by parts formulas",
#     "Fractional Calculus of Variations (FCoV)",
#     "Euler–Lagrange equations involving fractional derivatives",
#     "Lagrangian mechanics for dissipative systems",
#     "Duality between left and right fractional operators",
#     "New perspective on fractional calculus of variations",
#     "Nonconservative/dissipative motion equations",
#     "Riemann–Liouville fractional derivatives",
#     "Proposition of a new Lagrangian with only left fractional derivatives",
#     "Equations of motion for dissipative systems using fractional calculus"
#   ]
# }
# ```
# Successfully extracted 6 topics and 12 key concepts from 2404.14458v2.pdf
# Raw output: ```json
# {
#   "topics": [
#     "Central Binomial Coefficients",
#     "Infinite Series",
#     "Fibonacci and Lucas Numbers",
#     "Binomial Coefficient Identities",
#     "Analytic Combinatorics"
#   ],
#   "key_concepts": [
#     "Central binomial coefficients are a key component of Pascal's triangle and hold significance in combinatorics and mathematical analysis.",
#     "The paper investigates series involving central binomial coefficients, focusing on their convergence properties and connections to other mathematical sequences such as Fibonacci and Lucas numbers.",
#     "New closed-form representations for alternating series with central binomial coefficients are derived.",
#     "Series that involve the floor and ceiling functions and their relationships with central binomial coefficients are explored.",
#     "The connections between central binomial coefficients and Catalan numbers are emphasized.",
#     "The paper also examines the relationship between these series and certain trigonometric and hyperbolic tangent functions.",
#     "The study extends to additional series involving higher-order binomial coefficients and harmonic numbers."
#   ]
# }
# ```
# Successfully extracted 5 topics and 7 key concepts from 2505.11575v1.pdf
# Raw output: ```json
# {
#   "topics": [
#     "Waring problem for matrices",
#     "Matrices over finite fields",
#     "Algebraic structures in finite fields",
#     "Minimal polynomial and companion matrix",
#     "Additive decomposition of matrices",
#     "k-th powers in matrix algebra",
#     "Primitive and irreducible polynomials",
#     "Divisor counting in mathematical analysis"
#   ],
#   "key_concepts": [
#     "Waring decomposition",
#     "Finite fields and cardinality",
#     "Trace of a matrix",
#     "Non-derogatory matrices",
#     "Companion matrices",
#     "Characteristics of irreducible polynomials",
#     "Diagonalization and Frobenius normal form",
#     "Primitive elements in finite fields",
#     "Non-commutative simple groups",
#     "Galois theory in finite fields",
#     "Larsen's conjecture",
#     "Legendre symbols and divisors in number theory",
#     "Representation of matrices as sums of powers"
#   ]
# }
# ```
# Successfully extracted 8 topics and 13 key concepts from 2505.11805v1.pdf
# Raw output: ```json
# {
#   "topics": [
#     "MacMahon-type sums of divisors",
#     "Generating functions",
#     "Congruences in Mathematics",
#     "Integer partitions",
#     "Divisibility and modular properties"
#   ],
#   "key_concepts": [
#     "MacMahon's generating function relating sum-of-divisors functions with integer partitions",
#     "Extensions and generalizations of MacMahon's sums of divisors",
#     "The definition and exploration of U(a,q) generating functions for various values of a",
#     "Ramanujan-like congruences for power series coefficients",
#     "Arithmetic properties of partitions and overpartition families",
#     "Kummer's Theorem for binomial coefficients and divisibility by prime powers",
#     "Chebychev polynomials and their applications in this context",
#     "Properties of q-series and their arithmetic applications",
#     "Explicit formulas and expansions for generalized series"
#   ]
# }
# ```
# Successfully extracted 5 topics and 9 key concepts from 2505.12813v1.pdf
# Raw output: ```json
# {
#   "topics": [
#     "Graph Theory",
#     "Spectral Graph Theory",
#     "Signed Graphs",
#     "Characteristic Polynomial",
#     "Discriminant",
#     "Cospectrality",
#     "Generalized Spectrum",
#     "Matrix Theory",
#     "Square-free Integer",
#     "Control Theory"
#   ],
#   "key_concepts": [
#     "Signed Graphs: A graph with edges assigned a positive or negative sign.",
#     "Bipartite Graphs: A type of graph where vertices can be divided into two disjoint sets, with no two graph vertices within the same set being adjacent.",
#     "Generalized Spectrum: A set of invariants related to the eigenvalues of a graph.",
#     "Characteristic Polynomial: A polynomial associated with a matrix whose roots are the eigenvalues of the matrix.",
#     "Discriminant: A polynomial function of the coefficients of a polynomial, providing information about the nature of its roots.",
#     "Controllability: A property of a graph indicating that the entire state space can be reached from any initial state under certain controls.",
#     "Totally Isotropic Subspace: A subspace where every pair of vectors is orthogonal.",
#     "Sylvester Matrix: A matrix derived from two polynomials, used to compute the resultant.",
#     "Irreducible Polynomial: A polynomial that cannot be factored into the product of two non-constant polynomials over a given field.",
#     "Invariant Factors: Factors related to the Smith normal form of a matrix, useful for characterizing its integer matrix equivalence."
#   ]
# }
# ```
# Successfully extracted 10 topics and 10 key concepts from 2505.12446v1.pdf
# Raw output: ```json
# {
#   "topics": [
#     "Markov Chain Monte Carlo (MCMC)",
#     "Metropolis-Hastings Algorithms",
#     "Discrete Sampling Algorithms",
#     "Wasserstein Gradient Flow",
#     "Accelerated Sampling in Discrete Spaces",
#     "Hamiltonian Dynamics",
#     "Probability Manifolds"
#   ],
#   "key_concepts": [
#     "Nesterov's Accelerated Gradient Method",
#     "Kullback-Leibler (KL) Divergence",
#     "Wasserstein-2 Metric",
#     "Discrete Space Probability Distribution",
#     "Momentum-Based Acceleration",
#     "Hamiltonian Flows on Simplex",
#     "Score Functions",
#     "Relative Fisher Information",
#     "Geodesic Convexity",
#     "Numerical Algorithms for Sampling",
#     "Stationary Distribution",
#     "Graph Theory in MCMC Algorithms",
#     "Ergodic Markov Chains",
#     "Eigenvalue Analysis for Convergence",
#     "Numerical Scheme Adaptation",
#     "Sampling Complex Distributions"
#   ]
# }
# ```
# Successfully extracted 7 topics and 16 key concepts from 2505.12599v1.pdf
# Raw output: ```json
# {
#   "topics": [
#     "Differential Operators",
#     "q-Difference Operators",
#     "Arithmetic Support",
#     "Formal Deformations",
#     "Monodromy",
#     "Determinants and Traces",
#     "Nilpotent Connections",
#     "Holonomic D-modules"
#   ],
#   "key_concepts": [
#     "Arithmetic support of differential operators",
#     "Formal deformations of operators",
#     "Motivic differential operators",
#     "Monodromy in characteristic zero",
#     "q-difference operators and their representations",
#     "Determinants and traces of operators",
#     "p-curvature in arithmetic geometry",
#     "Operators with regular and irregular singularities",
#     "Characteristic polynomials",
#     "Eigenvectors and eigenvalues of monodromy operators",
#     "Application of cyclotomic polynomials",
#     "Relation between arithmetic and q-analog cases",
#     "Adic properties in coefficient expansions"
#   ]
# }
# ```
# Successfully extracted 8 topics and 13 key concepts from 2505.12480v1.pdf
# Raw output: ```json
# {
#   "topics": [
#     "Division Algebras",
#     "Maximal Subfields",
#     "Multilinear Polynomials",
#     "Laurent Polynomials",
#     "Algebraic Elements",
#     "Matrix Rings",
#     "Group Words",
#     "Algebraic Structures in Rings"
#   ],
#   "key_concepts": [
#     "Division ring",
#     "Maximal subfield",
#     "Multilinear polynomial",
#     "Group word",
#     "Algebraic matrix",
#     "Laurent polynomial identities",
#     "Finite-dimensional division ring",
#     "Image of a polynomial",
#     "Matrix algebra",
#     "Algebraic degree",
#     "Characteristic polynomial",
#     "The Brauer-Albert theorem",
#     "Matrix trace",
#     "Symmetric group",
#     "Non-commutative polynomial",
#     "Center of a division ring",
#     "Simple maximal subfield",
#     "Algebraic extension",
#     "Bounded algebraic degree"
#   ]
# }
# ```
# Successfully extracted 8 topics and 19 key concepts from 2505.12855v1.pdf
# Raw output: ```json
# {
#   "topics": [
#     "Number Theory",
#     "Prime Numbers",
#     "Divergence of Series",
#     "Riemann Hypothesis"
#   ],
#   "key_concepts": [
#     "Sum of Reciprocals of Primes",
#     "Euler's Proof of Divergence of Sum of Reciprocals of Primes",
#     "Prime Number Theorem",
#     "Cosine Function and Primes",
#     "Sets of Primes Based on Cosine Inequalities",
#     "Lemmas on Prime Factorization",
#     "Divergence Theorem for Specific Sets of Primes"
#   ]
# }
# ```
# Successfully extracted 4 topics and 7 key concepts from 2403.04768v4.pdf
# Raw output: ```json
# {
#   "topics": [
#     "Semilinear Differential Equations",
#     "Controllability",
#     "Moving Singularities",
#     "Fractional Differential Equations"
#   ],
#   "key_concepts": [
#     "Control Problem",
#     "Differential Equations with Singularities",
#     "Bisection Algorithm",
#     "Lipschitz Continuity",
#     "Integral Equations",
#     "Continuous Dependence on Parameters",
#     "Grönwall's Lemma",
#     "Arzelà-Ascoli Theorem",
#     "Fractional Calculus",
#     "Convergence and Continuity in Control Problems"
#   ]
# }
# ```
# Successfully extracted 4 topics and 10 key concepts from 2505.11531v1.pdf
# Raw output: ```json
# {
#   "topics": [
#     "Resolvent Analysis",
#     "Spectral Theory",
#     "Interpolation Theory",
#     "Model Spaces and Operators",
#     "Toeplitz Matrices",
#     "Matrix Analysis"
#   ],
#   "key_concepts": [
#     "Supremum of the resolvent norm",
#     "Finite-dimensional contraction",
#     "Spectral radius conditions",
#     "Operator norm",
#     "Analytic Toeplitz matrix",
#     "Commutant Lifting Theorem",
#     "Blaschke product",
#     "H∞ space",
#     "Interpolation techniques",
#     "Model operator",
#     "Fejer kernel",
#     "Takenaka-Malmquist-Walsh basis"
#   ]
# }
# ```
# Successfully extracted 6 topics and 12 key concepts from 2505.12901v1.pdf
# Raw output: ```json
# {
#   "topics": [
#     "Combinatorics",
#     "Finite Abelian Groups",
#     "Subset Sums",
#     "Asymptotic Analysis",
#     "Extremal Combinatorics",
#     "Coding Theory"
#   ],
#   "key_concepts": [
#     "Asymptotic Uniform Distribution",
#     "Sperner's Theorem",
#     "Subset Sum Problem",
#     "Hamming Distance",
#     "Constant-weight Codes",
#     "Equidistribution of Subset Sums",
#     "Pich-mentioned_maximum and minimum sizes of subset families",
#     "Kronecker-delta Functions",
#     "Induction and Recurrence Relations",
#     "Intersection Properties of Subsets",
#     "Finite Set Theory",
#     "Extremal Problems in N-Cube"
#   ]
# }
# ```
# Successfully extracted 6 topics and 12 key concepts from 2505.12319v1.pdf
# Raw output: ```json
# {
#   "topics": [
#     "Inverse Problems in Fractional Differential Equations",
#     "Subdiffusion Equations with Caputo Derivatives",
#     "Existence and Uniqueness of Solutions",
#     "Integral Overdetermination Conditions",
#     "Fractional Calculus Applications",
#     "Eigenvalue Problems in Differential Equations"
#   ],
#   "key_concepts": [
#     "Caputo time derivative",
#     "Inverse problem for subdiffusion equation",
#     "Existence and uniqueness of weak solutions",
#     "Fourier method for solving differential equations",
#     "Integral overdetermination",
#     "Mittag-Leffler functions",
#     "Spectral theory and eigenvalue problems",
#     "Approximations and convergence in functional spaces",
#     "Coercive estimates in differential equations",
#     "Fractional Sobolev spaces"
#   ]
# }
# ```
# Successfully extracted 6 topics and 10 key concepts from 2505.12385v1.pdf
# Raw output: ```json
# {
#   "topics": [
#     "Nonlocal Discrete Problems",
#     "Sign-Changing Kirchhoff Functions",
#     "Difference Equations",
#     "Variational Methods",
#     "Multiplicity Theorems",
#     "Nonlinear Analysis"
#   ],
#   "key_concepts": [
#     "Multiplicity Theorem for Nonlocal Discrete Problems",
#     "Kirchhoff Functions with Negative Coefficients",
#     "Minimax Theorems",
#     "Sign-Changing Functions in Mathematical Problems",
#     "Lower Semicontinuous and Inf-Compact Functions",
#     "Topological Vector Spaces",
#     "Infimum and Supremum in Functional Analysis",
#     "Hilbert Spaces and Closed Balls",
#     "Cauchy-Schwarz Inequality",
#     "Courant's Theorem for Critical Points",
#     "Weak Lower Semicontinuity",
#     "Variational Formulation of Difference Equations",
#     "Convex and Quasi-Concave Functions"
#   ]
# }
# ```
# Successfully extracted 6 topics and 13 key concepts from 2505.12790v1.pdf
# Raw output: ```json
# {
#   "topics": [
#     "Boolean Functions",
#     "Secondary Constructions",
#     "Walsh Transform",
#     "Bent Functions",
#     "Nonlinearity in Boolean Functions",
#     "Coding Theory",
#     "Cryptography"
#   ],
#   "key_concepts": [
#     "Indirect Sum and Generalizations",
#     "Direct Sum Construction",
#     "General Secondary Construction",
#     "Walsh Transform Calculation",
#     "Vectorial Boolean Functions",
#     "Plateaued Functions",
#     "Resilient Functions",
#     "Algebraic Immunity",
#     "Hamming Weight",
#     "Maiorana-McFarland Construction",
#     "Characterization of Bent Functions",
#     "Difference Sets in Non-cyclic Groups"
#   ]
# }
# ```
# Successfully extracted 7 topics and 12 key concepts from 2505.11994v1.pdf
# Raw output: ```json
# {
#   "topics": [
#     "Symmetric Solutions",
#     "Symmetry in Difference Equations",
#     "Finite Group of Symmetries",
#     "Representation Theory",
#     "Automorphism Groups",
#     "Discrete Systems"
#   ],
#   "key_concepts": [
#     "Linear Partial Difference Equations",
#     "Invariant Solutions",
#     "Symmetry Group Actions",
#     "Lattice Zn",
#     "Group Representations",
#     "G-invariant Submodules",
#     "Laurent Polynomial Ring",
#     "Finite-dimensional Representations",
#     "GLn(Z) and (C*)n Subgroups",
#     "Homothety and Matrix Automorphisms",
#     "Injective Cogenerators",
#     "Submodule Construction",
#     "System Perturbations",
#     "Exact and Approximate Solutions"
#   ]
# }
# ```
# Successfully extracted 6 topics and 14 key concepts from 2310.00903v3.pdf
# Raw output: ```json
# {
#   "topics": [
#     "Large Deviations",
#     "Regular Variation",
#     "Random Walks",
#     "Tauberian Theorems",
#     "Probability Theory",
#     "Random Sums",
#     "Heavy-Tailed Distributions",
#     "Renewal Processes",
#     "Statistical Physics",
#     "Queueing Theory"
#   ],
#   "key_concepts": [
#     "Precise large deviation principle",
#     "Tauberian theorem for Laplace-Stieltjes transforms",
#     "Spectrally positive stable distributions",
#     "Random walks with long-ranged memory kernels",
#     "Randomly stopped sums",
#     "Cramér’s condition",
#     "Subexponentiality",
#     "Big-jump domain",
#     "Karamata's theorem",
#     "Anomalous diffusion models",
#     "Compound Poisson risk model",
#     "Renewal counting process",
#     "Inverse of a stable subordinator"
#   ]
# }
# ```
# Successfully extracted 10 topics and 13 key concepts from 2407.04059v2.pdf
# Raw output: ```json
# {
#   "topics": [
#     "Orthogonal Polynomials",
#     "Zeros of Polynomials",
#     "Polynomial Combinations",
#     "Special Functions",
#     "Asymptotic Analysis"
#   ],
#   "key_concepts": [
#     "Sequence of orthogonal polynomials",
#     "Positive measure on the real line",
#     "Real zeros of polynomial combinations",
#     "Renormalization of orthogonal polynomials",
#     "Interlacing property of polynomial zeros",
#     "Obreshkov Theorem",
#     "Hermite polynomials",
#     "Laguerre polynomials",
#     "Jacobi polynomials",
#     "Asymptotic distribution of zeros",
#     "Mehler-Heine type formulas"
#   ]
# }
# ```
# Successfully extracted 5 topics and 11 key concepts from 2505.11956v1.pdf
# Raw output: ```json
# {
#   "topics": [
#     "Mean Curvature Flow (MCF)",
#     "Avoidance Principle",
#     "Hausdorff Dimension",
#     "Intersection of Flows",
#     "Brakke Flows",
#     "Level Set Flows",
#     "Weak Solutions",
#     "Self-Shrinkers",
#     "Non-Fattening Criterion"
#   ],
#   "key_concepts": [
#     "Mean curvature flow is used to deform submanifolds.",
#     "The avoidance principle states that disjoint hypersurfaces under MCF remain disjoint.",
#     "Hausdorff dimension of the intersection of two MCFs is non-increasing over time.",
#     "Self-intersection of an immersed MCF has non-increasing dimension over time.",
#     "Extension of intersection dimension monotonicity to Brakke flows and level set flows under certain conditions.",
#     "Fattening criterion for level set flows with finitely many singularities.",
#     "Intersection principle for weak solutions depends on finite singularities and unique flows.",
#     "Characterization of non-fattening level set flows via intersection principle.",
#     "Localization result for level set flows with finitely many singularities.",
#     "Examples of flows with increasing intersection dimension or nodal components.",
#     "Hausdorff measure controls applied to graphical solutions of MCF.",
#     "Brakke flows and level set flows as weak solutions with bounded area ratios."
#   ]
# }
# ```
# Successfully extracted 9 topics and 12 key concepts from 2505.11600v1.pdf
# Saved document extractions to output_maths/document_extractions_maths.json
#
# Building concept graph...
# Graph built with 130 topics and 238 key concepts
#
# Sampling concept combinations...
# Sampling from 130 topics

# %% [markdown]
# ### download data from csv

# %%
import os
import argparse
import pandas as pd
import requests
from urllib.parse import urlparse, unquote

def download_files(
    csv_path="Researchpapers_PhD_Synthetic_Data - Physics.csv",
    output_dir="docs"
) -> None:
    """
    Reads a CSV with a 'Link' column and downloads each URL to output_dir,
    saving each file with a .pdf extension.
    """
    # Load CSV
    df = pd.read_csv(csv_path)
    if 'Link' not in df.columns:
        raise ValueError("CSV must contain a 'Link' column.")

    # Ensure output directory exists
    os.makedirs(output_dir, exist_ok=True)

    total = len(df['Link'].dropna())
    for idx, url in enumerate(df['Link'].dropna(), start=1):
        try:
            # Parse URL and derive a safe filename
            parsed = urlparse(url)
            raw_name = os.path.basename(parsed.path)
            raw_name = unquote(raw_name)  # decode URL-encoded characters

            if raw_name:
                name, ext = os.path.splitext(raw_name)
                # If there's no .pdf extension, force it
                filename = f"{idx}.pdf" if ext.lower() != '.pdf' else raw_name
            else:
                filename = f"{idx}.pdf"

            out_path = os.path.join(output_dir, filename)

            # Stream download
            with requests.get(url, stream=True) as r:
                r.raise_for_status()
                with open(out_path, 'wb') as f:
                    for chunk in r.iter_content(chunk_size=8192):
                        if chunk:
                            f.write(chunk)

            print(f"[{idx}/{total}] Downloaded → {filename}")

        except Exception as e:
            print(f"[{idx}/{total}] FAILED  → {url}\n    {e}")

if __name__ == "__main__":
    download_files()
# Out:
# [1/23] Downloaded → 1.pdf
# [2/23] Downloaded → 2.pdf
# [3/23] Downloaded → 3.pdf
# [4/23] Downloaded → 4.pdf
# [5/23] Downloaded → 5.pdf
# [6/23] Downloaded → 6.pdf
# [7/23] Downloaded → 7.pdf
# [8/23] Downloaded → 8.pdf
# [9/23] Downloaded → 9.pdf
# [10/23] Downloaded → 10.pdf
# [11/23] Downloaded → 11.pdf
# [12/23] Downloaded → 12.pdf
# [13/23] Downloaded → 13.pdf
# [14/23] Downloaded → 14.pdf
# [15/23] Downloaded → 15.pdf
# [16/23] Downloaded → 16.pdf
# [17/23] Downloaded → 17.pdf
# [18/23] Downloaded → 18.pdf
# [19/23] Downloaded → 19.pdf
# [20/23] Downloaded → 20.pdf
# [21/23] Downloaded → 21.pdf
# [22/23] FAILED  → https://arxiv.org/abs/2505.06432'
#     404 Client Error: Not Found for url: https://arxiv.org/abs/2505.06432'
# [23/23] Downloaded → 23.pdf

# %% [markdown]
# ## Author - Critique Model

# %%
import logging
from typing import List, Dict
import json
from langchain.chat_models import ChatOpenAI
from langchain.prompts import PromptTemplate, FewShotPromptTemplate
from langchain.chains import LLMChain

# Explicit logging configuration for console and file
logger = logging.getLogger()
logger.setLevel(logging.INFO)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

# File handler
file_handler = logging.FileHandler('conversation.log', mode='w')
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# Console handler
console_handler = logging.StreamHandler()
console_handler.setFormatter(formatter)
logger.addHandler(console_handler)

# ---- Core author–critic loop for Chemistry ----
def author_critique_loop(
    topics: List[str],
    concepts: List[str],
    guidelines: str,
    few_shot_examples: List[Dict[str, str]],
    max_turns: int = 4,
) -> str:
    """
    Runs the author–critic loop for chemistry questions and logs each turn.
    Returns the final set of questions.
    """
    # Initialize LLMs
    author_llm = ChatOpenAI(model_name="o4-mini", temperature=1)
    critic_llm = ChatOpenAI(model_name="o3", temperature=1)

    # Build Few-Shot prompt for author
    example_prompt = PromptTemplate(
        input_variables=["example"],
        template="Example:\n{{ example }}\n---",
        template_format="jinja2"
    )
    author_fs_prompt = FewShotPromptTemplate(
        examples=few_shot_examples,
        example_prompt=example_prompt,
        example_separator="\n\n",

        prefix="You are a mathematics education specialist. Generate novel university-level Mathematics questions. Here are some examples:",
        suffix=(
            "Based on topics: {{topics}}, key concepts: {{concepts}}, "
            "and guidelines: {{guidelines}}, produce a set of new, high-quality Mathematics questions."
        ),
        input_variables=["topics", "concepts", "guidelines"],
        template_format="jinja2",

    )
    # 3) Now when you format, only pass the outer variables:
    # prompt_value = author_fs_prompt.format_prompt(
    # topics=topics,
    # concepts=concepts,
    # guidelines=guidelines,
    # )
    # print("Suyash",prompt_value.to_string())
    author_chain = LLMChain(llm=author_llm, prompt=author_fs_prompt)

    # Build Critic prompt
    critic_prompt = PromptTemplate(
        input_variables=["questions", "guidelines"],
        template=(
            "You are a mathematics assessment expert. Critique the following questions:\n"
            "{questions}\n"
            "Evaluate them against these guidelines:\n{guidelines}\n"
            "Provide concise, actionable feedback on how to improve."
        ),
    )
    critic_chain = LLMChain(llm=critic_llm, prompt=critic_prompt)

    questions, feedback = "", ""

    for turn in range(max_turns):
        # ---- AUTHOR STEP ----
        if turn == 0:
            # print(f"Starting author–critic loop with topics: {topics} and concepts: {concepts} ,")
            prompt = author_fs_prompt.format_prompt(
                topics=topics, concepts=concepts, guidelines=guidelines
            ).to_string()
            response = author_chain.run(
                topics=topics, concepts=concepts, guidelines=guidelines
            )
        else:
            refine = PromptTemplate(
                input_variables=["questions", "feedback"],
                template=(
                    "Refine these questions based on feedback:\n"
                    "Questions:\n{questions}\n"
                    "Feedback:\n{feedback}\n"
                    "Provide an improved set of Mathematics questions following the original criteria."
                ),
            )
            prompt = refine.format(questions=questions, feedback=feedback)
            response = LLMChain(llm=author_llm, prompt=refine).run(
                questions=questions, feedback=feedback
            )

        logger.info(f"[Author turn {turn}] Prompt:\n{prompt}")
        logger.info(f"[Author turn {turn}] Response:\n{response}")
        questions = response

        # ---- CRITIC STEP ----
        prompt_c = critic_prompt.format(
            questions=questions, guidelines=guidelines
        )
        response_c = critic_chain.run(
            questions=questions, guidelines=guidelines
        )
        logger.info(f"[Critic turn {turn}] Prompt:\n{prompt_c}")
        logger.info(f"[Critic turn {turn}] Response:\n{response_c}")
        feedback = response_c

    return questions


if __name__ == "__main__":
    # Chemistry-specific example usage
    # topics = [
    #     "Thermodynamics of Chemical Reactions",
    #     "Organic Reaction Mechanisms",
    #     "Coordination Chemistry",
    #     "Electrochemical Cells"
    # ]
    # concepts = [
    #     "Use of enthalpy, entropy, and Gibbs free energy to predict reaction spontaneity.",
    #     "Mechanistic steps in nucleophilic substitution and elimination reactions.",
    #     "Formation constants and isomerism in transition metal complexes.",
    #     "Calculating cell potential using standard reduction potentials and Nernst equation."
    # ]
    with open("output_maths/topic_combinations_maths.json", "r") as f:
        topic_combinations = json.load(f)

  # Limit for testing topic combinations is last k
    topic_combinations = topic_combinations[-1:]  # Adjust as needed for testing
    print(f"Processing {len(topic_combinations)} topic combinations for Mathematics questions...")
    guidelines = (
    "1. Input Format: Fully text-based. No diagrams, visual aids, or references to external media. "
    "2. Mathematical Structure: Start with a well-defined setup—real-world or idealized. Avoid vague, puzzle-like, or speculative scenarios. "
    "3. Solvable Target: Ask for a clear symbolic result (e.g., function, limit, closed-form expression). Do not use phrasing like 'Prove' or 'Show that'. "
    "4. Multi-Step Reasoning: Require a logical sequence of algebraic or analytic steps, involving definitions, identities, or theorems. "
    "5. Concise and Relevant: Include only essential information. Eliminate redundant details or irrelevant symbols. "
    "6. Originality: Ensure the problem is unique and non-trivial. Avoid rewording standard textbook problems. "
    "7. Single Output: Expect a single, unambiguous symbolic answer in LaTeX. Equivalent forms are allowed. No numeric approximations. Do not rely on computational tools - use traditional mathematical methods. "
    "8. Solution Formatting: Format the equations, numbers and variables using LaTeX with Markdown syntax: "
    "Replace \\(...\\) with $...$ "
    "Replace \\[...\\] with $$...$$ "
    "9. Language and Notation: Be rigorous and concise. Avoid colloquial terms. Use standard, consistent mathematical notation throughout. "
    "10. Questions must not have multiple parts to answer, there should be only 1 solution to each question"
    "11. Only questions should be generated, no answers,solutions or explainations should be provided."

)
    
    few_shot_examples = [
        {"example": (
            """Good: Problem: As the sun set over the quiet town, a mathematician named Alex sat by the lake, tossing pebbles into the water. He pondered a curious geometric puzzle inspired by the ripples—how distances change when a point moves along a circle. His thoughts led him to an intriguing problem about a regular octagon inscribed in a circle.
Let $A_1, A_2, A_3, \ldots, A_8$ be the vertices of a regular octagon that lie on a circle of radius $2$. Let $P$ be a point on the circle and let $PA_i$ denote the distance between the points $P$ and $A_i$ for $i = 1, 2, \ldots, 8$.
If $P$ varies over the circle, then find the maximum value of $$PA_1 \cdot PA_2 \cdots PA_8.$$

"""
        )},
        {"example": (
            "Bad: What is the pythagorus theorm."
        )},
    ]
    all_questions = []

    for combo in topic_combinations:
        topics = combo['topics']
        concepts = combo['key_concepts']
        logger.info(f"Processing combination: {topics} | {concepts}")
        # Run the author–critic loop for this combination
        questions = author_critique_loop(
            topics, concepts, guidelines, few_shot_examples, max_turns=4
        )
        
        all_questions.append({
            "topics": topics,
            "key_concepts": concepts,
            "questions": questions
        })

    # Save all questions to a file
    with open("final_questions_maths.json", "w") as f:
        json.dump(all_questions, f, indent=2)
    logger.info("Author–Critique loop for Mathematics complete.")
    #save just questions using pretty print in text format
    # final_questions = author_critique_loop(
    #     topics, concepts, guidelines, few_shot_examples, max_turns=4
    # )
    # print(f"Final Chemistry Questions:\n{final_questions}\n")
    # logger.info("Author–Critique loop for chemistry complete.")
    # #save final questions in a file 
    
    # with open("final_questions_chemistry.txt", "w") as f:
    #     f.write(final_questions)
    # logging.info("Author–Critique loop complete.")
# Out:
# 2025-05-27 14:48:20,044 - INFO - Processing combination: ['Divisibility and modular properties', 'Congruences in Mathematics'] | ['Ramanujan-like congruences for power series coefficients', "Extensions and generalizations of MacMahon's sums of divisors", 'Arithmetic properties of partitions and overpartition families', 'Chebychev polynomials and their applications in this context']
# 2025-05-27 14:48:20,044 - INFO - Processing combination: ['Divisibility and modular properties', 'Congruences in Mathematics'] | ['Ramanujan-like congruences for power series coefficients', "Extensions and generalizations of MacMahon's sums of divisors", 'Arithmetic properties of partitions and overpartition families', 'Chebychev polynomials and their applications in this context']
# 2025-05-27 14:48:20,044 - INFO - Processing combination: ['Divisibility and modular properties', 'Congruences in Mathematics'] | ['Ramanujan-like congruences for power series coefficients', "Extensions and generalizations of MacMahon's sums of divisors", 'Arithmetic properties of partitions and overpartition families', 'Chebychev polynomials and their applications in this context']
# Processing 1 topic combinations for Mathematics questions...
# 2025-05-27 14:49:02,410 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-27 14:49:02,410 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-27 14:49:02,410 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-27 14:49:02,417 - INFO - [Author turn 0] Prompt:
# You are a mathematics education specialist. Generate novel university-level Mathematics questions. Here are some examples:
#
# Example:
# Good: Problem: As the sun set over the quiet town, a mathematician named Alex sat by the lake, tossing pebbles into the water. He pondered a curious geometric puzzle inspired by the ripples—how distances change when a point moves along a circle. His thoughts led him to an intriguing problem about a regular octagon inscribed in a circle.
# Let $A_1, A_2, A_3, \ldots, A_8$ be the vertices of a regular octagon that lie on a circle of radius $2$. Let $P$ be a point on the circle and let $PA_i$ denote the distance between the points $P$ and $A_i$ for $i = 1, 2, \ldots, 8$.
# If $P$ varies over the circle, then find the maximum value of $$PA_1 \cdot PA_2 \cdots PA_8.$$
#
#
# ---
#
# Example:
# Bad: What is the pythagorus theorm.
# ---
#
# Based on topics: ['Divisibility and modular properties', 'Congruences in Mathematics'], key concepts: ['Ramanujan-like congruences for power series coefficients', "Extensions and generalizations of MacMahon's sums of divisors", 'Arithmetic properties of partitions and overpartition families', 'Chebychev polynomials and their applications in this context'], and guidelines: 1. Input Format: Fully text-based. No diagrams, visual aids, or references to external media. 2. Mathematical Structure: Start with a well-defined setup—real-world or idealized. Avoid vague, puzzle-like, or speculative scenarios. 3. Solvable Target: Ask for a clear symbolic result (e.g., function, limit, closed-form expression). Do not use phrasing like 'Prove' or 'Show that'. 4. Multi-Step Reasoning: Require a logical sequence of algebraic or analytic steps, involving definitions, identities, or theorems. 5. Concise and Relevant: Include only essential information. Eliminate redundant details or irrelevant symbols. 6. Originality: Ensure the problem is unique and non-trivial. Avoid rewording standard textbook problems. 7. Single Output: Expect a single, unambiguous symbolic answer in LaTeX. Equivalent forms are allowed. No numeric approximations. Do not rely on computational tools - use traditional mathematical methods. 8. Solution Formatting: Format the equations, numbers and variables using LaTeX with Markdown syntax: Replace \(...\) with $...$ Replace \[...\] with $$...$$ 9. Language and Notation: Be rigorous and concise. Avoid colloquial terms. Use standard, consistent mathematical notation throughout. 10. Questions must not have multiple parts to answer, there should be only 1 solution to each question11. Only questions should be generated, no answers,solutions or explainations should be provided., produce a set of new, high-quality Mathematics questions.
# 2025-05-27 14:49:02,417 - INFO - [Author turn 0] Prompt:
# You are a mathematics education specialist. Generate novel university-level Mathematics questions. Here are some examples:
#
# Example:
# Good: Problem: As the sun set over the quiet town, a mathematician named Alex sat by the lake, tossing pebbles into the water. He pondered a curious geometric puzzle inspired by the ripples—how distances change when a point moves along a circle. His thoughts led him to an intriguing problem about a regular octagon inscribed in a circle.
# Let $A_1, A_2, A_3, \ldots, A_8$ be the vertices of a regular octagon that lie on a circle of radius $2$. Let $P$ be a point on the circle and let $PA_i$ denote the distance between the points $P$ and $A_i$ for $i = 1, 2, \ldots, 8$.
# If $P$ varies over the circle, then find the maximum value of $$PA_1 \cdot PA_2 \cdots PA_8.$$
#
#
# ---
#
# Example:
# Bad: What is the pythagorus theorm.
# ---
#
# Based on topics: ['Divisibility and modular properties', 'Congruences in Mathematics'], key concepts: ['Ramanujan-like congruences for power series coefficients', "Extensions and generalizations of MacMahon's sums of divisors", 'Arithmetic properties of partitions and overpartition families', 'Chebychev polynomials and their applications in this context'], and guidelines: 1. Input Format: Fully text-based. No diagrams, visual aids, or references to external media. 2. Mathematical Structure: Start with a well-defined setup—real-world or idealized. Avoid vague, puzzle-like, or speculative scenarios. 3. Solvable Target: Ask for a clear symbolic result (e.g., function, limit, closed-form expression). Do not use phrasing like 'Prove' or 'Show that'. 4. Multi-Step Reasoning: Require a logical sequence of algebraic or analytic steps, involving definitions, identities, or theorems. 5. Concise and Relevant: Include only essential information. Eliminate redundant details or irrelevant symbols. 6. Originality: Ensure the problem is unique and non-trivial. Avoid rewording standard textbook problems. 7. Single Output: Expect a single, unambiguous symbolic answer in LaTeX. Equivalent forms are allowed. No numeric approximations. Do not rely on computational tools - use traditional mathematical methods. 8. Solution Formatting: Format the equations, numbers and variables using LaTeX with Markdown syntax: Replace \(...\) with $...$ Replace \[...\] with $$...$$ 9. Language and Notation: Be rigorous and concise. Avoid colloquial terms. Use standard, consistent mathematical notation throughout. 10. Questions must not have multiple parts to answer, there should be only 1 solution to each question11. Only questions should be generated, no answers,solutions or explainations should be provided., produce a set of new, high-quality Mathematics questions.
# 2025-05-27 14:49:02,417 - INFO - [Author turn 0] Prompt:
# You are a mathematics education specialist. Generate novel university-level Mathematics questions. Here are some examples:
#
# Example:
# Good: Problem: As the sun set over the quiet town, a mathematician named Alex sat by the lake, tossing pebbles into the water. He pondered a curious geometric puzzle inspired by the ripples—how distances change when a point moves along a circle. His thoughts led him to an intriguing problem about a regular octagon inscribed in a circle.
# Let $A_1, A_2, A_3, \ldots, A_8$ be the vertices of a regular octagon that lie on a circle of radius $2$. Let $P$ be a point on the circle and let $PA_i$ denote the distance between the points $P$ and $A_i$ for $i = 1, 2, \ldots, 8$.
# If $P$ varies over the circle, then find the maximum value of $$PA_1 \cdot PA_2 \cdots PA_8.$$
#
#
# ---
#
# Example:
# Bad: What is the pythagorus theorm.
# ---
#
# Based on topics: ['Divisibility and modular properties', 'Congruences in Mathematics'], key concepts: ['Ramanujan-like congruences for power series coefficients', "Extensions and generalizations of MacMahon's sums of divisors", 'Arithmetic properties of partitions and overpartition families', 'Chebychev polynomials and their applications in this context'], and guidelines: 1. Input Format: Fully text-based. No diagrams, visual aids, or references to external media. 2. Mathematical Structure: Start with a well-defined setup—real-world or idealized. Avoid vague, puzzle-like, or speculative scenarios. 3. Solvable Target: Ask for a clear symbolic result (e.g., function, limit, closed-form expression). Do not use phrasing like 'Prove' or 'Show that'. 4. Multi-Step Reasoning: Require a logical sequence of algebraic or analytic steps, involving definitions, identities, or theorems. 5. Concise and Relevant: Include only essential information. Eliminate redundant details or irrelevant symbols. 6. Originality: Ensure the problem is unique and non-trivial. Avoid rewording standard textbook problems. 7. Single Output: Expect a single, unambiguous symbolic answer in LaTeX. Equivalent forms are allowed. No numeric approximations. Do not rely on computational tools - use traditional mathematical methods. 8. Solution Formatting: Format the equations, numbers and variables using LaTeX with Markdown syntax: Replace \(...\) with $...$ Replace \[...\] with $$...$$ 9. Language and Notation: Be rigorous and concise. Avoid colloquial terms. Use standard, consistent mathematical notation throughout. 10. Questions must not have multiple parts to answer, there should be only 1 solution to each question11. Only questions should be generated, no answers,solutions or explainations should be provided., produce a set of new, high-quality Mathematics questions.
# 2025-05-27 14:49:02,420 - INFO - [Author turn 0] Response:
# 1. Let \(p(n)\) denote the ordinary partition function. Determine the unique residue class \(r\) modulo 5 for which
# \[
# p(5n + r)\equiv 0\pmod 5
# \]
# for all integers \(n\ge0\).
#
# 2. Define \(A_3(n)\) by the generating function
# \[
# \sum_{n=0}^\infty A_3(n)\,q^n \;=\;\prod_{m=1}^\infty\bigl(1-q^m\bigr)^{-3}.
# \]
# Express \(A_3(n)\) in closed form as a combination of the usual divisor functions \(\sigma_k(d)=\sum_{d\mid n}d^k\).
#
# 3. Let \(\overline{p}_{\mathrm{odd}}(n)\) be the number of overpartitions of \(n\) into odd parts. Determine the generating function
# \[
# \sum_{n=0}^\infty \overline{p}_{\mathrm{odd}}(n)\,q^n
# \]
# in closed form.
#
# 4. For the Chebyshev polynomials of the first kind \(T_n(x)\), find the ordinary generating function
# \[
# \sum_{n=0}^\infty T_n(x)\,t^n
# \]
# as a rational function in \(x\) and \(t\).
# 2025-05-27 14:49:02,420 - INFO - [Author turn 0] Response:
# 1. Let \(p(n)\) denote the ordinary partition function. Determine the unique residue class \(r\) modulo 5 for which
# \[
# p(5n + r)\equiv 0\pmod 5
# \]
# for all integers \(n\ge0\).
#
# 2. Define \(A_3(n)\) by the generating function
# \[
# \sum_{n=0}^\infty A_3(n)\,q^n \;=\;\prod_{m=1}^\infty\bigl(1-q^m\bigr)^{-3}.
# \]
# Express \(A_3(n)\) in closed form as a combination of the usual divisor functions \(\sigma_k(d)=\sum_{d\mid n}d^k\).
#
# 3. Let \(\overline{p}_{\mathrm{odd}}(n)\) be the number of overpartitions of \(n\) into odd parts. Determine the generating function
# \[
# \sum_{n=0}^\infty \overline{p}_{\mathrm{odd}}(n)\,q^n
# \]
# in closed form.
#
# 4. For the Chebyshev polynomials of the first kind \(T_n(x)\), find the ordinary generating function
# \[
# \sum_{n=0}^\infty T_n(x)\,t^n
# \]
# as a rational function in \(x\) and \(t\).
# 2025-05-27 14:49:02,420 - INFO - [Author turn 0] Response:
# 1. Let \(p(n)\) denote the ordinary partition function. Determine the unique residue class \(r\) modulo 5 for which
# \[
# p(5n + r)\equiv 0\pmod 5
# \]
# for all integers \(n\ge0\).
#
# 2. Define \(A_3(n)\) by the generating function
# \[
# \sum_{n=0}^\infty A_3(n)\,q^n \;=\;\prod_{m=1}^\infty\bigl(1-q^m\bigr)^{-3}.
# \]
# Express \(A_3(n)\) in closed form as a combination of the usual divisor functions \(\sigma_k(d)=\sum_{d\mid n}d^k\).
#
# 3. Let \(\overline{p}_{\mathrm{odd}}(n)\) be the number of overpartitions of \(n\) into odd parts. Determine the generating function
# \[
# \sum_{n=0}^\infty \overline{p}_{\mathrm{odd}}(n)\,q^n
# \]
# in closed form.
#
# 4. For the Chebyshev polynomials of the first kind \(T_n(x)\), find the ordinary generating function
# \[
# \sum_{n=0}^\infty T_n(x)\,t^n
# \]
# as a rational function in \(x\) and \(t\).
# 2025-05-27 14:50:04,769 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-27 14:50:04,769 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-27 14:50:04,769 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-27 14:50:04,776 - INFO - [Critic turn 0] Prompt:
# You are a mathematics assessment expert. Critique the following questions:
# 1. Let \(p(n)\) denote the ordinary partition function. Determine the unique residue class \(r\) modulo 5 for which
# \[
# p(5n + r)\equiv 0\pmod 5
# \]
# for all integers \(n\ge0\).
#
# 2. Define \(A_3(n)\) by the generating function
# \[
# \sum_{n=0}^\infty A_3(n)\,q^n \;=\;\prod_{m=1}^\infty\bigl(1-q^m\bigr)^{-3}.
# \]
# Express \(A_3(n)\) in closed form as a combination of the usual divisor functions \(\sigma_k(d)=\sum_{d\mid n}d^k\).
#
# 3. Let \(\overline{p}_{\mathrm{odd}}(n)\) be the number of overpartitions of \(n\) into odd parts. Determine the generating function
# \[
# \sum_{n=0}^\infty \overline{p}_{\mathrm{odd}}(n)\,q^n
# \]
# in closed form.
#
# 4. For the Chebyshev polynomials of the first kind \(T_n(x)\), find the ordinary generating function
# \[
# \sum_{n=0}^\infty T_n(x)\,t^n
# \]
# as a rational function in \(x\) and \(t\).
# Evaluate them against these guidelines:
# 1. Input Format: Fully text-based. No diagrams, visual aids, or references to external media. 2. Mathematical Structure: Start with a well-defined setup—real-world or idealized. Avoid vague, puzzle-like, or speculative scenarios. 3. Solvable Target: Ask for a clear symbolic result (e.g., function, limit, closed-form expression). Do not use phrasing like 'Prove' or 'Show that'. 4. Multi-Step Reasoning: Require a logical sequence of algebraic or analytic steps, involving definitions, identities, or theorems. 5. Concise and Relevant: Include only essential information. Eliminate redundant details or irrelevant symbols. 6. Originality: Ensure the problem is unique and non-trivial. Avoid rewording standard textbook problems. 7. Single Output: Expect a single, unambiguous symbolic answer in LaTeX. Equivalent forms are allowed. No numeric approximations. Do not rely on computational tools - use traditional mathematical methods. 8. Solution Formatting: Format the equations, numbers and variables using LaTeX with Markdown syntax: Replace \(...\) with $...$ Replace \[...\] with $$...$$ 9. Language and Notation: Be rigorous and concise. Avoid colloquial terms. Use standard, consistent mathematical notation throughout. 10. Questions must not have multiple parts to answer, there should be only 1 solution to each question11. Only questions should be generated, no answers,solutions or explainations should be provided.
# Provide concise, actionable feedback on how to improve.
# 2025-05-27 14:50:04,776 - INFO - [Critic turn 0] Prompt:
# You are a mathematics assessment expert. Critique the following questions:
# 1. Let \(p(n)\) denote the ordinary partition function. Determine the unique residue class \(r\) modulo 5 for which
# \[
# p(5n + r)\equiv 0\pmod 5
# \]
# for all integers \(n\ge0\).
#
# 2. Define \(A_3(n)\) by the generating function
# \[
# \sum_{n=0}^\infty A_3(n)\,q^n \;=\;\prod_{m=1}^\infty\bigl(1-q^m\bigr)^{-3}.
# \]
# Express \(A_3(n)\) in closed form as a combination of the usual divisor functions \(\sigma_k(d)=\sum_{d\mid n}d^k\).
#
# 3. Let \(\overline{p}_{\mathrm{odd}}(n)\) be the number of overpartitions of \(n\) into odd parts. Determine the generating function
# \[
# \sum_{n=0}^\infty \overline{p}_{\mathrm{odd}}(n)\,q^n
# \]
# in closed form.
#
# 4. For the Chebyshev polynomials of the first kind \(T_n(x)\), find the ordinary generating function
# \[
# \sum_{n=0}^\infty T_n(x)\,t^n
# \]
# as a rational function in \(x\) and \(t\).
# Evaluate them against these guidelines:
# 1. Input Format: Fully text-based. No diagrams, visual aids, or references to external media. 2. Mathematical Structure: Start with a well-defined setup—real-world or idealized. Avoid vague, puzzle-like, or speculative scenarios. 3. Solvable Target: Ask for a clear symbolic result (e.g., function, limit, closed-form expression). Do not use phrasing like 'Prove' or 'Show that'. 4. Multi-Step Reasoning: Require a logical sequence of algebraic or analytic steps, involving definitions, identities, or theorems. 5. Concise and Relevant: Include only essential information. Eliminate redundant details or irrelevant symbols. 6. Originality: Ensure the problem is unique and non-trivial. Avoid rewording standard textbook problems. 7. Single Output: Expect a single, unambiguous symbolic answer in LaTeX. Equivalent forms are allowed. No numeric approximations. Do not rely on computational tools - use traditional mathematical methods. 8. Solution Formatting: Format the equations, numbers and variables using LaTeX with Markdown syntax: Replace \(...\) with $...$ Replace \[...\] with $$...$$ 9. Language and Notation: Be rigorous and concise. Avoid colloquial terms. Use standard, consistent mathematical notation throughout. 10. Questions must not have multiple parts to answer, there should be only 1 solution to each question11. Only questions should be generated, no answers,solutions or explainations should be provided.
# Provide concise, actionable feedback on how to improve.
# 2025-05-27 14:50:04,776 - INFO - [Critic turn 0] Prompt:
# You are a mathematics assessment expert. Critique the following questions:
# 1. Let \(p(n)\) denote the ordinary partition function. Determine the unique residue class \(r\) modulo 5 for which
# \[
# p(5n + r)\equiv 0\pmod 5
# \]
# for all integers \(n\ge0\).
#
# 2. Define \(A_3(n)\) by the generating function
# \[
# \sum_{n=0}^\infty A_3(n)\,q^n \;=\;\prod_{m=1}^\infty\bigl(1-q^m\bigr)^{-3}.
# \]
# Express \(A_3(n)\) in closed form as a combination of the usual divisor functions \(\sigma_k(d)=\sum_{d\mid n}d^k\).
#
# 3. Let \(\overline{p}_{\mathrm{odd}}(n)\) be the number of overpartitions of \(n\) into odd parts. Determine the generating function
# \[
# \sum_{n=0}^\infty \overline{p}_{\mathrm{odd}}(n)\,q^n
# \]
# in closed form.
#
# 4. For the Chebyshev polynomials of the first kind \(T_n(x)\), find the ordinary generating function
# \[
# \sum_{n=0}^\infty T_n(x)\,t^n
# \]
# as a rational function in \(x\) and \(t\).
# Evaluate them against these guidelines:
# 1. Input Format: Fully text-based. No diagrams, visual aids, or references to external media. 2. Mathematical Structure: Start with a well-defined setup—real-world or idealized. Avoid vague, puzzle-like, or speculative scenarios. 3. Solvable Target: Ask for a clear symbolic result (e.g., function, limit, closed-form expression). Do not use phrasing like 'Prove' or 'Show that'. 4. Multi-Step Reasoning: Require a logical sequence of algebraic or analytic steps, involving definitions, identities, or theorems. 5. Concise and Relevant: Include only essential information. Eliminate redundant details or irrelevant symbols. 6. Originality: Ensure the problem is unique and non-trivial. Avoid rewording standard textbook problems. 7. Single Output: Expect a single, unambiguous symbolic answer in LaTeX. Equivalent forms are allowed. No numeric approximations. Do not rely on computational tools - use traditional mathematical methods. 8. Solution Formatting: Format the equations, numbers and variables using LaTeX with Markdown syntax: Replace \(...\) with $...$ Replace \[...\] with $$...$$ 9. Language and Notation: Be rigorous and concise. Avoid colloquial terms. Use standard, consistent mathematical notation throughout. 10. Questions must not have multiple parts to answer, there should be only 1 solution to each question11. Only questions should be generated, no answers,solutions or explainations should be provided.
# Provide concise, actionable feedback on how to improve.
# 2025-05-27 14:50:04,778 - INFO - [Critic turn 0] Response:
# Overall
# • The set presents four well-known, textbook-level problems packaged together.
# • Guidelines 6 and 10 are the main sticking points: each prompt should be both original and self-contained, yet here we have four classical results bundled into a single item.
# • Minor wording/formatting edits would tighten compliance with the other rules.
#
# Detailed feedback
#
# 1. Partition-congruence question
#  – Strengths: text-only, asks for a single residue class, no “prove/show”.
#  – Issues: Ramanujan’s mod-5 congruence is famous → violates Originality (6).
#  – Fix: Replace with a less-standard modulus or a new arithmetic condition; keep it as an independent, standalone problem.
#
# 2. $A_3(n)$ divisor-sum formula
#  – Strengths: clear target (closed-form expression).
#  – Issues: This identity is standard in divisor-sum literature → fails (6).
#  – Clarify “closed form” by specifying “express $A_3(n)$ solely in terms of $\sigma_k(n)$”.
#  – Make it an individual question, not part 2 of a list.
#
# 3. Overpartitions into odd parts
#  – Strengths: single generating function requested, no proof language.
#  – Issues: Again a standard formula → weak originality.
#  – State the required output explicitly, e.g. “Give the product representation in $q$-Pochhammer notation.”
#
# 4. Chebyshev generating function
#  – Strengths: concise, expects one rational function.
#  – Issues: Classic textbook fact → originality problem.
#  – Minor: the variable order “$\sum_{n\ge0}T_n(x)t^n$” is fine; no change needed.
#
# Global recommendations
# • Split the list into four separate prompts so each contains exactly one question (guideline 10).
# • Re-tool each problem to incorporate a novel twist or lesser-known parameter to satisfy guideline 6.
# • Phrase targets explicitly: “Find $r\in\{0,1,2,3,4\}$ …”, “Provide an explicit formula $A_3(n)=\dots$”, etc.
# • Drop “in closed form” if the allowed form is already specified; it adds ambiguity.
# • Keep all LaTeX inline ($...$) or display ($$...$$) per rule 8.
#
# Implementing these changes will make each question fully compliant with the stated guidelines.
# 2025-05-27 14:50:04,778 - INFO - [Critic turn 0] Response:
# Overall
# • The set presents four well-known, textbook-level problems packaged together.
# • Guidelines 6 and 10 are the main sticking points: each prompt should be both original and self-contained, yet here we have four classical results bundled into a single item.
# • Minor wording/formatting edits would tighten compliance with the other rules.
#
# Detailed feedback
#
# 1. Partition-congruence question
#  – Strengths: text-only, asks for a single residue class, no “prove/show”.
#  – Issues: Ramanujan’s mod-5 congruence is famous → violates Originality (6).
#  – Fix: Replace with a less-standard modulus or a new arithmetic condition; keep it as an independent, standalone problem.
#
# 2. $A_3(n)$ divisor-sum formula
#  – Strengths: clear target (closed-form expression).
#  – Issues: This identity is standard in divisor-sum literature → fails (6).
#  – Clarify “closed form” by specifying “express $A_3(n)$ solely in terms of $\sigma_k(n)$”.
#  – Make it an individual question, not part 2 of a list.
#
# 3. Overpartitions into odd parts
#  – Strengths: single generating function requested, no proof language.
#  – Issues: Again a standard formula → weak originality.
#  – State the required output explicitly, e.g. “Give the product representation in $q$-Pochhammer notation.”
#
# 4. Chebyshev generating function
#  – Strengths: concise, expects one rational function.
#  – Issues: Classic textbook fact → originality problem.
#  – Minor: the variable order “$\sum_{n\ge0}T_n(x)t^n$” is fine; no change needed.
#
# Global recommendations
# • Split the list into four separate prompts so each contains exactly one question (guideline 10).
# • Re-tool each problem to incorporate a novel twist or lesser-known parameter to satisfy guideline 6.
# • Phrase targets explicitly: “Find $r\in\{0,1,2,3,4\}$ …”, “Provide an explicit formula $A_3(n)=\dots$”, etc.
# • Drop “in closed form” if the allowed form is already specified; it adds ambiguity.
# • Keep all LaTeX inline ($...$) or display ($$...$$) per rule 8.
#
# Implementing these changes will make each question fully compliant with the stated guidelines.
# 2025-05-27 14:50:04,778 - INFO - [Critic turn 0] Response:
# Overall
# • The set presents four well-known, textbook-level problems packaged together.
# • Guidelines 6 and 10 are the main sticking points: each prompt should be both original and self-contained, yet here we have four classical results bundled into a single item.
# • Minor wording/formatting edits would tighten compliance with the other rules.
#
# Detailed feedback
#
# 1. Partition-congruence question
#  – Strengths: text-only, asks for a single residue class, no “prove/show”.
#  – Issues: Ramanujan’s mod-5 congruence is famous → violates Originality (6).
#  – Fix: Replace with a less-standard modulus or a new arithmetic condition; keep it as an independent, standalone problem.
#
# 2. $A_3(n)$ divisor-sum formula
#  – Strengths: clear target (closed-form expression).
#  – Issues: This identity is standard in divisor-sum literature → fails (6).
#  – Clarify “closed form” by specifying “express $A_3(n)$ solely in terms of $\sigma_k(n)$”.
#  – Make it an individual question, not part 2 of a list.
#
# 3. Overpartitions into odd parts
#  – Strengths: single generating function requested, no proof language.
#  – Issues: Again a standard formula → weak originality.
#  – State the required output explicitly, e.g. “Give the product representation in $q$-Pochhammer notation.”
#
# 4. Chebyshev generating function
#  – Strengths: concise, expects one rational function.
#  – Issues: Classic textbook fact → originality problem.
#  – Minor: the variable order “$\sum_{n\ge0}T_n(x)t^n$” is fine; no change needed.
#
# Global recommendations
# • Split the list into four separate prompts so each contains exactly one question (guideline 10).
# • Re-tool each problem to incorporate a novel twist or lesser-known parameter to satisfy guideline 6.
# • Phrase targets explicitly: “Find $r\in\{0,1,2,3,4\}$ …”, “Provide an explicit formula $A_3(n)=\dots$”, etc.
# • Drop “in closed form” if the allowed form is already specified; it adds ambiguity.
# • Keep all LaTeX inline ($...$) or display ($$...$$) per rule 8.
#
# Implementing these changes will make each question fully compliant with the stated guidelines.
# 2025-05-27 14:50:25,656 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-27 14:50:25,656 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-27 14:50:25,656 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-27 14:50:25,661 - INFO - [Author turn 1] Prompt:
# Refine these questions based on feedback:
# Questions:
# 1. Let \(p(n)\) denote the ordinary partition function. Determine the unique residue class \(r\) modulo 5 for which
# \[
# p(5n + r)\equiv 0\pmod 5
# \]
# for all integers \(n\ge0\).
#
# 2. Define \(A_3(n)\) by the generating function
# \[
# \sum_{n=0}^\infty A_3(n)\,q^n \;=\;\prod_{m=1}^\infty\bigl(1-q^m\bigr)^{-3}.
# \]
# Express \(A_3(n)\) in closed form as a combination of the usual divisor functions \(\sigma_k(d)=\sum_{d\mid n}d^k\).
#
# 3. Let \(\overline{p}_{\mathrm{odd}}(n)\) be the number of overpartitions of \(n\) into odd parts. Determine the generating function
# \[
# \sum_{n=0}^\infty \overline{p}_{\mathrm{odd}}(n)\,q^n
# \]
# in closed form.
#
# 4. For the Chebyshev polynomials of the first kind \(T_n(x)\), find the ordinary generating function
# \[
# \sum_{n=0}^\infty T_n(x)\,t^n
# \]
# as a rational function in \(x\) and \(t\).
# Feedback:
# Overall
# • The set presents four well-known, textbook-level problems packaged together.
# • Guidelines 6 and 10 are the main sticking points: each prompt should be both original and self-contained, yet here we have four classical results bundled into a single item.
# • Minor wording/formatting edits would tighten compliance with the other rules.
#
# Detailed feedback
#
# 1. Partition-congruence question
#  – Strengths: text-only, asks for a single residue class, no “prove/show”.
#  – Issues: Ramanujan’s mod-5 congruence is famous → violates Originality (6).
#  – Fix: Replace with a less-standard modulus or a new arithmetic condition; keep it as an independent, standalone problem.
#
# 2. $A_3(n)$ divisor-sum formula
#  – Strengths: clear target (closed-form expression).
#  – Issues: This identity is standard in divisor-sum literature → fails (6).
#  – Clarify “closed form” by specifying “express $A_3(n)$ solely in terms of $\sigma_k(n)$”.
#  – Make it an individual question, not part 2 of a list.
#
# 3. Overpartitions into odd parts
#  – Strengths: single generating function requested, no proof language.
#  – Issues: Again a standard formula → weak originality.
#  – State the required output explicitly, e.g. “Give the product representation in $q$-Pochhammer notation.”
#
# 4. Chebyshev generating function
#  – Strengths: concise, expects one rational function.
#  – Issues: Classic textbook fact → originality problem.
#  – Minor: the variable order “$\sum_{n\ge0}T_n(x)t^n$” is fine; no change needed.
#
# Global recommendations
# • Split the list into four separate prompts so each contains exactly one question (guideline 10).
# • Re-tool each problem to incorporate a novel twist or lesser-known parameter to satisfy guideline 6.
# • Phrase targets explicitly: “Find $r\in\{0,1,2,3,4\}$ …”, “Provide an explicit formula $A_3(n)=\dots$”, etc.
# • Drop “in closed form” if the allowed form is already specified; it adds ambiguity.
# • Keep all LaTeX inline ($...$) or display ($$...$$) per rule 8.
#
# Implementing these changes will make each question fully compliant with the stated guidelines.
# Provide an improved set of Mathematics questions following the original criteria.
# 2025-05-27 14:50:25,661 - INFO - [Author turn 1] Prompt:
# Refine these questions based on feedback:
# Questions:
# 1. Let \(p(n)\) denote the ordinary partition function. Determine the unique residue class \(r\) modulo 5 for which
# \[
# p(5n + r)\equiv 0\pmod 5
# \]
# for all integers \(n\ge0\).
#
# 2. Define \(A_3(n)\) by the generating function
# \[
# \sum_{n=0}^\infty A_3(n)\,q^n \;=\;\prod_{m=1}^\infty\bigl(1-q^m\bigr)^{-3}.
# \]
# Express \(A_3(n)\) in closed form as a combination of the usual divisor functions \(\sigma_k(d)=\sum_{d\mid n}d^k\).
#
# 3. Let \(\overline{p}_{\mathrm{odd}}(n)\) be the number of overpartitions of \(n\) into odd parts. Determine the generating function
# \[
# \sum_{n=0}^\infty \overline{p}_{\mathrm{odd}}(n)\,q^n
# \]
# in closed form.
#
# 4. For the Chebyshev polynomials of the first kind \(T_n(x)\), find the ordinary generating function
# \[
# \sum_{n=0}^\infty T_n(x)\,t^n
# \]
# as a rational function in \(x\) and \(t\).
# Feedback:
# Overall
# • The set presents four well-known, textbook-level problems packaged together.
# • Guidelines 6 and 10 are the main sticking points: each prompt should be both original and self-contained, yet here we have four classical results bundled into a single item.
# • Minor wording/formatting edits would tighten compliance with the other rules.
#
# Detailed feedback
#
# 1. Partition-congruence question
#  – Strengths: text-only, asks for a single residue class, no “prove/show”.
#  – Issues: Ramanujan’s mod-5 congruence is famous → violates Originality (6).
#  – Fix: Replace with a less-standard modulus or a new arithmetic condition; keep it as an independent, standalone problem.
#
# 2. $A_3(n)$ divisor-sum formula
#  – Strengths: clear target (closed-form expression).
#  – Issues: This identity is standard in divisor-sum literature → fails (6).
#  – Clarify “closed form” by specifying “express $A_3(n)$ solely in terms of $\sigma_k(n)$”.
#  – Make it an individual question, not part 2 of a list.
#
# 3. Overpartitions into odd parts
#  – Strengths: single generating function requested, no proof language.
#  – Issues: Again a standard formula → weak originality.
#  – State the required output explicitly, e.g. “Give the product representation in $q$-Pochhammer notation.”
#
# 4. Chebyshev generating function
#  – Strengths: concise, expects one rational function.
#  – Issues: Classic textbook fact → originality problem.
#  – Minor: the variable order “$\sum_{n\ge0}T_n(x)t^n$” is fine; no change needed.
#
# Global recommendations
# • Split the list into four separate prompts so each contains exactly one question (guideline 10).
# • Re-tool each problem to incorporate a novel twist or lesser-known parameter to satisfy guideline 6.
# • Phrase targets explicitly: “Find $r\in\{0,1,2,3,4\}$ …”, “Provide an explicit formula $A_3(n)=\dots$”, etc.
# • Drop “in closed form” if the allowed form is already specified; it adds ambiguity.
# • Keep all LaTeX inline ($...$) or display ($$...$$) per rule 8.
#
# Implementing these changes will make each question fully compliant with the stated guidelines.
# Provide an improved set of Mathematics questions following the original criteria.
# 2025-05-27 14:50:25,661 - INFO - [Author turn 1] Prompt:
# Refine these questions based on feedback:
# Questions:
# 1. Let \(p(n)\) denote the ordinary partition function. Determine the unique residue class \(r\) modulo 5 for which
# \[
# p(5n + r)\equiv 0\pmod 5
# \]
# for all integers \(n\ge0\).
#
# 2. Define \(A_3(n)\) by the generating function
# \[
# \sum_{n=0}^\infty A_3(n)\,q^n \;=\;\prod_{m=1}^\infty\bigl(1-q^m\bigr)^{-3}.
# \]
# Express \(A_3(n)\) in closed form as a combination of the usual divisor functions \(\sigma_k(d)=\sum_{d\mid n}d^k\).
#
# 3. Let \(\overline{p}_{\mathrm{odd}}(n)\) be the number of overpartitions of \(n\) into odd parts. Determine the generating function
# \[
# \sum_{n=0}^\infty \overline{p}_{\mathrm{odd}}(n)\,q^n
# \]
# in closed form.
#
# 4. For the Chebyshev polynomials of the first kind \(T_n(x)\), find the ordinary generating function
# \[
# \sum_{n=0}^\infty T_n(x)\,t^n
# \]
# as a rational function in \(x\) and \(t\).
# Feedback:
# Overall
# • The set presents four well-known, textbook-level problems packaged together.
# • Guidelines 6 and 10 are the main sticking points: each prompt should be both original and self-contained, yet here we have four classical results bundled into a single item.
# • Minor wording/formatting edits would tighten compliance with the other rules.
#
# Detailed feedback
#
# 1. Partition-congruence question
#  – Strengths: text-only, asks for a single residue class, no “prove/show”.
#  – Issues: Ramanujan’s mod-5 congruence is famous → violates Originality (6).
#  – Fix: Replace with a less-standard modulus or a new arithmetic condition; keep it as an independent, standalone problem.
#
# 2. $A_3(n)$ divisor-sum formula
#  – Strengths: clear target (closed-form expression).
#  – Issues: This identity is standard in divisor-sum literature → fails (6).
#  – Clarify “closed form” by specifying “express $A_3(n)$ solely in terms of $\sigma_k(n)$”.
#  – Make it an individual question, not part 2 of a list.
#
# 3. Overpartitions into odd parts
#  – Strengths: single generating function requested, no proof language.
#  – Issues: Again a standard formula → weak originality.
#  – State the required output explicitly, e.g. “Give the product representation in $q$-Pochhammer notation.”
#
# 4. Chebyshev generating function
#  – Strengths: concise, expects one rational function.
#  – Issues: Classic textbook fact → originality problem.
#  – Minor: the variable order “$\sum_{n\ge0}T_n(x)t^n$” is fine; no change needed.
#
# Global recommendations
# • Split the list into four separate prompts so each contains exactly one question (guideline 10).
# • Re-tool each problem to incorporate a novel twist or lesser-known parameter to satisfy guideline 6.
# • Phrase targets explicitly: “Find $r\in\{0,1,2,3,4\}$ …”, “Provide an explicit formula $A_3(n)=\dots$”, etc.
# • Drop “in closed form” if the allowed form is already specified; it adds ambiguity.
# • Keep all LaTeX inline ($...$) or display ($$...$$) per rule 8.
#
# Implementing these changes will make each question fully compliant with the stated guidelines.
# Provide an improved set of Mathematics questions following the original criteria.
# 2025-05-27 14:50:25,663 - INFO - [Author turn 1] Response:
# Below is a set of four self-contained problems.  Each asks for a concrete “find” or “determine” and adds a small twist so that none of them is the standard textbook statement.
#
# Problem 1 (3-regular partitions modulo 7)
# Let p₃(n) be the number of partitions of n into parts not divisible by 3.  Show that there is a unique residue r in {0,1,2,3,4,5,6} for which
# \[
# p₃(7n + r)\equiv 0\pmod{7}
# \quad\text{for all integers }n\ge0.
# \]
# Find that r explicitly.
#
# Problem 2 (A two-factor divisor-sum identity)
# Define the sequence B(n) by the generating function
# \[
# \sum_{n=0}^\infty B(n)\,q^n
# \;=\;
# \prod_{m=1}^\infty
# \bigl(1 - q^m\bigr)^{-3}\,\bigl(1 + q^m\bigr).
# \]
# Express B(n) in closed form as an explicit linear combination of the usual divisor sums
# \(\sigma_k(n)=\sum_{d\mid n}d^k\).
#
# Problem 3 (Overpartitions into odd parts with parity condition)
# Let \(\overline p_{\mathrm{odd}}^{\mathrm{even}}(n)\) be the number of overpartitions of n into odd parts such that the total number of overlined parts is even.  Determine a product (or quotient) formula for its ordinary generating function, for example in terms of \(q\)\!-Pochhammer symbols,
# \[
# \sum_{n=0}^\infty
# \overline p_{\mathrm{odd}}^{\mathrm{even}}(n)\,q^n
# \;=\;
# \text{(explicit product in $q$)}.
# \]
#
# Problem 4 (Shifted Chebyshev generating function)
# For the Chebyshev polynomials of the first kind \(T_n(x)\), fix a nonnegative integer \(a\) and define
# \[
# G_a(x,t)\;=\;
# \sum_{n=0}^\infty T_{n+a}(x)\,t^n.
# \]
# Show that \(G_a(x,t)\) is a rational function in \(x\) and \(t\), and write it down explicitly.
# 2025-05-27 14:50:25,663 - INFO - [Author turn 1] Response:
# Below is a set of four self-contained problems.  Each asks for a concrete “find” or “determine” and adds a small twist so that none of them is the standard textbook statement.
#
# Problem 1 (3-regular partitions modulo 7)
# Let p₃(n) be the number of partitions of n into parts not divisible by 3.  Show that there is a unique residue r in {0,1,2,3,4,5,6} for which
# \[
# p₃(7n + r)\equiv 0\pmod{7}
# \quad\text{for all integers }n\ge0.
# \]
# Find that r explicitly.
#
# Problem 2 (A two-factor divisor-sum identity)
# Define the sequence B(n) by the generating function
# \[
# \sum_{n=0}^\infty B(n)\,q^n
# \;=\;
# \prod_{m=1}^\infty
# \bigl(1 - q^m\bigr)^{-3}\,\bigl(1 + q^m\bigr).
# \]
# Express B(n) in closed form as an explicit linear combination of the usual divisor sums
# \(\sigma_k(n)=\sum_{d\mid n}d^k\).
#
# Problem 3 (Overpartitions into odd parts with parity condition)
# Let \(\overline p_{\mathrm{odd}}^{\mathrm{even}}(n)\) be the number of overpartitions of n into odd parts such that the total number of overlined parts is even.  Determine a product (or quotient) formula for its ordinary generating function, for example in terms of \(q\)\!-Pochhammer symbols,
# \[
# \sum_{n=0}^\infty
# \overline p_{\mathrm{odd}}^{\mathrm{even}}(n)\,q^n
# \;=\;
# \text{(explicit product in $q$)}.
# \]
#
# Problem 4 (Shifted Chebyshev generating function)
# For the Chebyshev polynomials of the first kind \(T_n(x)\), fix a nonnegative integer \(a\) and define
# \[
# G_a(x,t)\;=\;
# \sum_{n=0}^\infty T_{n+a}(x)\,t^n.
# \]
# Show that \(G_a(x,t)\) is a rational function in \(x\) and \(t\), and write it down explicitly.
# 2025-05-27 14:50:25,663 - INFO - [Author turn 1] Response:
# Below is a set of four self-contained problems.  Each asks for a concrete “find” or “determine” and adds a small twist so that none of them is the standard textbook statement.
#
# Problem 1 (3-regular partitions modulo 7)
# Let p₃(n) be the number of partitions of n into parts not divisible by 3.  Show that there is a unique residue r in {0,1,2,3,4,5,6} for which
# \[
# p₃(7n + r)\equiv 0\pmod{7}
# \quad\text{for all integers }n\ge0.
# \]
# Find that r explicitly.
#
# Problem 2 (A two-factor divisor-sum identity)
# Define the sequence B(n) by the generating function
# \[
# \sum_{n=0}^\infty B(n)\,q^n
# \;=\;
# \prod_{m=1}^\infty
# \bigl(1 - q^m\bigr)^{-3}\,\bigl(1 + q^m\bigr).
# \]
# Express B(n) in closed form as an explicit linear combination of the usual divisor sums
# \(\sigma_k(n)=\sum_{d\mid n}d^k\).
#
# Problem 3 (Overpartitions into odd parts with parity condition)
# Let \(\overline p_{\mathrm{odd}}^{\mathrm{even}}(n)\) be the number of overpartitions of n into odd parts such that the total number of overlined parts is even.  Determine a product (or quotient) formula for its ordinary generating function, for example in terms of \(q\)\!-Pochhammer symbols,
# \[
# \sum_{n=0}^\infty
# \overline p_{\mathrm{odd}}^{\mathrm{even}}(n)\,q^n
# \;=\;
# \text{(explicit product in $q$)}.
# \]
#
# Problem 4 (Shifted Chebyshev generating function)
# For the Chebyshev polynomials of the first kind \(T_n(x)\), fix a nonnegative integer \(a\) and define
# \[
# G_a(x,t)\;=\;
# \sum_{n=0}^\infty T_{n+a}(x)\,t^n.
# \]
# Show that \(G_a(x,t)\) is a rational function in \(x\) and \(t\), and write it down explicitly.
# 2025-05-27 14:50:55,764 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-27 14:50:55,764 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-27 14:50:55,764 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-05-27 14:50:55,772 - INFO - [Critic turn 1] Prompt:
# You are a mathematics assessment expert. Critique the following questions:
# Below is a set of four self-contained problems.  Each asks for a concrete “find” or “determine” and adds a small twist so that none of them is the standard textbook statement.
#
# Problem 1 (3-regular partitions modulo 7)
# Let p₃(n) be the number of partitions of n into parts not divisible by 3.  Show that there is a unique residue r in {0,1,2,3,4,5,6} for which
# \[
# p₃(7n + r)\equiv 0\pmod{7}
# \quad\text{for all integers }n\ge0.
# \]
# Find that r explicitly.
#
# Problem 2 (A two-factor divisor-sum identity)
# Define the sequence B(n) by the generating function
# \[
# \sum_{n=0}^\infty B(n)\,q^n
# \;=\;
# \prod_{m=1}^\infty
# \bigl(1 - q^m\bigr)^{-3}\,\bigl(1 + q^m\bigr).
# \]
# Express B(n) in closed form as an explicit linear combination of the usual divisor sums
# \(\sigma_k(n)=\sum_{d\mid n}d^k\).
#
# Problem 3 (Overpartitions into odd parts with parity condition)
# Let \(\overline p_{\mathrm{odd}}^{\mathrm{even}}(n)\) be the number of overpartitions of n into odd parts such that the total number of overlined parts is even.  Determine a product (or quotient) formula for its ordinary generating function, for example in terms of \(q\)\!-Pochhammer symbols,
# \[
# \sum_{n=0}^\infty
# \overline p_{\mathrm{odd}}^{\mathrm{even}}(n)\,q^n
# \;=\;
# \text{(explicit product in $q$)}.
# \]
#
# Problem 4 (Shifted Chebyshev generating function)
# For the Chebyshev polynomials of the first kind \(T_n(x)\), fix a nonnegative integer \(a\) and define
# \[
# G_a(x,t)\;=\;
# \sum_{n=0}^\infty T_{n+a}(x)\,t^n.
# \]
# Show that \(G_a(x,t)\) is a rational function in \(x\) and \(t\), and write it down explicitly.
# Evaluate them against these guidelines:
# 1. Input Format: Fully text-based. No diagrams, visual aids, or references to external media. 2. Mathematical Structure: Start with a well-defined setup—real-world or idealized. Avoid vague, puzzle-like, or speculative scenarios. 3. Solvable Target: Ask for a clear symbolic result (e.g., function, limit, closed-form expression). Do not use phrasing like 'Prove' or 'Show that'. 4. Multi-Step Reasoning: Require a logical sequence of algebraic or analytic steps, involving definitions, identities, or theorems. 5. Concise and Relevant: Include only essential information. Eliminate redundant details or irrelevant symbols. 6. Originality: Ensure the problem is unique and non-trivial. Avoid rewording standard textbook problems. 7. Single Output: Expect a single, unambiguous symbolic answer in LaTeX. Equivalent forms are allowed. No numeric approximations. Do not rely on computational tools - use traditional mathematical methods. 8. Solution Formatting: Format the equations, numbers and variables using LaTeX with Markdown syntax: Replace \(...\) with $...$ Replace \[...\] with $$...$$ 9. Language and Notation: Be rigorous and concise. Avoid colloquial terms. Use standard, consistent mathematical notation throughout. 10. Questions must not have multiple parts to answer, there should be only 1 solution to each question11. Only questions should be generated, no answers,solutions or explainations should be provided.
# Provide concise, actionable feedback on how to improve.
# 2025-05-27 14:50:55,772 - INFO - [Critic turn 1] Prompt:
# You are a mathematics assessment expert. Critique the following questions:
# Below is a set of four self-contained problems.  Each asks for a concrete “find” or “determine” and adds a small twist so that none of them is the standard textbook statement.
#
# Problem 1 (3-regular partitions modulo 7)
# Let p₃(n) be the number of partitions of n into parts not divisible by 3.  Show that there is a unique residue r in {0,1,2,3,4,5,6} for which
# \[
# p₃(7n + r)\equiv 0\pmod{7}
# \quad\text{for all integers }n\ge0.
# \]
# Find that r explicitly.
#
# Problem 2 (A two-factor divisor-sum identity)
# Define the sequence B(n) by the generating function
# \[
# \sum_{n=0}^\infty B(n)\,q^n
# \;=\;
# \prod_{m=1}^\infty
# \bigl(1 - q^m\bigr)^{-3}\,\bigl(1 + q^m\bigr).
# \]
# Express B(n) in closed form as an explicit linear combination of the usual divisor sums
# \(\sigma_k(n)=\sum_{d\mid n}d^k\).
#
# Problem 3 (Overpartitions into odd parts with parity condition)
# Let \(\overline p_{\mathrm{odd}}^{\mathrm{even}}(n)\) be the number of overpartitions of n into odd parts such that the total number of overlined parts is even.  Determine a product (or quotient) formula for its ordinary generating function, for example in terms of \(q\)\!-Pochhammer symbols,
# \[
# \sum_{n=0}^\infty
# \overline p_{\mathrm{odd}}^{\mathrm{even}}(n)\,q^n
# \;=\;
# \text{(explicit product in $q$)}.
# \]
#
# Problem 4 (Shifted Chebyshev generating function)
# For the Chebyshev polynomials of the first kind \(T_n(x)\), fix a nonnegative integer \(a\) and define
# \[
# G_a(x,t)\;=\;
# \sum_{n=0}^\infty T_{n+a}(x)\,t^n.
# \]
# Show that \(G_a(x,t)\) is a rational function in \(x\) and \(t\), and write it down explicitly.
# Evaluate them against these guidelines:
# ...
# Provide concise, actionable feedback on how to improve.
# 2025-05-27 14:52:59,407 - INFO - [Critic turn 3] Prompt:
# You are a mathematics assessment expert. Critique the following questions:
# Below is the revised problem set.  Each question asks you to “Find” or “Give” exactly one symbolic object.  Display‐math uses `$$…$$`, inline math uses `$…$`, and every answer is uniquely determined.
#
# 1.
# Let $p_3(n)$ be the number of partitions of $n$ into parts not divisible by 3.
# Find the unique residue
# $$r\in\{0,1,2,3,4,5,6\}$$
# such that for all integers $n\ge0$
# $$
# p_3(7n+r)\;\equiv\;0\pmod7.
# $$
#
# 2.
# Let
# $$
# \sum_{n=0}^{\infty}B(n)\,q^n
# \;=\;
# \prod_{m=1}^{\infty}(1-q^m)^{-3}(1+q^m),
# \qquad
# \sigma_k(n)=\sum_{d\mid n}d^k.
# $$
# Find the unique integers $c_1,c_3,c_5\in\Bbb Z$ such that for all integers $n\ge1$
# $$
# B(n)
# \;=\;
# c_1\,\sigma_1(n)\;+\;c_3\,\sigma_3(n)\;+\;c_5\,\sigma_5(n).
# $$
#
# 3.
# An _overpartition_ of $n$ is a partition in which the first occurrence of each distinct part may be overlined.  Let $\overline p_{\mathrm{odd}}^{\mathrm{even}}(n)$ be the number of overpartitions of $n$ into odd parts with an even number of overlined parts.
# Find the unique integer sequences $(\alpha_m)_{m\ge1}$ and $(\beta_m)_{m\ge1}$ for which
# $$
# \sum_{n=0}^{\infty}\overline p_{\mathrm{odd}}^{\mathrm{even}}(n)\,q^n
# \;=\;
# \prod_{m=1}^{\infty}(1-q^{2m-1})^{\alpha_m}(1+q^{2m-1})^{\beta_m}.
# $$
#
# 4.
# Define
# $$
# G_a(x,t)\;=\;\sum_{n=0}^{\infty}T_{n+a}(x)\,t^n,
# $$
# where $T_n(x)$ is the Chebyshev polynomial of the first kind satisfying $T_n(\cos\theta)=\cos(n\theta)$.
# For a fixed nonnegative integer $a$, find the unique rational function $R(x,t)\in\Bbb Q(x,t)$ such that
# $$
# G_a(x,t)\;=\;R(x,t).
# $$
# Evaluate them against these guidelines:
# 1. Input Format: Fully text-based. No diagrams, visual aids, or references to external media. 2. Mathematical Structure: Start with a well-defined setup—real-world or idealized. Avoid vague, puzzle-like, or speculative scenarios. 3. Solvable Target: Ask for a clear symbolic result (e.g., function, limit, closed-form expression). Do not use phrasing like 'Prove' or 'Show that'. 4. Multi-Step Reasoning: Require a logical sequence of algebraic or analytic steps, involving definitions, identities, or theorems. 5. Concise and Relevant: Include only essential information. Eliminate redundant details or irrelevant symbols. 6. Originality: Ensure the problem is unique and non-trivial. Avoid rewording standard textbook problems. 7. Single Output: Expect a single, unambiguous symbolic answer in LaTeX. Equivalent forms are allowed. No numeric approximations. Do not rely on computational tools - use traditional mathematical methods. 8. Solution Formatting: Format the equations, numbers and variables using LaTeX with Markdown syntax: Replace \(...\) with $...$ Replace \[...\] with $$...$$ 9. Language and Notation: Be rigorous and concise. Avoid colloquial terms. Use standard, consistent mathematical notation throughout. 10. Questions must not have multiple parts to answer, there should be only 1 solution to each question11. Only questions should be generated, no answers,solutions or explainations should be provided.
# Provide concise, actionable feedback on how to improve.
# 2025-05-27 14:52:59,409 - INFO - [Critic turn 3] Response:
# Overall
# The set is well-crafted and intellectually interesting, yet several items clash with the stated writing rules or leave avoidable ambiguities.  The comments below reference the numbering of your guidelines (1–11).
#
# ────────────────────────────────────────────────────────
# Global points
# •  (5) Concision – Each prompt carries background material that can be trimmed (e.g., “unique” is implied by “exactly one symbolic object”; the reminders about display-math are meta-instructions, not part of the problem).
# •  (8) LaTeX style – You mix \(...\)/\[...\] and $$…$$.  Consistently follow your own rule (replace \[...\] with $$…$$, etc.).
# •  (10) Single-answer rule – Questions 2 and 3 ask for several independent numbers/sequences, which effectively creates “multiple parts”.  Bundle them as one object (e.g., an ordered triple, a pair of closed-form formulas) or split into separate problems.
#
# ────────────────────────────────────────────────────────
# Problem-by-problem feedback
#
# 1.  Partition modulo-7 residue
#    •  Good fit for (3) and (4).
#    •  Suggestion (2,5): Delete “for all integers $n\ge0$” – that is implicit in the congruence statement that follows.
#    •  Clarify existence (6): add a parenthetical “(known to exist by a theorem of …)” or cite a standard result; otherwise a solver may doubt uniqueness.
#
# 2.  Triple of divisor-sum coefficients
#    •  Violates (10): three separate integers are requested.  Rephrase as “Find the ordered triple $(c_{1},c_{3},c_{5})\in\Bbb Z^{3}$ …”.
#    •  (2) Domain: add “for $|q|<1$” to legitimise the product.
#    •  (5) The definition of $\sigma_k$ is standard; you can drop it if brevity is paramount.
#
# 3.  Overpartition exponents
#    •  Major (10) issue: two unrelated sequences are required.  Package them as one pair $(\alpha_m,\beta_m)_{m\ge1}$ or split the task.
#    •  (5) “with an even number of overlined parts” is essential—keep it—but the word “unique” is not needed twice.
#    •  (6) Potential non-uniqueness: Because $(1-q^{2m-1})$ and $(1+q^{2m-1})$ are not algebraically independent, integer exponents might not be unique.  State the constraint that makes them unique (e.g., $\alpha_m\in\{0,1\}$, $\beta_m\in\Bbb Z$), or supply a closed-form formula instead of an entire infinite list.
#
# 4.  Chebyshev generating function
#    •  (2) Domain: declare $|t|<1$ or whatever region ensures convergence of $G_a$.
#    •  (5) The sentence “For a fixed nonnegative integer $a$” is enough; the second “such that” clause can drop “$=\;R(x,t)$”.
#    •  (3) Good: asks for a single rational function.
#    •  (4,6) Verify originality: many textbooks already give this closed form; consider adding a mild twist (e.g., “express $R$ as a quotient of two explicit polynomials”).
#
# ────────────────────────────────────────────────────────
# Concrete rewrite examples (illustrative)
#
# 2.  “Let $|q|<1$ and define $B(n)$ by
# $$\sum_{n\ge0} B(n)q^n=\prod_{m\ge1}(1-q^m)^{-3}(1+q^m).$$
# Find the ordered triple $(c_1,c_3,c_5)\in\Bbb Z^3$ such that for every $n\ge1$,
# $$B(n)=c_1\sigma_1(n)+c_3\sigma_3(n)+c_5\sigma_5(n).$$”
#
# 3.  “Find integer‐valued sequences $(\alpha_m)_{m\ge1}$, $(\beta_m)_{m\ge1}$, uniquely determined by the conditions …” → better: “Find closed‐form expressions for the integer sequences …”.
#
# ────────────────────────────────────────────────────────
# Action checklist
# 1. Remove meta-instructions from the prompts.
# 2. State domains of series/products explicitly.
# 3. Reword Q2 and Q3 to comply with the “single output” rule or split them.
# 4. Ensure uniqueness by adding explicit constraints where necessary.
# 5. Standardise LaTeX delimiters to match guideline 8.
# 2025-05-27 14:52:59,409 - INFO - [Critic turn 3] Response:
# Overall
# The set is well-crafted and intellectually interesting, yet several items clash with the stated writing rules or leave avoidable ambiguities.  The comments below reference the numbering of your guidelines (1–11).
#
# ────────────────────────────────────────────────────────
# Global points
# •  (5) Concision – Each prompt carries background material that can be trimmed (e.g., “unique” is implied by “exactly one symbolic object”; the reminders about display-math are meta-instructions, not part of the problem).
# •  (8) LaTeX style – You mix \(...\)/\[...\] and $$…$$.  Consistently follow your own rule (replace \[...\] with $$…$$, etc.).
# •  (10) Single-answer rule – Questions 2 and 3 ask for several independent numbers/sequences, which effectively creates “multiple parts”.  Bundle them as one object (e.g., an ordered triple, a pair of closed-form formulas) or split into separate problems.
#
# ────────────────────────────────────────────────────────
# Problem-by-problem feedback
#
# 1.  Partition modulo-7 residue
#    •  Good fit for (3) and (4).
#    •  Suggestion (2,5): Delete “for all integers $n\ge0$” – that is implicit in the congruence statement that follows.
#    •  Clarify existence (6): add a parenthetical “(known to exist by a theorem of …)” or cite a standard result; otherwise a solver may doubt uniqueness.
#
# 2.  Triple of divisor-sum coefficients
#    •  Violates (10): three separate integers are requested.  Rephrase as “Find the ordered triple $(c_{1},c_{3},c_{5})\in\Bbb Z^{3}$ …”.
#    •  (2) Domain: add “for $|q|<1$” to legitimise the product.
#    •  (5) The definition of $\sigma_k$ is standard; you can drop it if brevity is paramount.
#
# 3.  Overpartition exponents
#    •  Major (10) issue: two unrelated sequences are required.  Package them as one pair $(\alpha_m,\beta_m)_{m\ge1}$ or split the task.
#    •  (5) “with an even number of overlined parts” is essential—keep it—but the word “unique” is not needed twice.
#    •  (6) Potential non-uniqueness: Because $(1-q^{2m-1})$ and $(1+q^{2m-1})$ are not algebraically independent, integer exponents might not be unique.  State the constraint that makes them unique (e.g., $\alpha_m\in\{0,1\}$, $\beta_m\in\Bbb Z$), or supply a closed-form formula instead of an entire infinite list.
#
# 4.  Chebyshev generating function
#    •  (2) Domain: declare $|t|<1$ or whatever region ensures convergence of $G_a$.
#    •  (5) The sentence “For a fixed nonnegative integer $a$” is enough; the second “such that” clause can drop “$=\;R(x,t)$”.
#    •  (3) Good: asks for a single rational function.
#    •  (4,6) Verify originality: many textbooks already give this closed form; consider adding a mild twist (e.g., “express $R$ as a quotient of two explicit polynomials”).
#
# ────────────────────────────────────────────────────────
# Concrete rewrite examples (illustrative)
#
# 2.  “Let $|q|<1$ and define $B(n)$ by
# $$\sum_{n\ge0} B(n)q^n=\prod_{m\ge1}(1-q^m)^{-3}(1+q^m).$$
# Find the ordered triple $(c_1,c_3,c_5)\in\Bbb Z^3$ such that for every $n\ge1$,
# $$B(n)=c_1\sigma_1(n)+c_3\sigma_3(n)+c_5\sigma_5(n).$$”
#
# 3.  “Find integer‐valued sequences $(\alpha_m)_{m\ge1}$, $(\beta_m)_{m\ge1}$, uniquely determined by the conditions …” → better: “Find closed‐form expressions for the integer sequences …”.
#
# ────────────────────────────────────────────────────────
# Action checklist
# 1. Remove meta-instructions from the prompts.
# 2. State domains of series/products explicitly.
# 3. Reword Q2 and Q3 to comply with the “single output” rule or split them.
# 4. Ensure uniqueness by adding explicit constraints where necessary.
# 5. Standardise LaTeX delimiters to match guideline 8.
# 2025-05-27 14:52:59,409 - INFO - [Critic turn 3] Response:
# Overall
# The set is well-crafted and intellectually interesting, yet several items clash with the stated writing rules or leave avoidable ambiguities.  The comments below reference the numbering of your guidelines (1–11).
#
# ────────────────────────────────────────────────────────
# Global points
# •  (5) Concision – Each prompt carries background material that can be trimmed (e.g., “unique” is implied by “exactly one symbolic object”; the reminders about display-math are meta-instructions, not part of the problem).
# •  (8) LaTeX style – You mix \(...\)/\[...\] and $$…$$.  Consistently follow your own rule (replace \[...\] with $$…$$, etc.).
# •  (10) Single-answer rule – Questions 2 and 3 ask for several independent numbers/sequences, which effectively creates “multiple parts”.  Bundle them as one object (e.g., an ordered triple, a pair of closed-form formulas) or split into separate problems.
#
# ────────────────────────────────────────────────────────
# Problem-by-problem feedback
#
# 1.  Partition modulo-7 residue
#    •  Good fit for (3) and (4).
#    •  Suggestion (2,5): Delete “for all integers $n\ge0$” – that is implicit in the congruence statement that follows.
#    •  Clarify existence (6): add a parenthetical “(known to exist by a theorem of …)” or cite a standard result; otherwise a solver may doubt uniqueness.
#
# 2.  Triple of divisor-sum coefficients
#    •  Violates (10): three separate integers are requested.  Rephrase as “Find the ordered triple $(c_{1},c_{3},c_{5})\in\Bbb Z^{3}$ …”.
#    •  (2) Domain: add “for $|q|<1$” to legitimise the product.
#    •  (5) The definition of $\sigma_k$ is standard; you can drop it if brevity is paramount.
#
# 3.  Overpartition exponents
#    •  Major (10) issue: two unrelated sequences are required.  Package them as one pair $(\alpha_m,\beta_m)_{m\ge1}$ or split the task.
#    •  (5) “with an even number of overlined parts” is essential—keep it—but the word “unique” is not needed twice.
#    •  (6) Potential non-uniqueness: Because $(1-q^{2m-1})$ and $(1+q^{2m-1})$ are not algebraically independent, integer exponents might not be unique.  State the constraint that makes them unique (e.g., $\alpha_m\in\{0,1\}$, $\beta_m\in\Bbb Z$), or supply a closed-form formula instead of an entire infinite list.
#
# 4.  Chebyshev generating function
#    •  (2) Domain: declare $|t|<1$ or whatever region ensures convergence of $G_a$.
#    •  (5) The sentence “For a fixed nonnegative integer $a$” is enough; the second “such that” clause can drop “$=\;R(x,t)$”.
#    •  (3) Good: asks for a single rational function.
#    •  (4,6) Verify originality: many textbooks already give this closed form; consider adding a mild twist (e.g., “express $R$ as a quotient of two explicit polynomials”).
#
# ────────────────────────────────────────────────────────
# Concrete rewrite examples (illustrative)
#
# 2.  “Let $|q|<1$ and define $B(n)$ by
# $$\sum_{n\ge0} B(n)q^n=\prod_{m\ge1}(1-q^m)^{-3}(1+q^m).$$
# Find the ordered triple $(c_1,c_3,c_5)\in\Bbb Z^3$ such that for every $n\ge1$,
# $$B(n)=c_1\sigma_1(n)+c_3\sigma_3(n)+c_5\sigma_5(n).$$”
#
# 3.  “Find integer‐valued sequences $(\alpha_m)_{m\ge1}$, $(\beta_m)_{m\ge1}$, uniquely determined by the conditions …” → better: “Find closed‐form expressions for the integer sequences …”.
#
# ────────────────────────────────────────────────────────
# Action checklist
# 1. Remove meta-instructions from the prompts.
# 2. State domains of series/products explicitly.
# 3. Reword Q2 and Q3 to comply with the “single output” rule or split them.
# 4. Ensure uniqueness by adding explicit constraints where necessary.
# 5. Standardise LaTeX delimiters to match guideline 8.
# 2025-05-27 14:52:59,415 - INFO - Author–Critique loop for Mathematics complete.
# 2025-05-27 14:52:59,415 - INFO - Author–Critique loop for Mathematics complete.
# 2025-05-27 14:52:59,415 - INFO - Author–Critique loop for Mathematics complete.

# %%
import json

# 1. Load your JSON data
with open('final_questions_maths.json', 'r', encoding='utf-8') as f:
    all_questions = json.load(f)

# 2. Open a text file for writing the “pretty” version
with open('final_questions_maths.txt', 'w', encoding='utf-8') as out:
    for entry in all_questions:
        # Write header info
        out.write(f"Topics: {entry['topics']}\n")
        out.write(f"Key Concepts: {entry['key_concepts']}\n\n")
        
        # Extract questions; could be a single string or a list
        qs = entry['questions']
        
        # If it's one big string, just replace any literal "\n"
        if isinstance(qs, str):
            text = qs.replace('\\n', '\n')
            out.write(text)
            if not text.endswith('\n'):
                out.write('\n')
        
        # If it's a list of strings, iterate
        else:
            for q in qs:
                # json.load already gives you real \n, but just in case:
                line = q.replace('\\n', '\n')
                out.write(line)
                if not line.endswith('\n'):
                    out.write('\n')
        
        # Separator between entries
        out.write('\n' + '='*40 + '\n\n')
